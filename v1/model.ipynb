# %%
import pandas as pd
import cv2
import time
from PIL import Image

# %%
import xml.etree.ElementTree as ET
import os

def parse_annotation(ann_dir, img_dir, labels=[]):
    all_imgs = []
    seen_labels = {}
    
    for ann in os.listdir(ann_dir):
        img = {'object':[]}

        tree = ET.parse(ann_dir + ann)
        
        for elem in tree.iter():
            if 'folder' in elem.tag:
                img['folder'] = img_dir + "images/" + elem.text
            if 'filename' in elem.tag:
                img['filename'] = img['folder'] + "/" + elem.text
            if 'width' in elem.tag:
                img['width'] = int(elem.text)
            if 'height' in elem.tag:
                img['height'] = int(elem.text)
            if 'object' in elem.tag or 'part' in elem.tag:
                obj = {}
                
                for attr in list(elem):
                    if 'name' in attr.tag:
                        obj['name'] = attr.text

                        if obj['name'] in seen_labels:
                            seen_labels[obj['name']] += 1
                        else:
                            seen_labels[obj['name']] = 1
                        
                        if len(labels) > 0 and obj['name'] not in labels:
                            break
                        else:
                            img['object'] += [obj]
                            
                    if 'bndbox' in attr.tag:
                        for dim in list(attr):
                            if 'xmin' in dim.tag:
                                obj['xmin'] = int(round(float(dim.text)))
                            if 'ymin' in dim.tag:
                                obj['ymin'] = int(round(float(dim.text)))
                            if 'xmax' in dim.tag:
                                obj['xmax'] = int(round(float(dim.text)))
                            if 'ymax' in dim.tag:
                                obj['ymax'] = int(round(float(dim.text)))

        if len(img['object']) > 0:
            all_imgs += [img]
                        
    return all_imgs, seen_labels

train_image_folder = 'wider_face/data/WIDER_train/'
train_annot_folder = 'wider_face/data/WIDER_train_annotations/'

train_imgs, train_labels = parse_annotation(train_annot_folder, train_image_folder, labels=['face'])

# %%
train_labels
# Out:
# {'face': 159424}

# %%
train_imgs
# Out:
# [{'object': [{'name': 'face',
#     'xmin': 174,
#     'ymin': 321,
#     'xmax': 796,
#     'ymax': 965}],
#   'folder': 'wider_face/data/WIDER_train/images/28--Sports_Fan',
#   'filename': 'wider_face/data/WIDER_train/images/28--Sports_Fan/28_Sports_Fan_Sports_Fan_28_216.jpg',
#   'width': 1024,
#   'height': 1392},
#  {'object': [{'name': 'face',
#     'xmin': 580,
#     'ymin': 90,
#     'xmax': 672,
#     'ymax': 216},
#    {'name': 'face', 'xmin': 714, 'ymin': 182, 'xmax': 818, 'ymax': 328}],
#   'folder': 'wider_face/data/WIDER_train/images/20--Family_Group',
#   'filename': 'wider_face/data/WIDER_train/images/20--Family_Group/20_Family_Group_Family_Group_20_383.jpg',
#   'width': 1024,
#   'height': 683},
#  {'object': [{'name': 'face',
#     'xmin': 574,
#     'ymin': 292,
#     'xmax': 630,
#     'ymax': 346}],
#   'folder': 'wider_face/data/WIDER_train/images/7--Cheering',
#   'filename': 'wider_face/data/WIDER_train/images/7--Cheering/7_Cheering_Cheering_7_611.jpg',
#   'width': 1024,
#   'height': 767},
#  {'object': [{'name': 'face',
#     'xmin': 881,
#     'ymin': 22,
#     'xmax': 921,
#     'ymax': 82},
#    {'name': 'face', 'xmin': 581, 'ymin': 66, 'xmax': 629, 'ymax': 128},
#    {'name': 'face', 'xmin': 353, 'ymin': 69, 'xmax': 404, 'ymax': 115},
#    {'name': 'face', 'xmin': 72, 'ymin': 10, 'xmax': 120, 'ymax': 71}],
#   'folder': 'wider_face/data/WIDER_train/images/51--Dresses',
#   'filename': 'wider_face/data/WIDER_train/images/51--Dresses/51_Dresses_wearingdress_51_634.jpg',
#   'width': 1024,
#   'height': 659},
#  {'object': [{'name': 'face',
#     'xmin': 778,
#     'ymin': 171,
#     'xmax': 815,
#     'ymax': 212},
#    {'name': 'face', 'xmin': 597, 'ymin': 141, 'xmax': 622, 'ymax': 178},
#    {'name': 'face', 'xmin': 526, 'ymin': 164, 'xmax': 555, 'ymax': 200},
#    {'name': 'face', 'xmin': 439, 'ymin': 198, 'xmax': 482, 'ymax': 253},
#    {'name': 'face', 'xmin': 409, 'ymin': 173, 'xmax': 443, 'ymax': 216},
#    {'name': 'face', 'xmin': 334, 'ymin': 241, 'xmax': 390, 'ymax': 309},
#    {'name': 'face', 'xmin': 227, 'ymin': 353, 'xmax': 324, 'ymax': 487},
#    {'name': 'face', 'xmin': 83, 'ymin': 259, 'xmax': 156, 'ymax': 349}],
#   'folder': 'wider_face/data/WIDER_train/images/11--Meeting',
#   'filename': 'wider_face/data/WIDER_train/images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_105.jpg',
#   'width': 1024,
#   'height': 765},
#  {'object': [{'name': 'face',
#     'xmin': 476,
#     'ymin': 332,
#     'xmax': 526,
#     'ymax': 366},
#    {'name': 'face', 'xmin': 739, 'ymin': 478, 'xmax': 759, 'ymax': 504},
#    {'name': 'face', 'xmin': 974, 'ymin': 481, 'xmax': 995, 'ymax': 506},
#    {'name': 'face', 'xmin': 792, 'ymin': 478, 'xmax': 809, 'ymax': 499},
#    {'name': 'face', 'xmin': 844, 'ymin': 490, 'xmax': 860, 'ymax': 512},
#    {'name': 'face', 'xmin': 900, 'ymin': 499, 'xmax': 918, 'ymax': 522},
#    {'name': 'face', 'xmin': 686, 'ymin': 482, 'xmax': 703, 'ymax': 505},
#    {'name': 'face', 'xmin': 639, 'ymin': 488, 'xmax': 655, 'ymax': 509},
#    {'name': 'face', 'xmin': 590, 'ymin': 483, 'xmax': 604, 'ymax': 504},
#    {'name': 'face', 'xmin': 553, 'ymin': 492, 'xmax': 566, 'ymax': 510},
#    {'name': 'face', 'xmin': 500, 'ymin': 480, 'xmax': 515, 'ymax': 500},
#    {'name': 'face', 'xmin': 238, 'ymin': 480, 'xmax': 251, 'ymax': 497},
#    {'name': 'face', 'xmin': 283, 'ymin': 490, 'xmax': 295, 'ymax': 508},
#    {'name': 'face', 'xmin': 322, 'ymin': 480, 'xmax': 335, 'ymax': 498},
#    {'name': 'face', 'xmin': 345, 'ymin': 484, 'xmax': 357, 'ymax': 501},
#    {'name': 'face', 'xmin': 361, 'ymin': 484, 'xmax': 375, 'ymax': 505},
#    {'name': 'face', 'xmin': 199, 'ymin': 473, 'xmax': 214, 'ymax': 493},
#    {'name': 'face', 'xmin': 161, 'ymin': 477, 'xmax': 174, 'ymax': 495},
#    {'name': 'face', 'xmin': 77, 'ymin': 475, 'xmax': 91, 'ymax': 496},
#    {'name': 'face', 'xmin': 34, 'ymin': 472, 'xmax': 47, 'ymax': 490},
#    {'name': 'face', 'xmin': 574, 'ymin': 174, 'xmax': 606, 'ymax': 210}],
#   'folder': 'wider_face/data/WIDER_train/images/4--Dancing',
#   'filename': 'wider_face/data/WIDER_train/images/4--Dancing/4_Dancing_Dancing_4_108.jpg',
#   'width': 1024,
#   'height': 732},
#  {'object': [{'name': 'face',
#     'xmin': 195,
#     'ymin': 219,
#     'xmax': 473,
#     'ymax': 476}],
#   'folder': 'wider_face/data/WIDER_train/images/52--Photographers',
#   'filename': 'wider_face/data/WIDER_train/images/52--Photographers/52_Photographers_photographertakingphoto_52_628.jpg',
#   'width': 1024,
#   'height': 1535},
#  {'object': [{'name': 'face',
#     'xmin': 650,
#     'ymin': 169,
#     'xmax': 660,
#     'ymax': 184},
#    {'name': 'face', 'xmin': 666, 'ymin': 153, 'xmax': 675, 'ymax': 167},
#    {'name': 'face', 'xmin': 720, 'ymin': 155, 'xmax': 730, 'ymax': 171},
#    {'name': 'face', 'xmin': 735, 'ymin': 173, 'xmax': 745, 'ymax': 188},
#    {'name': 'face', 'xmin': 767, 'ymin': 167, 'xmax': 779, 'ymax': 182},
#    {'name': 'face', 'xmin': 974, 'ymin': 179, 'xmax': 984, 'ymax': 193},
#    {'name': 'face', 'xmin': 814, 'ymin': 158, 'xmax': 873, 'ymax': 233},
#    {'name': 'face', 'xmin': 486, 'ymin': 136, 'xmax': 500, 'ymax': 155},
#    {'name': 'face', 'xmin': 381, 'ymin': 172, 'xmax': 401, 'ymax': 199},
#    {'name': 'face', 'xmin': 329, 'ymin': 149, 'xmax': 348, 'ymax': 175},
#    {'name': 'face', 'xmin': 278, 'ymin': 170, 'xmax': 307, 'ymax': 207},
#    {'name': 'face', 'xmin': 340, 'ymin': 261, 'xmax': 372, 'ymax': 300},
#    {'name': 'face', 'xmin': 541, 'ymin': 170, 'xmax': 586, 'ymax': 224}],
#   'folder': 'wider_face/data/WIDER_train/images/25--Soldier_Patrol',
#   'filename': 'wider_face/data/WIDER_train/images/25--Soldier_Patrol/25_Soldier_Patrol_Soldier_Patrol_25_381.jpg',
#   'width': 1024,
#   'height': 808},
#  {'object': [{'name': 'face',
#     'xmin': 151,
#     'ymin': 210,
#     'xmax': 275,
#     'ymax': 395},
#    {'name': 'face', 'xmin': 696, 'ymin': 320, 'xmax': 841, 'ymax': 495}],
#   'folder': 'wider_face/data/WIDER_train/images/24--Soldier_Firing',
#   'filename': 'wider_face/data/WIDER_train/images/24--Soldier_Firing/24_Soldier_Firing_Soldier_Firing_24_631.jpg',
#   'width': 1024,
#   'height': 1377},
#  {'object': [{'name': 'face',
#     'xmin': 491,
#     'ymin': 108,
#     'xmax': 609,
#     'ymax': 293}],
#   'folder': 'wider_face/data/WIDER_train/images/16--Award_Ceremony',
#   'filename': 'wider_face/data/WIDER_train/images/16--Award_Ceremony/16_Award_Ceremony_Awards_Ceremony_16_291.jpg',
#   'width': 1024,
#   'height': 1636},
#  {'object': [{'name': 'face',
#     'xmin': 218,
#     'ymin': 156,
#     'xmax': 259,
#     'ymax': 217},
#    {'name': 'face', 'xmin': 307, 'ymin': 211, 'xmax': 317, 'ymax': 224},
#    {'name': 'face', 'xmin': 557, 'ymin': 196, 'xmax': 599, 'ymax': 238},
#    {'name': 'face', 'xmin': 466, 'ymin': 207, 'xmax': 474, 'ymax': 217},
#    {'name': 'face', 'xmin': 526, 'ymin': 196, 'xmax': 535, 'ymax': 208},
#    {'name': 'face', 'xmin': 622, 'ymin': 153, 'xmax': 647, 'ymax': 188},
#    {'name': 'face', 'xmin': 742, 'ymin': 197, 'xmax': 752, 'ymax': 210}],
#   'folder': 'wider_face/data/WIDER_train/images/36--Football',
#   'filename': 'wider_face/data/WIDER_train/images/36--Football/36_Football_Football_36_218.jpg',
#   'width': 1024,
#   'height': 577},
#  {'object': [{'name': 'face',
#     'xmin': 395,
#     'ymin': 73,
#     'xmax': 506,
#     'ymax': 214}],
#   'folder': 'wider_face/data/WIDER_train/images/51--Dresses',
#   'filename': 'wider_face/data/WIDER_train/images/51--Dresses/51_Dresses_wearingdress_51_620.jpg',
#   'width': 1024,
#   'height': 1289},
#  {'object': [{'name': 'face',
#     'xmin': 536,
#     'ymin': 54,
#     'xmax': 604,
#     'ymax': 142},
#    {'name': 'face', 'xmin': 828, 'ymin': 84, 'xmax': 900, 'ymax': 182},
#    {'name': 'face', 'xmin': 88, 'ymin': 116, 'xmax': 142, 'ymax': 184}],
#   'folder': 'wider_face/data/WIDER_train/images/32--Worker_Laborer',
#   'filename': 'wider_face/data/WIDER_train/images/32--Worker_Laborer/32_Worker_Laborer_Worker_Laborer_32_445.jpg',
#   'width': 1024,
#   'height': 652},
#  {'object': [{'name': 'face',
#     'xmin': 323,
#     'ymin': 333,
#     'xmax': 356,
#     'ymax': 378},
#    {'name': 'face', 'xmin': 491, 'ymin': 325, 'xmax': 515, 'ymax': 353},
#    {'name': 'face', 'xmin': 607, 'ymin': 337, 'xmax': 633, 'ymax': 371}],
#   'folder': 'wider_face/data/WIDER_train/images/43--Row_Boat',
#   'filename': 'wider_face/data/WIDER_train/images/43--Row_Boat/43_Row_Boat_Rowboat_43_383.jpg',
#   'width': 1024,
#   'height': 680},
#  {'object': [{'name': 'face',
#     'xmin': 180,
#     'ymin': 180,
#     'xmax': 298,
#     'ymax': 348},
#    {'name': 'face', 'xmin': 716, 'ymin': 72, 'xmax': 812, 'ymax': 206}],
#   'folder': 'wider_face/data/WIDER_train/images/12--Group',
#   'filename': 'wider_face/data/WIDER_train/images/12--Group/12_Group_Team_Organized_Group_12_Group_Team_Organized_Group_12_799.jpg',
#   'width': 1024,
#   'height': 701},
#  {'object': [{'name': 'face',
#     'xmin': 462,
#     'ymin': 124,
#     'xmax': 580,
#     'ymax': 292},
#    {'name': 'face', 'xmin': 450, 'ymin': 330, 'xmax': 584, 'ymax': 530}],
#   'folder': 'wider_face/data/WIDER_train/images/41--Swimming',
#   'filename': 'wider_face/data/WIDER_train/images/41--Swimming/41_Swimming_Swimming_41_59.jpg',
#   'width': 1024,
#   'height': 594},
#  {'object': [{'name': 'face',
#     'xmin': 174,
#     'ymin': 198,
#     'xmax': 712,
#     'ymax': 863}],
#   'folder': 'wider_face/data/WIDER_train/images/28--Sports_Fan',
#   'filename': 'wider_face/data/WIDER_train/images/28--Sports_Fan/28_Sports_Fan_Sports_Fan_28_202.jpg',
#   'width': 1024,
#   'height': 1392},
#  {'object': [{'name': 'face',
#     'xmin': 484,
#     'ymin': 105,
#     'xmax': 671,
#     'ymax': 361},
#    {'name': 'face', 'xmin': 908, 'ymin': 996, 'xmax': 982, 'ymax': 1103},
#    {'name': 'face', 'xmin': 140, 'ymin': 69, 'xmax': 280, 'ymax': 245},
#    {'name': 'face', 'xmin': 47, 'ymin': 336, 'xmax': 149, 'ymax': 501}],
#   'folder': 'wider_face/data/WIDER_train/images/5--Car_Accident',
#   'filename': 'wider_face/data/WIDER_train/images/5--Car_Accident/5_Car_Accident_Accident_5_784.jpg',
#   'width': 1024,
#   'height': 1409},
#  {'object': [{'name': 'face',
#     'xmin': 526,
#     'ymin': 417,
#     'xmax': 718,
#     'ymax': 663}],
#   'folder': 'wider_face/data/WIDER_train/images/44--Aerobics',
#   'filename': 'wider_face/data/WIDER_train/images/44--Aerobics/44_Aerobics_Aerobics_44_259.jpg',
#   'width': 1024,
#   'height': 1538},
#  {'object': [{'name': 'face',
#     'xmin': 142,
#     'ymin': 148,
#     'xmax': 233,
#     'ymax': 284},
#    {'name': 'face', 'xmin': 390, 'ymin': 81, 'xmax': 490, 'ymax': 217},
#    {'name': 'face', 'xmin': 727, 'ymin': 81, 'xmax': 843, 'ymax': 215}],
#   'folder': 'wider_face/data/WIDER_train/images/31--Waiter_Waitress',
#   'filename': 'wider_face/data/WIDER_train/images/31--Waiter_Waitress/31_Waiter_Waitress_Waiter_Waitress_31_586.jpg',
#   'width': 1024,
#   'height': 1041},
#  {'object': [{'name': 'face',
#     'xmin': 717,
#     'ymin': 77,
#     'xmax': 756,
#     'ymax': 130},
#    {'name': 'face', 'xmin': 406, 'ymin': 459, 'xmax': 422, 'ymax': 478},
#    {'name': 'face', 'xmin': 207, 'ymin': 379, 'xmax': 226, 'ymax': 401},
#    {'name': 'face', 'xmin': 248, 'ymin': 377, 'xmax': 263, 'ymax': 393},
#    {'name': 'face', 'xmin': 431, 'ymin': 437, 'xmax': 445, 'ymax': 454},
#    {'name': 'face', 'xmin': 445, 'ymin': 416, 'xmax': 458, 'ymax': 433},
#    {'name': 'face', 'xmin': 660, 'ymin': 443, 'xmax': 698, 'ymax': 492},
#    {'name': 'face', 'xmin': 506, 'ymin': 467, 'xmax': 519, 'ymax': 486},
#    {'name': 'face', 'xmin': 239, 'ymin': 376, 'xmax': 249, 'ymax': 389},
#    {'name': 'face', 'xmin': 897, 'ymin': 420, 'xmax': 907, 'ymax': 432},
#    {'name': 'face', 'xmin': 835, 'ymin': 390, 'xmax': 846, 'ymax': 404},
#    {'name': 'face', 'xmin': 795, 'ymin': 394, 'xmax': 806, 'ymax': 404},
#    {'name': 'face', 'xmin': 995, 'ymin': 436, 'xmax': 1006, 'ymax': 453},
#    {'name': 'face', 'xmin': 877, 'ymin': 400, 'xmax': 884, 'ymax': 410},
#    {'name': 'face', 'xmin': 961, 'ymin': 400, 'xmax': 968, 'ymax': 409},
#    {'name': 'face', 'xmin': 972, 'ymin': 390, 'xmax': 980, 'ymax': 400},
#    {'name': 'face', 'xmin': 390, 'ymin': 439, 'xmax': 403, 'ymax': 456}],
#   'folder': 'wider_face/data/WIDER_train/images/61--Street_Battle',
#   'filename': 'wider_face/data/WIDER_train/images/61--Street_Battle/61_Street_Battle_streetfight_61_111.jpg',
#   'width': 1024,
#   'height': 576},
#  {'object': [{'name': 'face',
#     'xmin': 54,
#     'ymin': 218,
#     'xmax': 86,
#     'ymax': 264},
#    {'name': 'face', 'xmin': 160, 'ymin': 211, 'xmax': 218, 'ymax': 264},
#    {'name': 'face', 'xmin': 224, 'ymin': 229, 'xmax': 262, 'ymax': 267},
#    {'name': 'face', 'xmin': 295, 'ymin': 195, 'xmax': 336, 'ymax': 246},
#    {'name': 'face', 'xmin': 337, 'ymin': 216, 'xmax': 373, 'ymax': 251},
#    {'name': 'face', 'xmin': 390, 'ymin': 198, 'xmax': 444, 'ymax': 259},
#    {'name': 'face', 'xmin': 499, 'ymin': 212, 'xmax': 546, 'ymax': 270},
#    {'name': 'face', 'xmin': 570, 'ymin': 229, 'xmax': 614, 'ymax': 279},
#    {'name': 'face', 'xmin': 619, 'ymin': 215, 'xmax': 656, 'ymax': 255},
#    {'name': 'face', 'xmin': 668, 'ymin': 213, 'xmax': 693, 'ymax': 245},
#    {'name': 'face', 'xmin': 680, 'ymin': 194, 'xmax': 724, 'ymax': 244},
#    {'name': 'face', 'xmin': 741, 'ymin': 217, 'xmax': 772, 'ymax': 252},
#    {'name': 'face', 'xmin': 821, 'ymin': 258, 'xmax': 847, 'ymax': 294},
#    {'name': 'face', 'xmin': 917, 'ymin': 243, 'xmax': 946, 'ymax': 278},
#    {'name': 'face', 'xmin': 777, 'ymin': 254, 'xmax': 801, 'ymax': 281},
#    {'name': 'face', 'xmin': 17, 'ymin': 203, 'xmax': 35, 'ymax': 247},
#    {'name': 'face', 'xmin': 864, 'ymin': 283, 'xmax': 887, 'ymax': 312}],
#   'folder': 'wider_face/data/WIDER_train/images/10--People_Marching',
#   'filename': 'wider_face/data/WIDER_train/images/10--People_Marching/10_People_Marching_People_Marching_2_456.jpg',
#   'width': 1024,
#   'height': 754},
#  {'object': [{'name': 'face',
#     'xmin': 36,
#     'ymin': 310,
#     'xmax': 150,
#     'ymax': 494},
#    {'name': 'face', 'xmin': 300, 'ymin': 318, 'xmax': 414, 'ymax': 468},
#    {'name': 'face', 'xmin': 582, 'ymin': 236, 'xmax': 708, 'ymax': 420},
#    {'name': 'face', 'xmin': 838, 'ymin': 226, 'xmax': 968, 'ymax': 420}],
#   'folder': 'wider_face/data/WIDER_train/images/3--Riot',
#   'filename': 'wider_face/data/WIDER_train/images/3--Riot/3_Riot_Riot_3_707.jpg',
#   'width': 1024,
#   'height': 996},
#  {'object': [{'name': 'face',
#     'xmin': 716,
#     'ymin': 114,
#     'xmax': 798,
#     'ymax': 228}],
#   'folder': 'wider_face/data/WIDER_train/images/44--Aerobics',
#   'filename': 'wider_face/data/WIDER_train/images/44--Aerobics/44_Aerobics_Aerobics_44_271.jpg',
#   'width': 1024,
#   'height': 596},
#  {'object': [{'name': 'face',
#     'xmin': 176,
#     'ymin': 405,
#     'xmax': 262,
#     'ymax': 508},
#    {'name': 'face', 'xmin': 444, 'ymin': 352, 'xmax': 519, 'ymax': 455}],
#   'folder': 'wider_face/data/WIDER_train/images/24--Soldier_Firing',
#   'filename': 'wider_face/data/WIDER_train/images/24--Soldier_Firing/24_Soldier_Firing_Soldier_Firing_24_619.jpg',
#   'width': 1024,
#   'height': 1431},
#  {'object': [{'name': 'face',
#     'xmin': 895,
#     'ymin': 130,
#     'xmax': 926,
#     'ymax': 177},
#    {'name': 'face', 'xmin': 758, 'ymin': 156, 'xmax': 771, 'ymax': 175},
#    {'name': 'face', 'xmin': 391, 'ymin': 102, 'xmax': 432, 'ymax': 162},
#    {'name': 'face', 'xmin': 63, 'ymin': 55, 'xmax': 92, 'ymax': 91},
#    {'name': 'face', 'xmin': 276, 'ymin': 157, 'xmax': 303, 'ymax': 195}],
#   'folder': 'wider_face/data/WIDER_train/images/37--Soccer',
#   'filename': 'wider_face/data/WIDER_train/images/37--Soccer/37_Soccer_Soccer_37_400.jpg',
#   'width': 1024,
#   'height': 685},
#  {'object': [{'name': 'face',
#     'xmin': 422,
#     'ymin': 86,
#     'xmax': 477,
#     'ymax': 148},
#    {'name': 'face', 'xmin': 599, 'ymin': 88, 'xmax': 631, 'ymax': 144},
#    {'name': 'face', 'xmin': 913, 'ymin': 201, 'xmax': 941, 'ymax': 236},
#    {'name': 'face', 'xmin': 799, 'ymin': 276, 'xmax': 823, 'ymax': 305},
#    {'name': 'face', 'xmin': 97, 'ymin': 263, 'xmax': 125, 'ymax': 298},
#    {'name': 'face', 'xmin': 40, 'ymin': 318, 'xmax': 59, 'ymax': 344}],
#   'folder': 'wider_face/data/WIDER_train/images/37--Soccer',
#   'filename': 'wider_face/data/WIDER_train/images/37--Soccer/37_Soccer_soccer_ball_37_425.jpg',
#   'width': 1024,
#   'height': 576},
#  {'object': [{'name': 'face',
#     'xmin': 696,
#     'ymin': 64,
#     'xmax': 846,
#     'ymax': 276}],
#   'folder': 'wider_face/data/WIDER_train/images/45--Balloonist',
#   'filename': 'wider_face/data/WIDER_train/images/45--Balloonist/45_Balloonist_Balloonist_45_835.jpg',
#   'width': 1024,
#   'height': 681},
#  {'object': [{'name': 'face',
#     'xmin': 534,
#     'ymin': 1073,
#     'xmax': 821,
#     'ymax': 1206}],
#   'folder': 'wider_face/data/WIDER_train/images/35--Basketball',
#   'filename': 'wider_face/data/WIDER_train/images/35--Basketball/35_Basketball_playingbasketball_35_415.jpg',
#   'width': 1024,
#   'height': 1579},
#  {'object': [{'name': 'face',
#     'xmin': 573,
#     'ymin': 45,
#     'xmax': 720,
#     'ymax': 261},
#    {'name': 'face', 'xmin': 181, 'ymin': 149, 'xmax': 320, 'ymax': 352}],
#   'folder': 'wider_face/data/WIDER_train/images/13--Interview',
#   'filename': 'wider_face/data/WIDER_train/images/13--Interview/13_Interview_Interview_On_Location_13_607.jpg',
#   'width': 1024,
#   'height': 1366},
#  {'object': [{'name': 'face',
#     'xmin': 381,
#     'ymin': 323,
#     'xmax': 586,
#     'ymax': 659},
#    {'name': 'face', 'xmin': 176, 'ymin': 360, 'xmax': 371, 'ymax': 581}],
#   'folder': 'wider_face/data/WIDER_train/images/18--Concerts',
#   'filename': 'wider_face/data/WIDER_train/images/18--Concerts/18_Concerts_Concerts_18_502.jpg',
#   'width': 1024,
#   'height': 1366},
#  {'object': [{'name': 'face',
#     'xmin': 761,
#     'ymin': 98,
#     'xmax': 826,
#     'ymax': 173},
#    {'name': 'face', 'xmin': 841, 'ymin': 402, 'xmax': 891, 'ymax': 473},
#    {'name': 'face', 'xmin': 237, 'ymin': 417, 'xmax': 281, 'ymax': 479},
#    {'name': 'face', 'xmin': 291, 'ymin': 103, 'xmax': 363, 'ymax': 189}],
#   'folder': 'wider_face/data/WIDER_train/images/11--Meeting',
#   'filename': 'wider_face/data/WIDER_train/images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_139.jpg',
#   'width': 1024,
#   'height': 791},
#  {'object': [{'name': 'face',
#     'xmin': 60,
#     'ymin': 194,
#     'xmax': 68,
#     'ymax': 201},
#    {'name': 'face', 'xmin': 141, 'ymin': 184, 'xmax': 147, 'ymax': 192},
#    {'name': 'face', 'xmin': 424, 'ymin': 276, 'xmax': 431, 'ymax': 286},
#    {'name': 'face', 'xmin': 917, 'ymin': 261, 'xmax': 933, 'ymax': 286},
#    {'name': 'face', 'xmin': 982, 'ymin': 266, 'xmax': 1002, 'ymax': 293},
#    {'name': 'face', 'xmin': 880, 'ymin': 324, 'xmax': 890, 'ymax': 337},
#    {'name': 'face', 'xmin': 889, 'ymin': 341, 'xmax': 899, 'ymax': 351},
#    {'name': 'face', 'xmin': 814, 'ymin': 302, 'xmax': 821, 'ymax': 311},
#    {'name': 'face', 'xmin': 816, 'ymin': 319, 'xmax': 824, 'ymax': 331},
#    {'name': 'face', 'xmin': 38, 'ymin': 188, 'xmax': 45, 'ymax': 196},
#    {'name': 'face', 'xmin': 239, 'ymin': 219, 'xmax': 243, 'ymax': 224},
#    {'name': 'face', 'xmin': 231, 'ymin': 219, 'xmax': 236, 'ymax': 226},
#    {'name': 'face', 'xmin': 316, 'ymin': 210, 'xmax': 323, 'ymax': 219},
#    {'name': 'face', 'xmin': 824, 'ymin': 272, 'xmax': 829, 'ymax': 280},
#    {'name': 'face', 'xmin': 831, 'ymin': 315, 'xmax': 837, 'ymax': 324},
#    {'name': 'face', 'xmin': 776, 'ymin': 316, 'xmax': 781, 'ymax': 323},
#    {'name': 'face', 'xmin': 787, 'ymin': 322, 'xmax': 794, 'ymax': 330},
#    {'name': 'face', 'xmin': 809, 'ymin': 321, 'xmax': 815, 'ymax': 329},
#    {'name': 'face', 'xmin': 878, 'ymin': 339, 'xmax': 885, 'ymax': 345},
#    {'name': 'face', 'xmin': 882, 'ymin': 353, 'xmax': 890, 'ymax': 363},
#    {'name': 'face', 'xmin': 888, 'ymin': 366, 'xmax': 895, 'ymax': 374},
#    {'name': 'face', 'xmin': 876, 'ymin': 349, 'xmax': 883, 'ymax': 358},
#    {'name': 'face', 'xmin': 843, 'ymin': 333, 'xmax': 852, 'ymax': 343}],
#   'folder': 'wider_face/data/WIDER_train/images/22--Picnic',
#   'filename': 'wider_face/data/WIDER_train/images/22--Picnic/22_Picnic_Picnic_22_687.jpg',
#   'width': 1024,
#   'height': 669},
#  {'object': [{'name': 'face',
#     'xmin': 243,
#     'ymin': 240,
#     'xmax': 820,
#     'ymax': 934}],
#   'folder': 'wider_face/data/WIDER_train/images/38--Tennis',
#   'filename': 'wider_face/data/WIDER_train/images/38--Tennis/38_Tennis_Tennis_38_780.jpg',
#   'width': 1024,
#   'height': 1536},
#  {'object': [{'name': 'face',
#     'xmin': 428,
#     'ymin': 468,
#     'xmax': 484,
#     'ymax': 560},
#    {'name': 'face', 'xmin': 584, 'ymin': 526, 'xmax': 636, 'ymax': 612},
#    {'name': 'face', 'xmin': 728, 'ymin': 486, 'xmax': 790, 'ymax': 564},
#    {'name': 'face', 'xmin': 862, 'ymin': 492, 'xmax': 922, 'ymax': 582},
#    {'name': 'face', 'xmin': 530, 'ymin': 404, 'xmax': 612, 'ymax': 458}],
#   'folder': 'wider_face/data/WIDER_train/images/40--Gymnastics',
#   'filename': 'wider_face/data/WIDER_train/images/40--Gymnastics/40_Gymnastics_Gymnastics_40_987.jpg',
#   'width': 1024,
#   'height': 940},
#  {'object': [{'name': 'face',
#     'xmin': 580,
#     'ymin': 224,
#     'xmax': 668,
#     'ymax': 356},
#    {'name': 'face', 'xmin': 330, 'ymin': 206, 'xmax': 392, 'ymax': 292},
#    {'name': 'face', 'xmin': 36, 'ymin': 196, 'xmax': 160, 'ymax': 378}],
#   'folder': 'wider_face/data/WIDER_train/images/53--Raid',
#   'filename': 'wider_face/data/WIDER_train/images/53--Raid/53_Raid_policeraid_53_250.jpg',
#   'width': 1024,
#   'height': 768},
#  {'object': [{'name': 'face',
#     'xmin': 245,
#     'ymin': 114,
#     'xmax': 300,
#     'ymax': 195},
#    {'name': 'face', 'xmin': 339, 'ymin': 180, 'xmax': 375, 'ymax': 236},
#    {'name': 'face', 'xmin': 151, 'ymin': 230, 'xmax': 188, 'ymax': 284},
#    {'name': 'face', 'xmin': 536, 'ymin': 150, 'xmax': 641, 'ymax': 289},
#    {'name': 'face', 'xmin': 642, 'ymin': 236, 'xmax': 671, 'ymax': 277}],
#   'folder': 'wider_face/data/WIDER_train/images/4--Dancing',
#   'filename': 'wider_face/data/WIDER_train/images/4--Dancing/4_Dancing_Dancing_4_120.jpg',
#   'width': 1024,
#   'height': 1114},
#  {'object': [{'name': 'face',
#     'xmin': 75,
#     'ymin': 219,
#     'xmax': 119,
#     'ymax': 274},
#    {'name': 'face', 'xmin': 348, 'ymin': 213, 'xmax': 389, 'ymax': 261},
#    {'name': 'face', 'xmin': 849, 'ymin': 210, 'xmax': 894, 'ymax': 265},
#    {'name': 'face', 'xmin': 392, 'ymin': 45, 'xmax': 425, 'ymax': 79}],
#   'folder': 'wider_face/data/WIDER_train/images/54--Rescue',
#   'filename': 'wider_face/data/WIDER_train/images/54--Rescue/54_Rescue_rescuepeople_54_844.jpg',
#   'width': 1024,
#   'height': 670},
#  {'object': [{'name': 'face',
#     'xmin': 391,
#     'ymin': 57,
#     'xmax': 400,
#     'ymax': 68},
#    {'name': 'face', 'xmin': 499, 'ymin': 123, 'xmax': 508, 'ymax': 133},
#    {'name': 'face', 'xmin': 552, 'ymin': 131, 'xmax': 561, 'ymax': 141},
#    {'name': 'face', 'xmin': 677, 'ymin': 173, 'xmax': 684, 'ymax': 180},
#    {'name': 'face', 'xmin': 564, 'ymin': 71, 'xmax': 571, 'ymax': 77},
#    {'name': 'face', 'xmin': 610, 'ymin': 61, 'xmax': 618, 'ymax': 71},
#    {'name': 'face', 'xmin': 527, 'ymin': 75, 'xmax': 533, 'ymax': 80},
#    {'name': 'face', 'xmin': 430, 'ymin': 55, 'xmax': 439, 'ymax': 66},
#    {'name': 'face', 'xmin': 472, 'ymin': 45, 'xmax': 478, 'ymax': 52},
#    {'name': 'face', 'xmin': 357, 'ymin': 66, 'xmax': 367, 'ymax': 77},
#    {'name': 'face', 'xmin': 387, 'ymin': 33, 'xmax': 396, 'ymax': 41},
#    {'name': 'face', 'xmin': 419, 'ymin': 48, 'xmax': 426, 'ymax': 55},
#    {'name': 'face', 'xmin': 446, 'ymin': 36, 'xmax': 451, 'ymax': 43},
#    {'name': 'face', 'xmin': 29, 'ymin': 303, 'xmax': 46, 'ymax': 321},
#    {'name': 'face', 'xmin': 122, 'ymin': 321, 'xmax': 138, 'ymax': 345},
#    {'name': 'face', 'xmin': 171, 'ymin': 314, 'xmax': 185, 'ymax': 329},
#    {'name': 'face', 'xmin': 197, 'ymin': 286, 'xmax': 211, 'ymax': 306},
#    {'name': 'face', 'xmin': 239, 'ymin': 308, 'xmax': 256, 'ymax': 334},
#    {'name': 'face', 'xmin': 259, 'ymin': 283, 'xmax': 271, 'ymax': 298},
#    {'name': 'face', 'xmin': 301, 'ymin': 333, 'xmax': 319, 'ymax': 355},
#    {'name': 'face', 'xmin': 346, 'ymin': 332, 'xmax': 363, 'ymax': 356},
#    {'name': 'face', 'xmin': 323, 'ymin': 291, 'xmax': 336, 'ymax': 304},
#    {'name': 'face', 'xmin': 387, 'ymin': 318, 'xmax': 405, 'ymax': 340},
#    {'name': 'face', 'xmin': 415, 'ymin': 269, 'xmax': 429, 'ymax': 277},
#    {'name': 'face', 'xmin': 415, 'ymin': 313, 'xmax': 428, 'ymax': 325},
#    {'name': 'face', 'xmin': 441, 'ymin': 320, 'xmax': 457, 'ymax': 334},
#    {'name': 'face', 'xmin': 485, 'ymin': 302, 'xmax': 505, 'ymax': 324},
#    {'name': 'face', 'xmin': 540, 'ymin': 287, 'xmax': 554, 'ymax': 301},
#    {'name': 'face', 'xmin': 552, 'ymin': 304, 'xmax': 574, 'ymax': 324},
#    {'name': 'face', 'xmin': 575, 'ymin': 332, 'xmax': 600, 'ymax': 362},
#    {'name': 'face', 'xmin': 588, 'ymin': 275, 'xmax': 601, 'ymax': 289},
#    {'name': 'face', 'xmin': 607, 'ymin': 318, 'xmax': 621, 'ymax': 330},
#    {'name': 'face', 'xmin': 651, 'ymin': 267, 'xmax': 663, 'ymax': 282},
#    {'name': 'face', 'xmin': 641, 'ymin': 301, 'xmax': 661, 'ymax': 328},
#    {'name': 'face', 'xmin': 697, 'ymin': 222, 'xmax': 703, 'ymax': 228},
#    {'name': 'face', 'xmin': 722, 'ymin': 245, 'xmax': 731, 'ymax': 252},
#    {'name': 'face', 'xmin': 748, 'ymin': 265, 'xmax': 759, 'ymax': 279},
#    {'name': 'face', 'xmin': 934, 'ymin': 262, 'xmax': 945, 'ymax': 271},
#    {'name': 'face', 'xmin': 984, 'ymin': 253, 'xmax': 995, 'ymax': 264},
#    {'name': 'face', 'xmin': 925, 'ymin': 305, 'xmax': 938, 'ymax': 319},
#    {'name': 'face', 'xmin': 951, 'ymin': 295, 'xmax': 971, 'ymax': 323},
#    {'name': 'face', 'xmin': 964, 'ymin': 333, 'xmax': 979, 'ymax': 355},
#    {'name': 'face', 'xmin': 781, 'ymin': 289, 'xmax': 789, 'ymax': 297},
#    {'name': 'face', 'xmin': 787, 'ymin': 281, 'xmax': 794, 'ymax': 287},
#    {'name': 'face', 'xmin': 1013, 'ymin': 304, 'xmax': 1024, 'ymax': 332},
#    {'name': 'face', 'xmin': 1000, 'ymin': 290, 'xmax': 1012, 'ymax': 299},
#    {'name': 'face', 'xmin': 1009, 'ymin': 271, 'xmax': 1018, 'ymax': 280},
#    {'name': 'face', 'xmin': 48, 'ymin': 307, 'xmax': 55, 'ymax': 315},
#    {'name': 'face', 'xmin': 293, 'ymin': 312, 'xmax': 306, 'ymax': 325},
#    {'name': 'face', 'xmin': 310, 'ymin': 302, 'xmax': 326, 'ymax': 318},
#    {'name': 'face', 'xmin': 510, 'ymin': 304, 'xmax': 524, 'ymax': 316},
#    {'name': 'face', 'xmin': 492, 'ymin': 275, 'xmax': 498, 'ymax': 283},
#    {'name': 'face', 'xmin': 562, 'ymin': 256, 'xmax': 573, 'ymax': 271},
#    {'name': 'face', 'xmin': 668, 'ymin': 312, 'xmax': 682, 'ymax': 332},
#    {'name': 'face', 'xmin': 711, 'ymin': 293, 'xmax': 725, 'ymax': 304},
#    {'name': 'face', 'xmin': 789, 'ymin': 265, 'xmax': 796, 'ymax': 273},
#    {'name': 'face', 'xmin': 805, 'ymin': 252, 'xmax': 814, 'ymax': 261},
#    {'name': 'face', 'xmin': 969, 'ymin': 278, 'xmax': 976, 'ymax': 286},
#    {'name': 'face', 'xmin': 916, 'ymin': 267, 'xmax': 923, 'ymax': 274},
#    {'name': 'face', 'xmin': 900, 'ymin': 293, 'xmax': 907, 'ymax': 301},
#    {'name': 'face', 'xmin': 350, 'ymin': 29, 'xmax': 358, 'ymax': 41},
#    {'name': 'face', 'xmin': 419, 'ymin': 80, 'xmax': 427, 'ymax': 90},
#    {'name': 'face', 'xmin': 464, 'ymin': 82, 'xmax': 471, 'ymax': 89},
#    {'name': 'face', 'xmin': 502, 'ymin': 107, 'xmax': 511, 'ymax': 115},
#    {'name': 'face', 'xmin': 556, 'ymin': 118, 'xmax': 564, 'ymax': 125},
#    {'name': 'face', 'xmin': 570, 'ymin': 83, 'xmax': 580, 'ymax': 92},
#    {'name': 'face', 'xmin': 668, 'ymin': 162, 'xmax': 675, 'ymax': 176},
#    {'name': 'face', 'xmin': 627, 'ymin': 82, 'xmax': 634, 'ymax': 92},
#    {'name': 'face', 'xmin': 746, 'ymin': 289, 'xmax': 758, 'ymax': 305},
#    {'name': 'face', 'xmin': 756, 'ymin': 295, 'xmax': 766, 'ymax': 313}],
#   'folder': 'wider_face/data/WIDER_train/images/2--Demonstration',
#   'filename': 'wider_face/data/WIDER_train/images/2--Demonstration/2_Demonstration_Demonstration_Or_Protest_2_189.jpg',
#   'width': 1024,
#   'height': 577},
#  {'object': [{'name': 'face',
#     'xmin': 405,
#     'ymin': 201,
#     'xmax': 519,
#     'ymax': 366}],
#   'folder': 'wider_face/data/WIDER_train/images/39--Ice_Skating',
#   'filename': 'wider_face/data/WIDER_train/images/39--Ice_Skating/39_Ice_Skating_Ice_Skating_39_1.jpg',
#   'width': 1024,
#   'height': 1536},
#  {'object': [{'name': 'face',
#     'xmin': 204,
#     'ymin': 277,
#     'xmax': 311,
#     'ymax': 405},
#    {'name': 'face', 'xmin': 80, 'ymin': 159, 'xmax': 122, 'ymax': 224},
#    {'name': 'face', 'xmin': 160, 'ymin': 220, 'xmax': 209, 'ymax': 285},
#    {'name': 'face', 'xmin': 293, 'ymin': 210, 'xmax': 341, 'ymax': 272},
#    {'name': 'face', 'xmin': 398, 'ymin': 228, 'xmax': 450, 'ymax': 292},
#    {'name': 'face', 'xmin': 511, 'ymin': 260, 'xmax': 611, 'ymax': 398},
#    {'name': 'face', 'xmin': 669, 'ymin': 238, 'xmax': 753, 'ymax': 380}],
#   'folder': 'wider_face/data/WIDER_train/images/10--People_Marching',
#   'filename': 'wider_face/data/WIDER_train/images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_101.jpg',
#   'width': 1024,
#   'height': 683},
#  {'object': [{'name': 'face',
#     'xmin': 300,
#     'ymin': 64,
#     'xmax': 426,
#     'ymax': 248}],
#   'folder': 'wider_face/data/WIDER_train/images/34--Baseball',
#   'filename': 'wider_face/data/WIDER_train/images/34--Baseball/34_Baseball_Baseball_34_482.jpg',
#   'width': 1024,
#   'height': 653},
#  {'object': [{'name': 'face',
#     'xmin': 412,
#     'ymin': 111,
#     'xmax': 425,
#     'ymax': 136},
#    {'name': 'face', 'xmin': 814, 'ymin': 162, 'xmax': 835, 'ymax': 184},
#    {'name': 'face', 'xmin': 890, 'ymin': 227, 'xmax': 898, 'ymax': 236},
#    {'name': 'face', 'xmin': 784, 'ymin': 170, 'xmax': 798, 'ymax': 190},
#    {'name': 'face', 'xmin': 724, 'ymin': 186, 'xmax': 738, 'ymax': 202},
#    {'name': 'face', 'xmin': 759, 'ymin': 181, 'xmax': 769, 'ymax': 189},
#    {'name': 'face', 'xmin': 21, 'ymin': 137, 'xmax': 28, 'ymax': 146}],
#   'folder': 'wider_face/data/WIDER_train/images/42--Car_Racing',
#   'filename': 'wider_face/data/WIDER_train/images/42--Car_Racing/42_Car_Racing_Car_Racing_42_37.jpg',
#   'width': 1024,
#   'height': 680},
#  {'object': [{'name': 'face',
#     'xmin': 58,
#     'ymin': 148,
#     'xmax': 148,
#     'ymax': 268},
#    {'name': 'face', 'xmin': 442, 'ymin': 152, 'xmax': 536, 'ymax': 320}],
#   'folder': 'wider_face/data/WIDER_train/images/18--Concerts',
#   'filename': 'wider_face/data/WIDER_train/images/18--Concerts/18_Concerts_Concerts_18_270.jpg',
#   'width': 1024,
#   'height': 688},
#  {'object': [{'name': 'face',
#     'xmin': 738,
#     'ymin': 228,
#     'xmax': 794,
#     'ymax': 306}],
#   'folder': 'wider_face/data/WIDER_train/images/32--Worker_Laborer',
#   'filename': 'wider_face/data/WIDER_train/images/32--Worker_Laborer/32_Worker_Laborer_Worker_Laborer_32_479.jpg',
#   'width': 1024,
#   'height': 685},
#  {'object': [{'name': 'face',
#     'xmin': 310,
#     'ymin': 274,
#     'xmax': 408,
#     'ymax': 396},
#    {'name': 'face', 'xmin': 472, 'ymin': 246, 'xmax': 554, 'ymax': 344},
#    {'name': 'face', 'xmin': 606, 'ymin': 266, 'xmax': 696, 'ymax': 374}],
#   'folder': 'wider_face/data/WIDER_train/images/11--Meeting',
#   'filename': 'wider_face/data/WIDER_train/images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_893.jpg',
#   'width': 1024,
#   'height': 767},
#  {'object': [{'name': 'face',
#     'xmin': 798,
#     'ymin': 112,
#     'xmax': 850,
#     'ymax': 178},
#    {'name': 'face', 'xmin': 653, 'ymin': 108, 'xmax': 705, 'ymax': 171},
#    {'name': 'face', 'xmin': 505, 'ymin': 95, 'xmax': 557, 'ymax': 162},
#    {'name': 'face', 'xmin': 328, 'ymin': 90, 'xmax': 387, 'ymax': 163},
#    {'name': 'face', 'xmin': 196, 'ymin': 99, 'xmax': 261, 'ymax': 167},
#    {'name': 'face', 'xmin': 957, 'ymin': 184, 'xmax': 977, 'ymax': 210},
#    {'name': 'face', 'xmin': 914, 'ymin': 336, 'xmax': 950, 'ymax': 402},
#    {'name': 'face', 'xmin': 1003, 'ymin': 225, 'xmax': 1016, 'ymax': 251},
#    {'name': 'face', 'xmin': 82, 'ymin': 132, 'xmax': 95, 'ymax': 148},
#    {'name': 'face', 'xmin': 37, 'ymin': 162, 'xmax': 50, 'ymax': 178},
#    {'name': 'face', 'xmin': 14, 'ymin': 173, 'xmax': 25, 'ymax': 184},
#    {'name': 'face', 'xmin': 59, 'ymin': 184, 'xmax': 71, 'ymax': 197}],
#   'folder': 'wider_face/data/WIDER_train/images/0--Parade',
#   'filename': 'wider_face/data/WIDER_train/images/0--Parade/0_Parade_Parade_0_253.jpg',
#   'width': 1024,
#   'height': 847},
#  {'object': [{'name': 'face',
#     'xmin': 609,
#     'ymin': 839,
#     'xmax': 872,
#     'ymax': 1155},
#    {'name': 'face', 'xmin': 513, 'ymin': 513, 'xmax': 685, 'ymax': 784},
#    {'name': 'face', 'xmin': 46, 'ymin': 652, 'xmax': 231, 'ymax': 910},
#    {'name': 'face', 'xmin': 169, 'ymin': 417, 'xmax': 323, 'ymax': 624},
#    {'name': 'face', 'xmin': 321, 'ymin': 253, 'xmax': 440, 'ymax': 415},
#    {'name': 'face', 'xmin': 685, 'ymin': 346, 'xmax': 829, 'ymax': 576},
#    {'name': 'face', 'xmin': 731, 'ymin': 233, 'xmax': 865, 'ymax': 367},
#    {'name': 'face', 'xmin': 465, 'ymin': 91, 'xmax': 581, 'ymax': 245},
#    {'name': 'face', 'xmin': 579, 'ymin': 185, 'xmax': 680, 'ymax': 311},
#    {'name': 'face', 'xmin': 162, 'ymin': 139, 'xmax': 271, 'ymax': 291},
#    {'name': 'face', 'xmin': 354, 'ymin': 66, 'xmax': 442, 'ymax': 170}],
#   'folder': 'wider_face/data/WIDER_train/images/29--Students_Schoolkids',
#   'filename': 'wider_face/data/WIDER_train/images/29--Students_Schoolkids/29_Students_Schoolkids_Students_Schoolkids_29_175.jpg',
#   'width': 1024,
#   'height': 1296},
#  {'object': [{'name': 'face',
#     'xmin': 230,
#     'ymin': 230,
#     'xmax': 640,
#     'ymax': 796}],
#   'folder': 'wider_face/data/WIDER_train/images/16--Award_Ceremony',
#   'filename': 'wider_face/data/WIDER_train/images/16--Award_Ceremony/16_Award_Ceremony_Awards_Ceremony_16_520.jpg',
#   'width': 1024,
#   'height': 1294},
#  {'object': [{'name': 'face',
#     'xmin': 433,
#     'ymin': 97,
#     'xmax': 492,
#     'ymax': 138},
#    {'name': 'face', 'xmin': 274, 'ymin': 217, 'xmax': 319, 'ymax': 274},
#    {'name': 'face', 'xmin': 80, 'ymin': 0, 'xmax': 175, 'ymax': 101},
#    {'name': 'face', 'xmin': 784, 'ymin': 128, 'xmax': 819, 'ymax': 173},
#    {'name': 'face', 'xmin': 896, 'ymin': 83, 'xmax': 943, 'ymax': 147},
#    {'name': 'face', 'xmin': 965, 'ymin': 85, 'xmax': 1024, 'ymax': 217},
#    {'name': 'face', 'xmin': 854, 'ymin': 133, 'xmax': 888, 'ymax': 176},
#    {'name': 'face', 'xmin': 541, 'ymin': 238, 'xmax': 577, 'ymax': 291},
#    {'name': 'face', 'xmin': 385, 'ymin': 363, 'xmax': 428, 'ymax': 389},
#    {'name': 'face', 'xmin': 706, 'ymin': 522, 'xmax': 772, 'ymax': 575},
#    {'name': 'face', 'xmin': 600, 'ymin': 345, 'xmax': 653, 'ymax': 388},
#    {'name': 'face', 'xmin': 217, 'ymin': 32, 'xmax': 231, 'ymax': 49}],
#   'folder': 'wider_face/data/WIDER_train/images/6--Funeral',
#   'filename': 'wider_face/data/WIDER_train/images/6--Funeral/6_Funeral_Funeral_6_620.jpg',
#   'width': 1024,
#   'height': 773},
#  {'object': [{'name': 'face',
#     'xmin': 321,
#     'ymin': 199,
#     'xmax': 467,
#     'ymax': 388},
#    {'name': 'face', 'xmin': 672, 'ymin': 282, 'xmax': 784, 'ymax': 447},
#    {'name': 'face', 'xmin': 868, 'ymin': 359, 'xmax': 945, 'ymax': 455},
#    {'name': 'face', 'xmin': 883, 'ymin': 278, 'xmax': 957, 'ymax': 371}],
#   'folder': 'wider_face/data/WIDER_train/images/2--Demonstration',
#   'filename': 'wider_face/data/WIDER_train/images/2--Demonstration/2_Demonstration_Political_Rally_2_512.jpg',
#   'width': 1024,
#   'height': 1225},
#  {'object': [{'name': 'face',
#     'xmin': 387,
#     'ymin': 401,
#     'xmax': 440,
#     'ymax': 498}],
#   'folder': 'wider_face/data/WIDER_train/images/33--Running',
#   'filename': 'wider_face/data/WIDER_train/images/33--Running/33_Running_Running_33_378.jpg',
#   'width': 1024,
#   'height': 1509},
#  {'object': [{'name': 'face',
#     'xmin': 378,
#     'ymin': 302,
#     'xmax': 393,
#     'ymax': 319},
#    {'name': 'face', 'xmin': 403, 'ymin': 305, 'xmax': 421, 'ymax': 326},
#    {'name': 'face', 'xmin': 430, 'ymin': 300, 'xmax': 449, 'ymax': 324},
#    {'name': 'face', 'xmin': 381, 'ymin': 318, 'xmax': 401, 'ymax': 344},
#    {'name': 'face', 'xmin': 361, 'ymin': 331, 'xmax': 381, 'ymax': 356},
#    {'name': 'face', 'xmin': 488, 'ymin': 293, 'xmax': 507, 'ymax': 319},
#    {'name': 'face', 'xmin': 510, 'ymin': 295, 'xmax': 525, 'ymax': 319},
#    {'name': 'face', 'xmin': 548, 'ymin': 297, 'xmax': 577, 'ymax': 335},
#    {'name': 'face', 'xmin': 511, 'ymin': 323, 'xmax': 563, 'ymax': 382},
#    {'name': 'face', 'xmin': 617, 'ymin': 325, 'xmax': 645, 'ymax': 370},
#    {'name': 'face', 'xmin': 626, 'ymin': 298, 'xmax': 649, 'ymax': 325},
#    {'name': 'face', 'xmin': 713, 'ymin': 334, 'xmax': 746, 'ymax': 372},
#    {'name': 'face', 'xmin': 790, 'ymin': 377, 'xmax': 833, 'ymax': 426},
#    {'name': 'face', 'xmin': 851, 'ymin': 335, 'xmax': 879, 'ymax': 370},
#    {'name': 'face', 'xmin': 840, 'ymin': 389, 'xmax': 870, 'ymax': 427},
#    {'name': 'face', 'xmin': 962, 'ymin': 356, 'xmax': 1010, 'ymax': 424},
#    {'name': 'face', 'xmin': 993, 'ymin': 318, 'xmax': 1023, 'ymax': 361},
#    {'name': 'face', 'xmin': 175, 'ymin': 150, 'xmax': 195, 'ymax': 170}],
#   'folder': 'wider_face/data/WIDER_train/images/23--Shoppers',
#   'filename': 'wider_face/data/WIDER_train/images/23--Shoppers/23_Shoppers_Shoppers_23_68.jpg',
#   'width': 1024,
#   'height': 748},
#  {'object': [{'name': 'face',
#     'xmin': 586,
#     'ymin': 73,
#     'xmax': 746,
#     'ymax': 317},
#    {'name': 'face', 'xmin': 389, 'ymin': 232, 'xmax': 578, 'ymax': 397}],
#   'folder': 'wider_face/data/WIDER_train/images/19--Couple',
#   'filename': 'wider_face/data/WIDER_train/images/19--Couple/19_Couple_Couple_19_340.jpg',
#   'width': 1024,
#   'height': 1486},
#  {'object': [{'name': 'face',
#     'xmin': 438,
#     'ymin': 42,
#     'xmax': 550,
#     'ymax': 210}],
#   'folder': 'wider_face/data/WIDER_train/images/56--Voter',
#   'filename': 'wider_face/data/WIDER_train/images/56--Voter/56_Voter_peoplevoting_56_226.jpg',
#   'width': 1024,
#   'height': 579},
#  {'object': [{'name': 'face',
#     'xmin': 429,
#     'ymin': 49,
#     'xmax': 476,
#     'ymax': 108},
#    {'name': 'face', 'xmin': 360, 'ymin': 89, 'xmax': 407, 'ymax': 144},
#    {'name': 'face', 'xmin': 161, 'ymin': 139, 'xmax': 205, 'ymax': 202},
#    {'name': 'face', 'xmin': 119, 'ymin': 260, 'xmax': 170, 'ymax': 330}],
#   'folder': 'wider_face/data/WIDER_train/images/6--Funeral',
#   'filename': 'wider_face/data/WIDER_train/images/6--Funeral/6_Funeral_Funeral_6_146.jpg',
#   'width': 1024,
#   'height': 577},
#  {'object': [{'name': 'face',
#     'xmin': 620,
#     'ymin': 200,
#     'xmax': 647,
#     'ymax': 231},
#    {'name': 'face', 'xmin': 551, 'ymin': 196, 'xmax': 578, 'ymax': 224},
#    {'name': 'face', 'xmin': 492, 'ymin': 202, 'xmax': 522, 'ymax': 236},
#    {'name': 'face', 'xmin': 421, 'ymin': 207, 'xmax': 453, 'ymax': 249},
#    {'name': 'face', 'xmin': 445, 'ymin': 195, 'xmax': 472, 'ymax': 226},
#    {'name': 'face', 'xmin': 509, 'ymin': 175, 'xmax': 517, 'ymax': 186},
#    {'name': 'face', 'xmin': 3, 'ymin': 164, 'xmax': 21, 'ymax': 184}],
#   'folder': 'wider_face/data/WIDER_train/images/29--Students_Schoolkids',
#   'filename': 'wider_face/data/WIDER_train/images/29--Students_Schoolkids/29_Students_Schoolkids_Students_Schoolkids_29_820.jpg',
#   'width': 1024,
#   'height': 576},
#  {'object': [{'name': 'face',
#     'xmin': 530,
#     'ymin': 180,
#     'xmax': 658,
#     'ymax': 402},
#    {'name': 'face', 'xmin': 38, 'ymin': 4, 'xmax': 180, 'ymax': 154},
#    {'name': 'face', 'xmin': 750, 'ymin': 2, 'xmax': 858, 'ymax': 104}],
#   'folder': 'wider_face/data/WIDER_train/images/8--Election_Campain',
#   'filename': 'wider_face/data/WIDER_train/images/8--Election_Campain/8_Election_Campain_Election_Campaign_8_215.jpg',
#   'width': 1024,
#   'height': 682},
#  {'object': [{'name': 'face',
#     'xmin': 540,
#     'ymin': 38,
#     'xmax': 642,
#     'ymax': 158}],
#   'folder': 'wider_face/data/WIDER_train/images/55--Sports_Coach_Trainer',
#   'filename': 'wider_face/data/WIDER_train/images/55--Sports_Coach_Trainer/55_Sports_Coach_Trainer_sportcoaching_55_753.jpg',
#   'width': 1024,
#   'height': 576},
#  {'object': [{'name': 'face',
#     'xmin': 76,
#     'ymin': 46,
#     'xmax': 166,
#     'ymax': 118},
#    {'name': 'face', 'xmin': 738, 'ymin': 488, 'xmax': 832, 'ymax': 576}],
#   'folder': 'wider_face/data/WIDER_train/images/39--Ice_Skating',
#   'filename': 'wider_face/data/WIDER_train/images/39--Ice_Skating/39_Ice_Skating_Ice_Skating_39_212.jpg',
#   'width': 1024,
#   'height': 768},
#  {'object': [{'name': 'face',
#     'xmin': 167,
#     'ymin': 107,
#     'xmax': 217,
#     'ymax': 173},
#    {'name': 'face', 'xmin': 277, 'ymin': 115, 'xmax': 320, 'ymax': 176},
#    {'name': 'face', 'xmin': 439, 'ymin': 150, 'xmax': 479, 'ymax': 199},
#    {'name': 'face', 'xmin': 557, 'ymin': 131, 'xmax': 599, 'ymax': 184},
#    {'name': 'face', 'xmin': 703, 'ymin': 125, 'xmax': 746, 'ymax': 178},
#    {'name': 'face', 'xmin': 874, 'ymin': 94, 'xmax': 922, 'ymax': 155}],
#   'folder': 'wider_face/data/WIDER_train/images/16--Award_Ceremony',
#   'filename': 'wider_face/data/WIDER_train/images/16--Award_Ceremony/16_Award_Ceremony_Awards_Ceremony_16_246.jpg',
#   'width': 1024,
#   'height': 680},
#  {'object': [{'name': 'face',
#     'xmin': 439,
#     'ymin': 319,
#     'xmax': 681,
#     'ymax': 650}],
#   'folder': 'wider_face/data/WIDER_train/images/9--Press_Conference',
#   'filename': 'wider_face/data/WIDER_train/images/9--Press_Conference/9_Press_Conference_Press_Conference_9_301.jpg',
#   'width': 1024,
#   'height': 1530},
#  {'object': [{'name': 'face',
#     'xmin': 562,
#     'ymin': 55,
#     'xmax': 585,
#     'ymax': 84}],
#   'folder': 'wider_face/data/WIDER_train/images/43--Row_Boat',
#   'filename': 'wider_face/data/WIDER_train/images/43--Row_Boat/43_Row_Boat_Rowboat_43_426.jpg',
#   'width': 1024,
#   'height': 451},
#  {'object': [{'name': 'face',
#     'xmin': 272,
#     'ymin': 201,
#     'xmax': 742,
#     'ymax': 819}],
#   'folder': 'wider_face/data/WIDER_train/images/30--Surgeons',
#   'filename': 'wider_face/data/WIDER_train/images/30--Surgeons/30_Surgeons_Surgeons_30_618.jpg',
#   'width': 1024,
#   'height': 1181},
#  {'object': [{'name': 'face',
#     'xmin': 100,
#     'ymin': 323,
#     'xmax': 167,
#     'ymax': 392},
#    {'name': 'face', 'xmin': 195, 'ymin': 307, 'xmax': 215, 'ymax': 330},
#    {'name': 'face', 'xmin': 224, 'ymin': 299, 'xmax': 240, 'ymax': 314},
#    {'name': 'face', 'xmin': 228, 'ymin': 316, 'xmax': 244, 'ymax': 338},
#    {'name': 'face', 'xmin': 262, 'ymin': 311, 'xmax': 280, 'ymax': 340},
#    {'name': 'face', 'xmin': 308, 'ymin': 308, 'xmax': 321, 'ymax': 320},
#    {'name': 'face', 'xmin': 326, 'ymin': 315, 'xmax': 342, 'ymax': 331},
#    {'name': 'face', 'xmin': 341, 'ymin': 307, 'xmax': 355, 'ymax': 323},
#    {'name': 'face', 'xmin': 379, 'ymin': 311, 'xmax': 399, 'ymax': 331},
#    {'name': 'face', 'xmin': 447, 'ymin': 317, 'xmax': 467, 'ymax': 338},
#    {'name': 'face', 'xmin': 482, 'ymin': 327, 'xmax': 503, 'ymax': 351},
#    {'name': 'face', 'xmin': 502, 'ymin': 329, 'xmax': 516, 'ymax': 349},
#    {'name': 'face', 'xmin': 497, 'ymin': 310, 'xmax': 510, 'ymax': 328},
#    {'name': 'face', 'xmin': 532, 'ymin': 314, 'xmax': 546, 'ymax': 329},
#    {'name': 'face', 'xmin': 555, 'ymin': 325, 'xmax': 570, 'ymax': 347},
#    {'name': 'face', 'xmin': 583, 'ymin': 303, 'xmax': 603, 'ymax': 325},
#    {'name': 'face', 'xmin': 664, 'ymin': 303, 'xmax': 680, 'ymax': 330},
#    {'name': 'face', 'xmin': 611, 'ymin': 91, 'xmax': 633, 'ymax': 122},
#    {'name': 'face', 'xmin': 706, 'ymin': 326, 'xmax': 729, 'ymax': 354},
#    {'name': 'face', 'xmin': 691, 'ymin': 303, 'xmax': 710, 'ymax': 326},
#    {'name': 'face', 'xmin': 720, 'ymin': 308, 'xmax': 736, 'ymax': 330},
#    {'name': 'face', 'xmin': 745, 'ymin': 309, 'xmax': 755, 'ymax': 330},
#    {'name': 'face', 'xmin': 768, 'ymin': 284, 'xmax': 796, 'ymax': 316},
#    {'name': 'face', 'xmin': 789, 'ymin': 258, 'xmax': 833, 'ymax': 306},
#    {'name': 'face', 'xmin': 903, 'ymin': 319, 'xmax': 916, 'ymax': 340},
#    {'name': 'face', 'xmin': 968, 'ymin': 296, 'xmax': 992, 'ymax': 325},
#    {'name': 'face', 'xmin': 961, 'ymin': 274, 'xmax': 986, 'ymax': 310},
#    {'name': 'face', 'xmin': 613, 'ymin': 298, 'xmax': 627, 'ymax': 316},
#    {'name': 'face', 'xmin': 643, 'ymin': 300, 'xmax': 661, 'ymax': 323},
#    {'name': 'face', 'xmin': 419, 'ymin': 305, 'xmax': 430, 'ymax': 320}],
#   'folder': 'wider_face/data/WIDER_train/images/2--Demonstration',
#   'filename': 'wider_face/data/WIDER_train/images/2--Demonstration/2_Demonstration_Demonstrators_2_439.jpg',
#   'width': 1024,
#   'height': 668},
#  {'object': [{'name': 'face', 'xmin': 119, 'ymin': 4, 'xmax': 151, 'ymax': 42},
#    {'name': 'face', 'xmin': 30, 'ymin': 15, 'xmax': 39, 'ymax': 25},
#    {'name': 'face', 'xmin': 45, 'ymin': 20, 'xmax': 56, 'ymax': 29},
#    {'name': 'face', 'xmin': 360, 'ymin': 793, 'xmax': 368, 'ymax': 802},
#    {'name': 'face', 'xmin': 442, 'ymin': 860, 'xmax': 456, 'ymax': 876},
#    {'name': 'face', 'xmin': 607, 'ymin': 866, 'xmax': 618, 'ymax': 883}],
#   'folder': 'wider_face/data/WIDER_train/images/39--Ice_Skating',
#   'filename': 'wider_face/data/WIDER_train/images/39--Ice_Skating/39_Ice_Skating_iceskiing_39_113.jpg',
#   'width': 1024,
#   'height': 1024},
#  {'object': [{'name': 'face',
#     'xmin': 312,
#     'ymin': 524,
#     'xmax': 369,
#     'ymax': 595}],
#   'folder': 'wider_face/data/WIDER_train/images/35--Basketball',
#   'filename': 'wider_face/data/WIDER_train/images/35--Basketball/35_Basketball_playingbasketball_35_32.jpg',
#   'width': 1024,
#   'height': 1392},
#  {'object': [{'name': 'face',
#     'xmin': 627,
#     'ymin': 422,
#     'xmax': 655,
#     'ymax': 457}],
#   'folder': 'wider_face/data/WIDER_train/images/10--People_Marching',
#   'filename': 'wider_face/data/WIDER_train/images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_840.jpg',
#   'width': 1024,
#   'height': 772},
#  {'object': [{'name': 'face',
#     'xmin': 470,
#     'ymin': 247,
#     'xmax': 575,
#     'ymax': 389}],
#   'folder': 'wider_face/data/WIDER_train/images/6--Funeral',
#   'filename': 'wider_face/data/WIDER_train/images/6--Funeral/6_Funeral_Funeral_6_634.jpg',
#   'width': 1024,
#   'height': 1543},
#  {'object': [{'name': 'face',
#     'xmin': 937,
#     'ymin': 329,
#     'xmax': 1014,
#     'ymax': 428},
#    {'name': 'face', 'xmin': 918, 'ymin': 382, 'xmax': 959, 'ymax': 457},
#    {'name': 'face', 'xmin': 778, 'ymin': 365, 'xmax': 848, 'ymax': 435},
#    {'name': 'face', 'xmin': 876, 'ymin': 267, 'xmax': 916, 'ymax': 321},
#    {'name': 'face', 'xmin': 752, 'ymin': 269, 'xmax': 805, 'ymax': 333},
#    {'name': 'face', 'xmin': 843, 'ymin': 246, 'xmax': 864, 'ymax': 275},
#    {'name': 'face', 'xmin': 742, 'ymin': 258, 'xmax': 761, 'ymax': 283},
#    {'name': 'face', 'xmin': 739, 'ymin': 238, 'xmax': 752, 'ymax': 251},
#    {'name': 'face', 'xmin': 950, 'ymin': 222, 'xmax': 957, 'ymax': 231},
#    {'name': 'face', 'xmin': 920, 'ymin': 302, 'xmax': 965, 'ymax': 376},
#    {'name': 'face', 'xmin': 647, 'ymin': 300, 'xmax': 695, 'ymax': 378},
#    {'name': 'face', 'xmin': 606, 'ymin': 274, 'xmax': 656, 'ymax': 344},
#    {'name': 'face', 'xmin': 548, 'ymin': 342, 'xmax': 597, 'ymax': 402},
#    {'name': 'face', 'xmin': 549, 'ymin': 297, 'xmax': 593, 'ymax': 343},
#    {'name': 'face', 'xmin': 484, 'ymin': 393, 'xmax': 537, 'ymax': 458},
#    {'name': 'face', 'xmin': 527, 'ymin': 295, 'xmax': 555, 'ymax': 344},
#    {'name': 'face', 'xmin': 497, 'ymin': 291, 'xmax': 529, 'ymax': 338},
#    {'name': 'face', 'xmin': 441, 'ymin': 295, 'xmax': 489, 'ymax': 358},
#    {'name': 'face', 'xmin': 509, 'ymin': 240, 'xmax': 523, 'ymax': 258},
#    {'name': 'face', 'xmin': 399, 'ymin': 347, 'xmax': 436, 'ymax': 399},
#    {'name': 'face', 'xmin': 337, 'ymin': 318, 'xmax': 388, 'ymax': 385},
#    {'name': 'face', 'xmin': 326, 'ymin': 282, 'xmax': 362, 'ymax': 333},
#    {'name': 'face', 'xmin': 363, 'ymin': 255, 'xmax': 392, 'ymax': 291},
#    {'name': 'face', 'xmin': 432, 'ymin': 275, 'xmax': 448, 'ymax': 309},
#    {'name': 'face', 'xmin': 271, 'ymin': 282, 'xmax': 315, 'ymax': 338},
#    {'name': 'face', 'xmin': 195, 'ymin': 313, 'xmax': 249, 'ymax': 373},
#    {'name': 'face', 'xmin': 159, 'ymin': 299, 'xmax': 197, 'ymax': 350},
#    {'name': 'face', 'xmin': 47, 'ymin': 333, 'xmax': 107, 'ymax': 401},
#    {'name': 'face', 'xmin': 109, 'ymin': 320, 'xmax': 146, 'ymax': 363},
#    {'name': 'face', 'xmin': 198, 'ymin': 254, 'xmax': 231, 'ymax': 290},
#    {'name': 'face', 'xmin': 75, 'ymin': 233, 'xmax': 108, 'ymax': 261},
#    {'name': 'face', 'xmin': 26, 'ymin': 278, 'xmax': 73, 'ymax': 337},
#    {'name': 'face', 'xmin': 1, 'ymin': 404, 'xmax': 70, 'ymax': 493},
#    {'name': 'face', 'xmin': 151, 'ymin': 245, 'xmax': 164, 'ymax': 259},
# ...
#   'width': 1024,
#   'height': 768},
#  {'object': [{'name': 'face',
#     'xmin': 53,
#     'ymin': 272,
#     'xmax': 58,
#     'ymax': 278},
#    {'name': 'face', 'xmin': 253, 'ymin': 102, 'xmax': 292, 'ymax': 163},
#    {'name': 'face', 'xmin': 263, 'ymin': 274, 'xmax': 281, 'ymax': 299},
#    {'name': 'face', 'xmin': 714, 'ymin': 82, 'xmax': 772, 'ymax': 154}],
#   'folder': 'wider_face/data/WIDER_train/images/2--Demonstration',
#   'filename': 'wider_face/data/WIDER_train/images/2--Demonstration/2_Demonstration_Demonstration_Or_Protest_2_363.jpg',
#   'width': 1024,
#   'height': 762},
#  {'object': [{'name': 'face',
#     'xmin': 465,
#     'ymin': 338,
#     'xmax': 495,
#     'ymax': 380},
#    {'name': 'face', 'xmin': 520, 'ymin': 368, 'xmax': 554, 'ymax': 409},
#    {'name': 'face', 'xmin': 616, 'ymin': 398, 'xmax': 638, 'ymax': 430},
#    {'name': 'face', 'xmin': 684, 'ymin': 408, 'xmax': 708, 'ymax': 439},
#    {'name': 'face', 'xmin': 744, 'ymin': 436, 'xmax': 760, 'ymax': 460},
#    {'name': 'face', 'xmin': 792, 'ymin': 444, 'xmax': 809, 'ymax': 468},
#    {'name': 'face', 'xmin': 844, 'ymin': 390, 'xmax': 862, 'ymax': 427},
#    {'name': 'face', 'xmin': 978, 'ymin': 462, 'xmax': 1006, 'ymax': 512}],
#   'folder': 'wider_face/data/WIDER_train/images/23--Shoppers',
#   'filename': 'wider_face/data/WIDER_train/images/23--Shoppers/23_Shoppers_Shoppers_23_152.jpg',
#   'width': 1024,
#   'height': 768},
#  {'object': [{'name': 'face',
#     'xmin': 89,
#     'ymin': 108,
#     'xmax': 138,
#     'ymax': 177},
#    {'name': 'face', 'xmin': 280, 'ymin': 134, 'xmax': 314, 'ymax': 165},
#    {'name': 'face', 'xmin': 357, 'ymin': 62, 'xmax': 407, 'ymax': 128},
#    {'name': 'face', 'xmin': 792, 'ymin': 159, 'xmax': 825, 'ymax': 189},
#    {'name': 'face', 'xmin': 971, 'ymin': 114, 'xmax': 1017, 'ymax': 160}],
#   'folder': 'wider_face/data/WIDER_train/images/36--Football',
#   'filename': 'wider_face/data/WIDER_train/images/36--Football/36_Football_americanfootball_ball_36_851.jpg',
#   'width': 1024,
#   'height': 683},
#  {'object': [{'name': 'face',
#     'xmin': 236,
#     'ymin': 304,
#     'xmax': 298,
#     'ymax': 384}],
#   'folder': 'wider_face/data/WIDER_train/images/48--Parachutist_Paratrooper',
#   'filename': 'wider_face/data/WIDER_train/images/48--Parachutist_Paratrooper/48_Parachutist_Paratrooper_Parachutist_Paratrooper_48_146.jpg',
#   'width': 1024,
#   'height': 679},
#  {'object': [{'name': 'face',
#     'xmin': 418,
#     'ymin': 269,
#     'xmax': 654,
#     'ymax': 584}],
#   'folder': 'wider_face/data/WIDER_train/images/28--Sports_Fan',
#   'filename': 'wider_face/data/WIDER_train/images/28--Sports_Fan/28_Sports_Fan_Sports_Fan_28_44.jpg',
#   'width': 1024,
#   'height': 1392},
#  {'object': [{'name': 'face',
#     'xmin': 475,
#     'ymin': 354,
#     'xmax': 623,
#     'ymax': 507},
#    {'name': 'face', 'xmin': 124, 'ymin': 419, 'xmax': 269, 'ymax': 575}],
#   'folder': 'wider_face/data/WIDER_train/images/35--Basketball',
#   'filename': 'wider_face/data/WIDER_train/images/35--Basketball/35_Basketball_basketballgame_ball_35_612.jpg',
#   'width': 1024,
#   'height': 1512},
#  {'object': [{'name': 'face',
#     'xmin': 702,
#     'ymin': 116,
#     'xmax': 936,
#     'ymax': 412}],
#   'folder': 'wider_face/data/WIDER_train/images/34--Baseball',
#   'filename': 'wider_face/data/WIDER_train/images/34--Baseball/34_Baseball_Baseball_34_898.jpg',
#   'width': 1024,
#   'height': 640},
#  {'object': [{'name': 'face',
#     'xmin': 109,
#     'ymin': 213,
#     'xmax': 402,
#     'ymax': 594},
#    {'name': 'face', 'xmin': 591, 'ymin': 449, 'xmax': 950, 'ymax': 927},
#    {'name': 'face', 'xmin': 241, 'ymin': 695, 'xmax': 558, 'ymax': 1073}],
#   'folder': 'wider_face/data/WIDER_train/images/33--Running',
#   'filename': 'wider_face/data/WIDER_train/images/33--Running/33_Running_Running_33_637.jpg',
#   'width': 1024,
#   'height': 1212},
#  {'object': [{'name': 'face',
#     'xmin': 580,
#     'ymin': 340,
#     'xmax': 608,
#     'ymax': 399},
#    {'name': 'face', 'xmin': 617, 'ymin': 119, 'xmax': 666, 'ymax': 176}],
#   'folder': 'wider_face/data/WIDER_train/images/34--Baseball',
#   'filename': 'wider_face/data/WIDER_train/images/34--Baseball/34_Baseball_Baseball_34_126.jpg',
#   'width': 1024,
#   'height': 668},
#  {'object': [{'name': 'face',
#     'xmin': 184,
#     'ymin': 275,
#     'xmax': 242,
#     'ymax': 347},
#    {'name': 'face', 'xmin': 656, 'ymin': 291, 'xmax': 712, 'ymax': 368}],
#   'folder': 'wider_face/data/WIDER_train/images/25--Soldier_Patrol',
#   'filename': 'wider_face/data/WIDER_train/images/25--Soldier_Patrol/25_Soldier_Patrol_Soldier_Patrol_25_619.jpg',
#   'width': 1024,
#   'height': 724},
#  {'object': [{'name': 'face',
#     'xmin': 820,
#     'ymin': 203,
#     'xmax': 846,
#     'ymax': 246},
#    {'name': 'face', 'xmin': 410, 'ymin': 111, 'xmax': 450, 'ymax': 169}],
#   'folder': 'wider_face/data/WIDER_train/images/39--Ice_Skating',
#   'filename': 'wider_face/data/WIDER_train/images/39--Ice_Skating/39_Ice_Skating_Ice_Skating_39_985.jpg',
#   'width': 1024,
#   'height': 685},
#  {'object': [{'name': 'face',
#     'xmin': 452,
#     'ymin': 86,
#     'xmax': 654,
#     'ymax': 409}],
#   'folder': 'wider_face/data/WIDER_train/images/12--Group',
#   'filename': 'wider_face/data/WIDER_train/images/12--Group/12_Group_Team_Organized_Group_12_Group_Team_Organized_Group_12_567.jpg',
#   'width': 1024,
#   'height': 1101},
#  {'object': [{'name': 'face',
#     'xmin': 538,
#     'ymin': 158,
#     'xmax': 682,
#     'ymax': 262},
#    {'name': 'face', 'xmin': 734, 'ymin': 340, 'xmax': 868, 'ymax': 412}],
#   'folder': 'wider_face/data/WIDER_train/images/4--Dancing',
#   'filename': 'wider_face/data/WIDER_train/images/4--Dancing/4_Dancing_Dancing_4_484.jpg',
#   'width': 1024,
#   'height': 662},
#  {'object': [{'name': 'face',
#     'xmin': 235,
#     'ymin': 109,
#     'xmax': 525,
#     'ymax': 507}],
#   'folder': 'wider_face/data/WIDER_train/images/16--Award_Ceremony',
#   'filename': 'wider_face/data/WIDER_train/images/16--Award_Ceremony/16_Award_Ceremony_Awards_Ceremony_16_709.jpg',
#   'width': 1024,
#   'height': 1326},
#  {'object': [{'name': 'face',
#     'xmin': 217,
#     'ymin': 146,
#     'xmax': 243,
#     'ymax': 183},
#    {'name': 'face', 'xmin': 798, 'ymin': 192, 'xmax': 829, 'ymax': 228}],
#   'folder': 'wider_face/data/WIDER_train/images/38--Tennis',
#   'filename': 'wider_face/data/WIDER_train/images/38--Tennis/38_Tennis_Tennis_38_224.jpg',
#   'width': 1024,
#   'height': 662},
#  {'object': [{'name': 'face',
#     'xmin': 481,
#     'ymin': 496,
#     'xmax': 628,
#     'ymax': 681}],
#   'folder': 'wider_face/data/WIDER_train/images/32--Worker_Laborer',
#   'filename': 'wider_face/data/WIDER_train/images/32--Worker_Laborer/32_Worker_Laborer_Worker_Laborer_32_863.jpg',
#   'width': 1024,
#   'height': 1504},
#  {'object': [{'name': 'face',
#     'xmin': 338,
#     'ymin': 261,
#     'xmax': 377,
#     'ymax': 307}],
#   'folder': 'wider_face/data/WIDER_train/images/4--Dancing',
#   'filename': 'wider_face/data/WIDER_train/images/4--Dancing/4_Dancing_Dancing_4_490.jpg',
#   'width': 1024,
#   'height': 683},
#  {'object': [{'name': 'face',
#     'xmin': 144,
#     'ymin': 201,
#     'xmax': 209,
#     'ymax': 286},
#    {'name': 'face', 'xmin': 376, 'ymin': 255, 'xmax': 438, 'ymax': 346},
#    {'name': 'face', 'xmin': 464, 'ymin': 320, 'xmax': 535, 'ymax': 411},
#    {'name': 'face', 'xmin': 687, 'ymin': 266, 'xmax': 763, 'ymax': 359},
#    {'name': 'face', 'xmin': 837, 'ymin': 286, 'xmax': 916, 'ymax': 391}],
#   'folder': 'wider_face/data/WIDER_train/images/18--Concerts',
#   'filename': 'wider_face/data/WIDER_train/images/18--Concerts/18_Concerts_Concerts_18_918.jpg',
#   'width': 1024,
#   'height': 1450},
#  {'object': [{'name': 'face',
#     'xmin': 233,
#     'ymin': 646,
#     'xmax': 264,
#     'ymax': 704}],
#   'folder': 'wider_face/data/WIDER_train/images/27--Spa',
#   'filename': 'wider_face/data/WIDER_train/images/27--Spa/27_Spa_Spa_27_260.jpg',
#   'width': 1024,
#   'height': 1200},
#  {'object': [{'name': 'face',
#     'xmin': 100,
#     'ymin': 364,
#     'xmax': 170,
#     'ymax': 446},
#    {'name': 'face', 'xmin': 480, 'ymin': 334, 'xmax': 538, 'ymax': 420},
#    {'name': 'face', 'xmin': 782, 'ymin': 382, 'xmax': 842, 'ymax': 456}],
#   'folder': 'wider_face/data/WIDER_train/images/2--Demonstration',
#   'filename': 'wider_face/data/WIDER_train/images/2--Demonstration/2_Demonstration_Demonstrators_2_610.jpg',
#   'width': 1024,
#   'height': 808},
#  {'object': [{'name': 'face',
#     'xmin': 121,
#     'ymin': 265,
#     'xmax': 142,
#     'ymax': 293},
#    {'name': 'face', 'xmin': 68, 'ymin': 267, 'xmax': 88, 'ymax': 291},
#    {'name': 'face', 'xmin': 16, 'ymin': 266, 'xmax': 33, 'ymax': 285},
#    {'name': 'face', 'xmin': 41, 'ymin': 277, 'xmax': 56, 'ymax': 293},
#    {'name': 'face', 'xmin': 221, 'ymin': 270, 'xmax': 243, 'ymax': 297},
#    {'name': 'face', 'xmin': 256, 'ymin': 265, 'xmax': 267, 'ymax': 279},
#    {'name': 'face', 'xmin': 306, 'ymin': 275, 'xmax': 323, 'ymax': 293},
#    {'name': 'face', 'xmin': 327, 'ymin': 281, 'xmax': 343, 'ymax': 302},
#    {'name': 'face', 'xmin': 359, 'ymin': 279, 'xmax': 382, 'ymax': 307},
#    {'name': 'face', 'xmin': 502, 'ymin': 297, 'xmax': 521, 'ymax': 323},
#    {'name': 'face', 'xmin': 575, 'ymin': 272, 'xmax': 600, 'ymax': 298},
#    {'name': 'face', 'xmin': 612, 'ymin': 245, 'xmax': 640, 'ymax': 278},
#    {'name': 'face', 'xmin': 648, 'ymin': 278, 'xmax': 665, 'ymax': 297},
#    {'name': 'face', 'xmin': 767, 'ymin': 280, 'xmax': 796, 'ymax': 317},
#    {'name': 'face', 'xmin': 816, 'ymin': 281, 'xmax': 838, 'ymax': 310},
#    {'name': 'face', 'xmin': 1007, 'ymin': 273, 'xmax': 1024, 'ymax': 309}],
#   'folder': 'wider_face/data/WIDER_train/images/12--Group',
#   'filename': 'wider_face/data/WIDER_train/images/12--Group/12_Group_Team_Organized_Group_12_Group_Team_Organized_Group_12_215.jpg',
#   'width': 1024,
#   'height': 680},
#  {'object': [{'name': 'face',
#     'xmin': 486,
#     'ymin': 42,
#     'xmax': 546,
#     'ymax': 126}],
#   'folder': 'wider_face/data/WIDER_train/images/40--Gymnastics',
#   'filename': 'wider_face/data/WIDER_train/images/40--Gymnastics/40_Gymnastics_Gymnastics_40_589.jpg',
#   'width': 1024,
#   'height': 645},
#  {'object': [{'name': 'face',
#     'xmin': 506,
#     'ymin': 220,
#     'xmax': 687,
#     'ymax': 443}],
#   'folder': 'wider_face/data/WIDER_train/images/21--Festival',
#   'filename': 'wider_face/data/WIDER_train/images/21--Festival/21_Festival_Festival_21_972.jpg',
#   'width': 1024,
#   'height': 1543},
#  {'object': [{'name': 'face',
#     'xmin': 380,
#     'ymin': 159,
#     'xmax': 620,
#     'ymax': 449}],
#   'folder': 'wider_face/data/WIDER_train/images/18--Concerts',
#   'filename': 'wider_face/data/WIDER_train/images/18--Concerts/18_Concerts_Concerts_18_887.jpg',
#   'width': 1024,
#   'height': 1535},
#  {'object': [{'name': 'face',
#     'xmin': 260,
#     'ymin': 174,
#     'xmax': 338,
#     'ymax': 288},
#    {'name': 'face', 'xmin': 446, 'ymin': 198, 'xmax': 518, 'ymax': 304},
#    {'name': 'face', 'xmin': 574, 'ymin': 294, 'xmax': 672, 'ymax': 422},
#    {'name': 'face', 'xmin': 764, 'ymin': 284, 'xmax': 854, 'ymax': 396}],
#   'folder': 'wider_face/data/WIDER_train/images/40--Gymnastics',
#   'filename': 'wider_face/data/WIDER_train/images/40--Gymnastics/40_Gymnastics_Gymnastics_40_416.jpg',
#   'width': 1024,
#   'height': 768},
#  {'object': [{'name': 'face',
#     'xmin': 189,
#     'ymin': 267,
#     'xmax': 697,
#     'ymax': 937}],
#   'folder': 'wider_face/data/WIDER_train/images/13--Interview',
#   'filename': 'wider_face/data/WIDER_train/images/13--Interview/13_Interview_Interview_Sequences_13_452.jpg',
#   'width': 1024,
#   'height': 1485},
#  {'object': [{'name': 'face',
#     'xmin': 794,
#     'ymin': 338,
#     'xmax': 815,
#     'ymax': 367},
#    {'name': 'face', 'xmin': 765, 'ymin': 240, 'xmax': 793, 'ymax': 272},
#    {'name': 'face', 'xmin': 610, 'ymin': 244, 'xmax': 628, 'ymax': 266},
#    {'name': 'face', 'xmin': 566, 'ymin': 309, 'xmax': 592, 'ymax': 343},
#    {'name': 'face', 'xmin': 385, 'ymin': 320, 'xmax': 410, 'ymax': 351},
#    {'name': 'face', 'xmin': 211, 'ymin': 319, 'xmax': 236, 'ymax': 353},
#    {'name': 'face', 'xmin': 35, 'ymin': 300, 'xmax': 54, 'ymax': 323},
#    {'name': 'face', 'xmin': 108, 'ymin': 284, 'xmax': 124, 'ymax': 305},
#    {'name': 'face', 'xmin': 441, 'ymin': 255, 'xmax': 464, 'ymax': 281},
#    {'name': 'face', 'xmin': 570, 'ymin': 274, 'xmax': 585, 'ymax': 298},
#    {'name': 'face', 'xmin': 427, 'ymin': 272, 'xmax': 441, 'ymax': 288},
#    {'name': 'face', 'xmin': 968, 'ymin': 264, 'xmax': 1006, 'ymax': 301}],
#   'folder': 'wider_face/data/WIDER_train/images/24--Soldier_Firing',
#   'filename': 'wider_face/data/WIDER_train/images/24--Soldier_Firing/24_Soldier_Firing_Soldier_Firing_24_544.jpg',
#   'width': 1024,
#   'height': 682},
#  {'object': [{'name': 'face',
#     'xmin': 439,
#     'ymin': 182,
#     'xmax': 624,
#     'ymax': 436}],
#   'folder': 'wider_face/data/WIDER_train/images/0--Parade',
#   'filename': 'wider_face/data/WIDER_train/images/0--Parade/0_Parade_marchingband_1_873.jpg',
#   'width': 1024,
#   'height': 1413},
#  {'object': [{'name': 'face',
#     'xmin': 526,
#     'ymin': 106,
#     'xmax': 648,
#     'ymax': 312}],
#   'folder': 'wider_face/data/WIDER_train/images/28--Sports_Fan',
#   'filename': 'wider_face/data/WIDER_train/images/28--Sports_Fan/28_Sports_Fan_Sports_Fan_28_177.jpg',
#   'width': 1024,
#   'height': 683},
#  {'object': [{'name': 'face',
#     'xmin': 404,
#     'ymin': 284,
#     'xmax': 560,
#     'ymax': 488}],
#   'folder': 'wider_face/data/WIDER_train/images/41--Swimming',
#   'filename': 'wider_face/data/WIDER_train/images/41--Swimming/41_Swimming_Swimmer_41_182.jpg',
#   'width': 1024,
#   'height': 615},
#  {'object': [{'name': 'face',
#     'xmin': 332,
#     'ymin': 365,
#     'xmax': 374,
#     'ymax': 417},
#    {'name': 'face', 'xmin': 669, 'ymin': 353, 'xmax': 719, 'ymax': 424}],
#   'folder': 'wider_face/data/WIDER_train/images/27--Spa',
#   'filename': 'wider_face/data/WIDER_train/images/27--Spa/27_Spa_Spa_27_29.jpg',
#   'width': 1024,
#   'height': 683},
#  {'object': [{'name': 'face',
#     'xmin': 730,
#     'ymin': 76,
#     'xmax': 884,
#     'ymax': 292}],
#   'folder': 'wider_face/data/WIDER_train/images/13--Interview',
#   'filename': 'wider_face/data/WIDER_train/images/13--Interview/13_Interview_Interview_Sequences_13_334.jpg',
#   'width': 1024,
#   'height': 576},
#  {'object': [{'name': 'face',
#     'xmin': 368,
#     'ymin': 90,
#     'xmax': 444,
#     'ymax': 200},
#    {'name': 'face', 'xmin': 792, 'ymin': 232, 'xmax': 844, 'ymax': 350}],
#   'folder': 'wider_face/data/WIDER_train/images/24--Soldier_Firing',
#   'filename': 'wider_face/data/WIDER_train/images/24--Soldier_Firing/24_Soldier_Firing_Soldier_Firing_24_222.jpg',
#   'width': 1024,
#   'height': 719},
#  {'object': [{'name': 'face',
#     'xmin': 238,
#     'ymin': 250,
#     'xmax': 294,
#     'ymax': 358},
#    {'name': 'face', 'xmin': 296, 'ymin': 268, 'xmax': 358, 'ymax': 364}],
#   'folder': 'wider_face/data/WIDER_train/images/49--Greeting',
#   'filename': 'wider_face/data/WIDER_train/images/49--Greeting/49_Greeting_peoplegreeting_49_141.jpg',
#   'width': 1024,
#   'height': 768},
#  {'object': [{'name': 'face',
#     'xmin': 268,
#     'ymin': 385,
#     'xmax': 684,
#     'ymax': 889}],
#   'folder': 'wider_face/data/WIDER_train/images/28--Sports_Fan',
#   'filename': 'wider_face/data/WIDER_train/images/28--Sports_Fan/28_Sports_Fan_Sports_Fan_28_1027.jpg',
#   'width': 1024,
#   'height': 1332},
#  {'object': [{'name': 'face',
#     'xmin': 713,
#     'ymin': 211,
#     'xmax': 780,
#     'ymax': 305},
#    {'name': 'face', 'xmin': 452, 'ymin': 157, 'xmax': 493, 'ymax': 213},
#    {'name': 'face', 'xmin': 333, 'ymin': 161, 'xmax': 385, 'ymax': 231},
#    {'name': 'face', 'xmin': 275, 'ymin': 143, 'xmax': 340, 'ymax': 229},
#    {'name': 'face', 'xmin': 570, 'ymin': 298, 'xmax': 596, 'ymax': 328},
#    {'name': 'face', 'xmin': 611, 'ymin': 276, 'xmax': 633, 'ymax': 311},
#    {'name': 'face', 'xmin': 637, 'ymin': 264, 'xmax': 657, 'ymax': 288},
#    {'name': 'face', 'xmin': 369, 'ymin': 503, 'xmax': 411, 'ymax': 537},
#    {'name': 'face', 'xmin': 654, 'ymin': 283, 'xmax': 678, 'ymax': 303}],
#   'folder': 'wider_face/data/WIDER_train/images/12--Group',
#   'filename': 'wider_face/data/WIDER_train/images/12--Group/12_Group_Large_Group_12_Group_Large_Group_12_738.jpg',
#   'width': 1024,
#   'height': 657},
#  ...]

# %%
"wider_face/data/WIDER_train/28--Sports_Fan28_Sports_Fan_Sports_Fan_28_216.jpg"
# Out:
# 'wider_face/data/WIDER_train/28--Sports_Fan28_Sports_Fan_Sports_Fan_28_216.jpg'

# %%
train_imgs
# Out:
# [{'object': [{'name': 'face',
#     'xmin': 174,
#     'ymin': 321,
#     'xmax': 796,
#     'ymax': 965}],
#   'folder': 'wider_face/data/WIDER_train/images/28--Sports_Fan',
#   'filename': 'wider_face/data/WIDER_train/images/28--Sports_Fan/28_Sports_Fan_Sports_Fan_28_216.jpg',
#   'width': 1024,
#   'height': 1392},
#  {'object': [{'name': 'face',
#     'xmin': 580,
#     'ymin': 90,
#     'xmax': 672,
#     'ymax': 216},
#    {'name': 'face', 'xmin': 714, 'ymin': 182, 'xmax': 818, 'ymax': 328}],
#   'folder': 'wider_face/data/WIDER_train/images/20--Family_Group',
#   'filename': 'wider_face/data/WIDER_train/images/20--Family_Group/20_Family_Group_Family_Group_20_383.jpg',
#   'width': 1024,
#   'height': 683},
#  {'object': [{'name': 'face',
#     'xmin': 574,
#     'ymin': 292,
#     'xmax': 630,
#     'ymax': 346}],
#   'folder': 'wider_face/data/WIDER_train/images/7--Cheering',
#   'filename': 'wider_face/data/WIDER_train/images/7--Cheering/7_Cheering_Cheering_7_611.jpg',
#   'width': 1024,
#   'height': 767},
#  {'object': [{'name': 'face',
#     'xmin': 881,
#     'ymin': 22,
#     'xmax': 921,
#     'ymax': 82},
#    {'name': 'face', 'xmin': 581, 'ymin': 66, 'xmax': 629, 'ymax': 128},
#    {'name': 'face', 'xmin': 353, 'ymin': 69, 'xmax': 404, 'ymax': 115},
#    {'name': 'face', 'xmin': 72, 'ymin': 10, 'xmax': 120, 'ymax': 71}],
#   'folder': 'wider_face/data/WIDER_train/images/51--Dresses',
#   'filename': 'wider_face/data/WIDER_train/images/51--Dresses/51_Dresses_wearingdress_51_634.jpg',
#   'width': 1024,
#   'height': 659},
#  {'object': [{'name': 'face',
#     'xmin': 778,
#     'ymin': 171,
#     'xmax': 815,
#     'ymax': 212},
#    {'name': 'face', 'xmin': 597, 'ymin': 141, 'xmax': 622, 'ymax': 178},
#    {'name': 'face', 'xmin': 526, 'ymin': 164, 'xmax': 555, 'ymax': 200},
#    {'name': 'face', 'xmin': 439, 'ymin': 198, 'xmax': 482, 'ymax': 253},
#    {'name': 'face', 'xmin': 409, 'ymin': 173, 'xmax': 443, 'ymax': 216},
#    {'name': 'face', 'xmin': 334, 'ymin': 241, 'xmax': 390, 'ymax': 309},
#    {'name': 'face', 'xmin': 227, 'ymin': 353, 'xmax': 324, 'ymax': 487},
#    {'name': 'face', 'xmin': 83, 'ymin': 259, 'xmax': 156, 'ymax': 349}],
#   'folder': 'wider_face/data/WIDER_train/images/11--Meeting',
#   'filename': 'wider_face/data/WIDER_train/images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_105.jpg',
#   'width': 1024,
#   'height': 765},
#  {'object': [{'name': 'face',
#     'xmin': 476,
#     'ymin': 332,
#     'xmax': 526,
#     'ymax': 366},
#    {'name': 'face', 'xmin': 739, 'ymin': 478, 'xmax': 759, 'ymax': 504},
#    {'name': 'face', 'xmin': 974, 'ymin': 481, 'xmax': 995, 'ymax': 506},
#    {'name': 'face', 'xmin': 792, 'ymin': 478, 'xmax': 809, 'ymax': 499},
#    {'name': 'face', 'xmin': 844, 'ymin': 490, 'xmax': 860, 'ymax': 512},
#    {'name': 'face', 'xmin': 900, 'ymin': 499, 'xmax': 918, 'ymax': 522},
#    {'name': 'face', 'xmin': 686, 'ymin': 482, 'xmax': 703, 'ymax': 505},
#    {'name': 'face', 'xmin': 639, 'ymin': 488, 'xmax': 655, 'ymax': 509},
#    {'name': 'face', 'xmin': 590, 'ymin': 483, 'xmax': 604, 'ymax': 504},
#    {'name': 'face', 'xmin': 553, 'ymin': 492, 'xmax': 566, 'ymax': 510},
#    {'name': 'face', 'xmin': 500, 'ymin': 480, 'xmax': 515, 'ymax': 500},
#    {'name': 'face', 'xmin': 238, 'ymin': 480, 'xmax': 251, 'ymax': 497},
#    {'name': 'face', 'xmin': 283, 'ymin': 490, 'xmax': 295, 'ymax': 508},
#    {'name': 'face', 'xmin': 322, 'ymin': 480, 'xmax': 335, 'ymax': 498},
#    {'name': 'face', 'xmin': 345, 'ymin': 484, 'xmax': 357, 'ymax': 501},
#    {'name': 'face', 'xmin': 361, 'ymin': 484, 'xmax': 375, 'ymax': 505},
#    {'name': 'face', 'xmin': 199, 'ymin': 473, 'xmax': 214, 'ymax': 493},
#    {'name': 'face', 'xmin': 161, 'ymin': 477, 'xmax': 174, 'ymax': 495},
#    {'name': 'face', 'xmin': 77, 'ymin': 475, 'xmax': 91, 'ymax': 496},
#    {'name': 'face', 'xmin': 34, 'ymin': 472, 'xmax': 47, 'ymax': 490},
#    {'name': 'face', 'xmin': 574, 'ymin': 174, 'xmax': 606, 'ymax': 210}],
#   'folder': 'wider_face/data/WIDER_train/images/4--Dancing',
#   'filename': 'wider_face/data/WIDER_train/images/4--Dancing/4_Dancing_Dancing_4_108.jpg',
#   'width': 1024,
#   'height': 732},
#  {'object': [{'name': 'face',
#     'xmin': 195,
#     'ymin': 219,
#     'xmax': 473,
#     'ymax': 476}],
#   'folder': 'wider_face/data/WIDER_train/images/52--Photographers',
#   'filename': 'wider_face/data/WIDER_train/images/52--Photographers/52_Photographers_photographertakingphoto_52_628.jpg',
#   'width': 1024,
#   'height': 1535},
#  {'object': [{'name': 'face',
#     'xmin': 650,
#     'ymin': 169,
#     'xmax': 660,
#     'ymax': 184},
#    {'name': 'face', 'xmin': 666, 'ymin': 153, 'xmax': 675, 'ymax': 167},
#    {'name': 'face', 'xmin': 720, 'ymin': 155, 'xmax': 730, 'ymax': 171},
#    {'name': 'face', 'xmin': 735, 'ymin': 173, 'xmax': 745, 'ymax': 188},
#    {'name': 'face', 'xmin': 767, 'ymin': 167, 'xmax': 779, 'ymax': 182},
#    {'name': 'face', 'xmin': 974, 'ymin': 179, 'xmax': 984, 'ymax': 193},
#    {'name': 'face', 'xmin': 814, 'ymin': 158, 'xmax': 873, 'ymax': 233},
#    {'name': 'face', 'xmin': 486, 'ymin': 136, 'xmax': 500, 'ymax': 155},
#    {'name': 'face', 'xmin': 381, 'ymin': 172, 'xmax': 401, 'ymax': 199},
#    {'name': 'face', 'xmin': 329, 'ymin': 149, 'xmax': 348, 'ymax': 175},
#    {'name': 'face', 'xmin': 278, 'ymin': 170, 'xmax': 307, 'ymax': 207},
#    {'name': 'face', 'xmin': 340, 'ymin': 261, 'xmax': 372, 'ymax': 300},
#    {'name': 'face', 'xmin': 541, 'ymin': 170, 'xmax': 586, 'ymax': 224}],
#   'folder': 'wider_face/data/WIDER_train/images/25--Soldier_Patrol',
#   'filename': 'wider_face/data/WIDER_train/images/25--Soldier_Patrol/25_Soldier_Patrol_Soldier_Patrol_25_381.jpg',
#   'width': 1024,
#   'height': 808},
#  {'object': [{'name': 'face',
#     'xmin': 151,
#     'ymin': 210,
#     'xmax': 275,
#     'ymax': 395},
#    {'name': 'face', 'xmin': 696, 'ymin': 320, 'xmax': 841, 'ymax': 495}],
#   'folder': 'wider_face/data/WIDER_train/images/24--Soldier_Firing',
#   'filename': 'wider_face/data/WIDER_train/images/24--Soldier_Firing/24_Soldier_Firing_Soldier_Firing_24_631.jpg',
#   'width': 1024,
#   'height': 1377},
#  {'object': [{'name': 'face',
#     'xmin': 491,
#     'ymin': 108,
#     'xmax': 609,
#     'ymax': 293}],
#   'folder': 'wider_face/data/WIDER_train/images/16--Award_Ceremony',
#   'filename': 'wider_face/data/WIDER_train/images/16--Award_Ceremony/16_Award_Ceremony_Awards_Ceremony_16_291.jpg',
#   'width': 1024,
#   'height': 1636},
#  {'object': [{'name': 'face',
#     'xmin': 218,
#     'ymin': 156,
#     'xmax': 259,
#     'ymax': 217},
#    {'name': 'face', 'xmin': 307, 'ymin': 211, 'xmax': 317, 'ymax': 224},
#    {'name': 'face', 'xmin': 557, 'ymin': 196, 'xmax': 599, 'ymax': 238},
#    {'name': 'face', 'xmin': 466, 'ymin': 207, 'xmax': 474, 'ymax': 217},
#    {'name': 'face', 'xmin': 526, 'ymin': 196, 'xmax': 535, 'ymax': 208},
#    {'name': 'face', 'xmin': 622, 'ymin': 153, 'xmax': 647, 'ymax': 188},
#    {'name': 'face', 'xmin': 742, 'ymin': 197, 'xmax': 752, 'ymax': 210}],
#   'folder': 'wider_face/data/WIDER_train/images/36--Football',
#   'filename': 'wider_face/data/WIDER_train/images/36--Football/36_Football_Football_36_218.jpg',
#   'width': 1024,
#   'height': 577},
#  {'object': [{'name': 'face',
#     'xmin': 395,
#     'ymin': 73,
#     'xmax': 506,
#     'ymax': 214}],
#   'folder': 'wider_face/data/WIDER_train/images/51--Dresses',
#   'filename': 'wider_face/data/WIDER_train/images/51--Dresses/51_Dresses_wearingdress_51_620.jpg',
#   'width': 1024,
#   'height': 1289},
#  {'object': [{'name': 'face',
#     'xmin': 536,
#     'ymin': 54,
#     'xmax': 604,
#     'ymax': 142},
#    {'name': 'face', 'xmin': 828, 'ymin': 84, 'xmax': 900, 'ymax': 182},
#    {'name': 'face', 'xmin': 88, 'ymin': 116, 'xmax': 142, 'ymax': 184}],
#   'folder': 'wider_face/data/WIDER_train/images/32--Worker_Laborer',
#   'filename': 'wider_face/data/WIDER_train/images/32--Worker_Laborer/32_Worker_Laborer_Worker_Laborer_32_445.jpg',
#   'width': 1024,
#   'height': 652},
#  {'object': [{'name': 'face',
#     'xmin': 323,
#     'ymin': 333,
#     'xmax': 356,
#     'ymax': 378},
#    {'name': 'face', 'xmin': 491, 'ymin': 325, 'xmax': 515, 'ymax': 353},
#    {'name': 'face', 'xmin': 607, 'ymin': 337, 'xmax': 633, 'ymax': 371}],
#   'folder': 'wider_face/data/WIDER_train/images/43--Row_Boat',
#   'filename': 'wider_face/data/WIDER_train/images/43--Row_Boat/43_Row_Boat_Rowboat_43_383.jpg',
#   'width': 1024,
#   'height': 680},
#  {'object': [{'name': 'face',
#     'xmin': 180,
#     'ymin': 180,
#     'xmax': 298,
#     'ymax': 348},
#    {'name': 'face', 'xmin': 716, 'ymin': 72, 'xmax': 812, 'ymax': 206}],
#   'folder': 'wider_face/data/WIDER_train/images/12--Group',
#   'filename': 'wider_face/data/WIDER_train/images/12--Group/12_Group_Team_Organized_Group_12_Group_Team_Organized_Group_12_799.jpg',
#   'width': 1024,
#   'height': 701},
#  {'object': [{'name': 'face',
#     'xmin': 462,
#     'ymin': 124,
#     'xmax': 580,
#     'ymax': 292},
#    {'name': 'face', 'xmin': 450, 'ymin': 330, 'xmax': 584, 'ymax': 530}],
#   'folder': 'wider_face/data/WIDER_train/images/41--Swimming',
#   'filename': 'wider_face/data/WIDER_train/images/41--Swimming/41_Swimming_Swimming_41_59.jpg',
#   'width': 1024,
#   'height': 594},
#  {'object': [{'name': 'face',
#     'xmin': 174,
#     'ymin': 198,
#     'xmax': 712,
#     'ymax': 863}],
#   'folder': 'wider_face/data/WIDER_train/images/28--Sports_Fan',
#   'filename': 'wider_face/data/WIDER_train/images/28--Sports_Fan/28_Sports_Fan_Sports_Fan_28_202.jpg',
#   'width': 1024,
#   'height': 1392},
#  {'object': [{'name': 'face',
#     'xmin': 484,
#     'ymin': 105,
#     'xmax': 671,
#     'ymax': 361},
#    {'name': 'face', 'xmin': 908, 'ymin': 996, 'xmax': 982, 'ymax': 1103},
#    {'name': 'face', 'xmin': 140, 'ymin': 69, 'xmax': 280, 'ymax': 245},
#    {'name': 'face', 'xmin': 47, 'ymin': 336, 'xmax': 149, 'ymax': 501}],
#   'folder': 'wider_face/data/WIDER_train/images/5--Car_Accident',
#   'filename': 'wider_face/data/WIDER_train/images/5--Car_Accident/5_Car_Accident_Accident_5_784.jpg',
#   'width': 1024,
#   'height': 1409},
#  {'object': [{'name': 'face',
#     'xmin': 526,
#     'ymin': 417,
#     'xmax': 718,
#     'ymax': 663}],
#   'folder': 'wider_face/data/WIDER_train/images/44--Aerobics',
#   'filename': 'wider_face/data/WIDER_train/images/44--Aerobics/44_Aerobics_Aerobics_44_259.jpg',
#   'width': 1024,
#   'height': 1538},
#  {'object': [{'name': 'face',
#     'xmin': 142,
#     'ymin': 148,
#     'xmax': 233,
#     'ymax': 284},
#    {'name': 'face', 'xmin': 390, 'ymin': 81, 'xmax': 490, 'ymax': 217},
#    {'name': 'face', 'xmin': 727, 'ymin': 81, 'xmax': 843, 'ymax': 215}],
#   'folder': 'wider_face/data/WIDER_train/images/31--Waiter_Waitress',
#   'filename': 'wider_face/data/WIDER_train/images/31--Waiter_Waitress/31_Waiter_Waitress_Waiter_Waitress_31_586.jpg',
#   'width': 1024,
#   'height': 1041},
#  {'object': [{'name': 'face',
#     'xmin': 717,
#     'ymin': 77,
#     'xmax': 756,
#     'ymax': 130},
#    {'name': 'face', 'xmin': 406, 'ymin': 459, 'xmax': 422, 'ymax': 478},
#    {'name': 'face', 'xmin': 207, 'ymin': 379, 'xmax': 226, 'ymax': 401},
#    {'name': 'face', 'xmin': 248, 'ymin': 377, 'xmax': 263, 'ymax': 393},
#    {'name': 'face', 'xmin': 431, 'ymin': 437, 'xmax': 445, 'ymax': 454},
#    {'name': 'face', 'xmin': 445, 'ymin': 416, 'xmax': 458, 'ymax': 433},
#    {'name': 'face', 'xmin': 660, 'ymin': 443, 'xmax': 698, 'ymax': 492},
#    {'name': 'face', 'xmin': 506, 'ymin': 467, 'xmax': 519, 'ymax': 486},
#    {'name': 'face', 'xmin': 239, 'ymin': 376, 'xmax': 249, 'ymax': 389},
#    {'name': 'face', 'xmin': 897, 'ymin': 420, 'xmax': 907, 'ymax': 432},
#    {'name': 'face', 'xmin': 835, 'ymin': 390, 'xmax': 846, 'ymax': 404},
#    {'name': 'face', 'xmin': 795, 'ymin': 394, 'xmax': 806, 'ymax': 404},
#    {'name': 'face', 'xmin': 995, 'ymin': 436, 'xmax': 1006, 'ymax': 453},
#    {'name': 'face', 'xmin': 877, 'ymin': 400, 'xmax': 884, 'ymax': 410},
#    {'name': 'face', 'xmin': 961, 'ymin': 400, 'xmax': 968, 'ymax': 409},
#    {'name': 'face', 'xmin': 972, 'ymin': 390, 'xmax': 980, 'ymax': 400},
#    {'name': 'face', 'xmin': 390, 'ymin': 439, 'xmax': 403, 'ymax': 456}],
#   'folder': 'wider_face/data/WIDER_train/images/61--Street_Battle',
#   'filename': 'wider_face/data/WIDER_train/images/61--Street_Battle/61_Street_Battle_streetfight_61_111.jpg',
#   'width': 1024,
#   'height': 576},
#  {'object': [{'name': 'face',
#     'xmin': 54,
#     'ymin': 218,
#     'xmax': 86,
#     'ymax': 264},
#    {'name': 'face', 'xmin': 160, 'ymin': 211, 'xmax': 218, 'ymax': 264},
#    {'name': 'face', 'xmin': 224, 'ymin': 229, 'xmax': 262, 'ymax': 267},
#    {'name': 'face', 'xmin': 295, 'ymin': 195, 'xmax': 336, 'ymax': 246},
#    {'name': 'face', 'xmin': 337, 'ymin': 216, 'xmax': 373, 'ymax': 251},
#    {'name': 'face', 'xmin': 390, 'ymin': 198, 'xmax': 444, 'ymax': 259},
#    {'name': 'face', 'xmin': 499, 'ymin': 212, 'xmax': 546, 'ymax': 270},
#    {'name': 'face', 'xmin': 570, 'ymin': 229, 'xmax': 614, 'ymax': 279},
#    {'name': 'face', 'xmin': 619, 'ymin': 215, 'xmax': 656, 'ymax': 255},
#    {'name': 'face', 'xmin': 668, 'ymin': 213, 'xmax': 693, 'ymax': 245},
#    {'name': 'face', 'xmin': 680, 'ymin': 194, 'xmax': 724, 'ymax': 244},
#    {'name': 'face', 'xmin': 741, 'ymin': 217, 'xmax': 772, 'ymax': 252},
#    {'name': 'face', 'xmin': 821, 'ymin': 258, 'xmax': 847, 'ymax': 294},
#    {'name': 'face', 'xmin': 917, 'ymin': 243, 'xmax': 946, 'ymax': 278},
#    {'name': 'face', 'xmin': 777, 'ymin': 254, 'xmax': 801, 'ymax': 281},
#    {'name': 'face', 'xmin': 17, 'ymin': 203, 'xmax': 35, 'ymax': 247},
#    {'name': 'face', 'xmin': 864, 'ymin': 283, 'xmax': 887, 'ymax': 312}],
#   'folder': 'wider_face/data/WIDER_train/images/10--People_Marching',
#   'filename': 'wider_face/data/WIDER_train/images/10--People_Marching/10_People_Marching_People_Marching_2_456.jpg',
#   'width': 1024,
#   'height': 754},
#  {'object': [{'name': 'face',
#     'xmin': 36,
#     'ymin': 310,
#     'xmax': 150,
#     'ymax': 494},
#    {'name': 'face', 'xmin': 300, 'ymin': 318, 'xmax': 414, 'ymax': 468},
#    {'name': 'face', 'xmin': 582, 'ymin': 236, 'xmax': 708, 'ymax': 420},
#    {'name': 'face', 'xmin': 838, 'ymin': 226, 'xmax': 968, 'ymax': 420}],
#   'folder': 'wider_face/data/WIDER_train/images/3--Riot',
#   'filename': 'wider_face/data/WIDER_train/images/3--Riot/3_Riot_Riot_3_707.jpg',
#   'width': 1024,
#   'height': 996},
#  {'object': [{'name': 'face',
#     'xmin': 716,
#     'ymin': 114,
#     'xmax': 798,
#     'ymax': 228}],
#   'folder': 'wider_face/data/WIDER_train/images/44--Aerobics',
#   'filename': 'wider_face/data/WIDER_train/images/44--Aerobics/44_Aerobics_Aerobics_44_271.jpg',
#   'width': 1024,
#   'height': 596},
#  {'object': [{'name': 'face',
#     'xmin': 176,
#     'ymin': 405,
#     'xmax': 262,
#     'ymax': 508},
#    {'name': 'face', 'xmin': 444, 'ymin': 352, 'xmax': 519, 'ymax': 455}],
#   'folder': 'wider_face/data/WIDER_train/images/24--Soldier_Firing',
#   'filename': 'wider_face/data/WIDER_train/images/24--Soldier_Firing/24_Soldier_Firing_Soldier_Firing_24_619.jpg',
#   'width': 1024,
#   'height': 1431},
#  {'object': [{'name': 'face',
#     'xmin': 895,
#     'ymin': 130,
#     'xmax': 926,
#     'ymax': 177},
#    {'name': 'face', 'xmin': 758, 'ymin': 156, 'xmax': 771, 'ymax': 175},
#    {'name': 'face', 'xmin': 391, 'ymin': 102, 'xmax': 432, 'ymax': 162},
#    {'name': 'face', 'xmin': 63, 'ymin': 55, 'xmax': 92, 'ymax': 91},
#    {'name': 'face', 'xmin': 276, 'ymin': 157, 'xmax': 303, 'ymax': 195}],
#   'folder': 'wider_face/data/WIDER_train/images/37--Soccer',
#   'filename': 'wider_face/data/WIDER_train/images/37--Soccer/37_Soccer_Soccer_37_400.jpg',
#   'width': 1024,
#   'height': 685},
#  {'object': [{'name': 'face',
#     'xmin': 422,
#     'ymin': 86,
#     'xmax': 477,
#     'ymax': 148},
#    {'name': 'face', 'xmin': 599, 'ymin': 88, 'xmax': 631, 'ymax': 144},
#    {'name': 'face', 'xmin': 913, 'ymin': 201, 'xmax': 941, 'ymax': 236},
#    {'name': 'face', 'xmin': 799, 'ymin': 276, 'xmax': 823, 'ymax': 305},
#    {'name': 'face', 'xmin': 97, 'ymin': 263, 'xmax': 125, 'ymax': 298},
#    {'name': 'face', 'xmin': 40, 'ymin': 318, 'xmax': 59, 'ymax': 344}],
#   'folder': 'wider_face/data/WIDER_train/images/37--Soccer',
#   'filename': 'wider_face/data/WIDER_train/images/37--Soccer/37_Soccer_soccer_ball_37_425.jpg',
#   'width': 1024,
#   'height': 576},
#  {'object': [{'name': 'face',
#     'xmin': 696,
#     'ymin': 64,
#     'xmax': 846,
#     'ymax': 276}],
#   'folder': 'wider_face/data/WIDER_train/images/45--Balloonist',
#   'filename': 'wider_face/data/WIDER_train/images/45--Balloonist/45_Balloonist_Balloonist_45_835.jpg',
#   'width': 1024,
#   'height': 681},
#  {'object': [{'name': 'face',
#     'xmin': 534,
#     'ymin': 1073,
#     'xmax': 821,
#     'ymax': 1206}],
#   'folder': 'wider_face/data/WIDER_train/images/35--Basketball',
#   'filename': 'wider_face/data/WIDER_train/images/35--Basketball/35_Basketball_playingbasketball_35_415.jpg',
#   'width': 1024,
#   'height': 1579},
#  {'object': [{'name': 'face',
#     'xmin': 573,
#     'ymin': 45,
#     'xmax': 720,
#     'ymax': 261},
#    {'name': 'face', 'xmin': 181, 'ymin': 149, 'xmax': 320, 'ymax': 352}],
#   'folder': 'wider_face/data/WIDER_train/images/13--Interview',
#   'filename': 'wider_face/data/WIDER_train/images/13--Interview/13_Interview_Interview_On_Location_13_607.jpg',
#   'width': 1024,
#   'height': 1366},
#  {'object': [{'name': 'face',
#     'xmin': 381,
#     'ymin': 323,
#     'xmax': 586,
#     'ymax': 659},
#    {'name': 'face', 'xmin': 176, 'ymin': 360, 'xmax': 371, 'ymax': 581}],
#   'folder': 'wider_face/data/WIDER_train/images/18--Concerts',
#   'filename': 'wider_face/data/WIDER_train/images/18--Concerts/18_Concerts_Concerts_18_502.jpg',
#   'width': 1024,
#   'height': 1366},
#  {'object': [{'name': 'face',
#     'xmin': 761,
#     'ymin': 98,
#     'xmax': 826,
#     'ymax': 173},
#    {'name': 'face', 'xmin': 841, 'ymin': 402, 'xmax': 891, 'ymax': 473},
#    {'name': 'face', 'xmin': 237, 'ymin': 417, 'xmax': 281, 'ymax': 479},
#    {'name': 'face', 'xmin': 291, 'ymin': 103, 'xmax': 363, 'ymax': 189}],
#   'folder': 'wider_face/data/WIDER_train/images/11--Meeting',
#   'filename': 'wider_face/data/WIDER_train/images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_139.jpg',
#   'width': 1024,
#   'height': 791},
#  {'object': [{'name': 'face',
#     'xmin': 60,
#     'ymin': 194,
#     'xmax': 68,
#     'ymax': 201},
#    {'name': 'face', 'xmin': 141, 'ymin': 184, 'xmax': 147, 'ymax': 192},
#    {'name': 'face', 'xmin': 424, 'ymin': 276, 'xmax': 431, 'ymax': 286},
#    {'name': 'face', 'xmin': 917, 'ymin': 261, 'xmax': 933, 'ymax': 286},
#    {'name': 'face', 'xmin': 982, 'ymin': 266, 'xmax': 1002, 'ymax': 293},
#    {'name': 'face', 'xmin': 880, 'ymin': 324, 'xmax': 890, 'ymax': 337},
#    {'name': 'face', 'xmin': 889, 'ymin': 341, 'xmax': 899, 'ymax': 351},
#    {'name': 'face', 'xmin': 814, 'ymin': 302, 'xmax': 821, 'ymax': 311},
#    {'name': 'face', 'xmin': 816, 'ymin': 319, 'xmax': 824, 'ymax': 331},
#    {'name': 'face', 'xmin': 38, 'ymin': 188, 'xmax': 45, 'ymax': 196},
#    {'name': 'face', 'xmin': 239, 'ymin': 219, 'xmax': 243, 'ymax': 224},
#    {'name': 'face', 'xmin': 231, 'ymin': 219, 'xmax': 236, 'ymax': 226},
#    {'name': 'face', 'xmin': 316, 'ymin': 210, 'xmax': 323, 'ymax': 219},
#    {'name': 'face', 'xmin': 824, 'ymin': 272, 'xmax': 829, 'ymax': 280},
#    {'name': 'face', 'xmin': 831, 'ymin': 315, 'xmax': 837, 'ymax': 324},
#    {'name': 'face', 'xmin': 776, 'ymin': 316, 'xmax': 781, 'ymax': 323},
#    {'name': 'face', 'xmin': 787, 'ymin': 322, 'xmax': 794, 'ymax': 330},
#    {'name': 'face', 'xmin': 809, 'ymin': 321, 'xmax': 815, 'ymax': 329},
#    {'name': 'face', 'xmin': 878, 'ymin': 339, 'xmax': 885, 'ymax': 345},
#    {'name': 'face', 'xmin': 882, 'ymin': 353, 'xmax': 890, 'ymax': 363},
#    {'name': 'face', 'xmin': 888, 'ymin': 366, 'xmax': 895, 'ymax': 374},
#    {'name': 'face', 'xmin': 876, 'ymin': 349, 'xmax': 883, 'ymax': 358},
#    {'name': 'face', 'xmin': 843, 'ymin': 333, 'xmax': 852, 'ymax': 343}],
#   'folder': 'wider_face/data/WIDER_train/images/22--Picnic',
#   'filename': 'wider_face/data/WIDER_train/images/22--Picnic/22_Picnic_Picnic_22_687.jpg',
#   'width': 1024,
#   'height': 669},
#  {'object': [{'name': 'face',
#     'xmin': 243,
#     'ymin': 240,
#     'xmax': 820,
#     'ymax': 934}],
#   'folder': 'wider_face/data/WIDER_train/images/38--Tennis',
#   'filename': 'wider_face/data/WIDER_train/images/38--Tennis/38_Tennis_Tennis_38_780.jpg',
#   'width': 1024,
#   'height': 1536},
#  {'object': [{'name': 'face',
#     'xmin': 428,
#     'ymin': 468,
#     'xmax': 484,
#     'ymax': 560},
#    {'name': 'face', 'xmin': 584, 'ymin': 526, 'xmax': 636, 'ymax': 612},
#    {'name': 'face', 'xmin': 728, 'ymin': 486, 'xmax': 790, 'ymax': 564},
#    {'name': 'face', 'xmin': 862, 'ymin': 492, 'xmax': 922, 'ymax': 582},
#    {'name': 'face', 'xmin': 530, 'ymin': 404, 'xmax': 612, 'ymax': 458}],
#   'folder': 'wider_face/data/WIDER_train/images/40--Gymnastics',
#   'filename': 'wider_face/data/WIDER_train/images/40--Gymnastics/40_Gymnastics_Gymnastics_40_987.jpg',
#   'width': 1024,
#   'height': 940},
#  {'object': [{'name': 'face',
#     'xmin': 580,
#     'ymin': 224,
#     'xmax': 668,
#     'ymax': 356},
#    {'name': 'face', 'xmin': 330, 'ymin': 206, 'xmax': 392, 'ymax': 292},
#    {'name': 'face', 'xmin': 36, 'ymin': 196, 'xmax': 160, 'ymax': 378}],
#   'folder': 'wider_face/data/WIDER_train/images/53--Raid',
#   'filename': 'wider_face/data/WIDER_train/images/53--Raid/53_Raid_policeraid_53_250.jpg',
#   'width': 1024,
#   'height': 768},
#  {'object': [{'name': 'face',
#     'xmin': 245,
#     'ymin': 114,
#     'xmax': 300,
#     'ymax': 195},
#    {'name': 'face', 'xmin': 339, 'ymin': 180, 'xmax': 375, 'ymax': 236},
#    {'name': 'face', 'xmin': 151, 'ymin': 230, 'xmax': 188, 'ymax': 284},
#    {'name': 'face', 'xmin': 536, 'ymin': 150, 'xmax': 641, 'ymax': 289},
#    {'name': 'face', 'xmin': 642, 'ymin': 236, 'xmax': 671, 'ymax': 277}],
#   'folder': 'wider_face/data/WIDER_train/images/4--Dancing',
#   'filename': 'wider_face/data/WIDER_train/images/4--Dancing/4_Dancing_Dancing_4_120.jpg',
#   'width': 1024,
#   'height': 1114},
#  {'object': [{'name': 'face',
#     'xmin': 75,
#     'ymin': 219,
#     'xmax': 119,
#     'ymax': 274},
#    {'name': 'face', 'xmin': 348, 'ymin': 213, 'xmax': 389, 'ymax': 261},
#    {'name': 'face', 'xmin': 849, 'ymin': 210, 'xmax': 894, 'ymax': 265},
#    {'name': 'face', 'xmin': 392, 'ymin': 45, 'xmax': 425, 'ymax': 79}],
#   'folder': 'wider_face/data/WIDER_train/images/54--Rescue',
#   'filename': 'wider_face/data/WIDER_train/images/54--Rescue/54_Rescue_rescuepeople_54_844.jpg',
#   'width': 1024,
#   'height': 670},
#  {'object': [{'name': 'face',
#     'xmin': 391,
#     'ymin': 57,
#     'xmax': 400,
#     'ymax': 68},
#    {'name': 'face', 'xmin': 499, 'ymin': 123, 'xmax': 508, 'ymax': 133},
#    {'name': 'face', 'xmin': 552, 'ymin': 131, 'xmax': 561, 'ymax': 141},
#    {'name': 'face', 'xmin': 677, 'ymin': 173, 'xmax': 684, 'ymax': 180},
#    {'name': 'face', 'xmin': 564, 'ymin': 71, 'xmax': 571, 'ymax': 77},
#    {'name': 'face', 'xmin': 610, 'ymin': 61, 'xmax': 618, 'ymax': 71},
#    {'name': 'face', 'xmin': 527, 'ymin': 75, 'xmax': 533, 'ymax': 80},
#    {'name': 'face', 'xmin': 430, 'ymin': 55, 'xmax': 439, 'ymax': 66},
#    {'name': 'face', 'xmin': 472, 'ymin': 45, 'xmax': 478, 'ymax': 52},
#    {'name': 'face', 'xmin': 357, 'ymin': 66, 'xmax': 367, 'ymax': 77},
#    {'name': 'face', 'xmin': 387, 'ymin': 33, 'xmax': 396, 'ymax': 41},
#    {'name': 'face', 'xmin': 419, 'ymin': 48, 'xmax': 426, 'ymax': 55},
#    {'name': 'face', 'xmin': 446, 'ymin': 36, 'xmax': 451, 'ymax': 43},
#    {'name': 'face', 'xmin': 29, 'ymin': 303, 'xmax': 46, 'ymax': 321},
#    {'name': 'face', 'xmin': 122, 'ymin': 321, 'xmax': 138, 'ymax': 345},
#    {'name': 'face', 'xmin': 171, 'ymin': 314, 'xmax': 185, 'ymax': 329},
#    {'name': 'face', 'xmin': 197, 'ymin': 286, 'xmax': 211, 'ymax': 306},
#    {'name': 'face', 'xmin': 239, 'ymin': 308, 'xmax': 256, 'ymax': 334},
#    {'name': 'face', 'xmin': 259, 'ymin': 283, 'xmax': 271, 'ymax': 298},
#    {'name': 'face', 'xmin': 301, 'ymin': 333, 'xmax': 319, 'ymax': 355},
#    {'name': 'face', 'xmin': 346, 'ymin': 332, 'xmax': 363, 'ymax': 356},
#    {'name': 'face', 'xmin': 323, 'ymin': 291, 'xmax': 336, 'ymax': 304},
#    {'name': 'face', 'xmin': 387, 'ymin': 318, 'xmax': 405, 'ymax': 340},
#    {'name': 'face', 'xmin': 415, 'ymin': 269, 'xmax': 429, 'ymax': 277},
#    {'name': 'face', 'xmin': 415, 'ymin': 313, 'xmax': 428, 'ymax': 325},
#    {'name': 'face', 'xmin': 441, 'ymin': 320, 'xmax': 457, 'ymax': 334},
#    {'name': 'face', 'xmin': 485, 'ymin': 302, 'xmax': 505, 'ymax': 324},
#    {'name': 'face', 'xmin': 540, 'ymin': 287, 'xmax': 554, 'ymax': 301},
#    {'name': 'face', 'xmin': 552, 'ymin': 304, 'xmax': 574, 'ymax': 324},
#    {'name': 'face', 'xmin': 575, 'ymin': 332, 'xmax': 600, 'ymax': 362},
#    {'name': 'face', 'xmin': 588, 'ymin': 275, 'xmax': 601, 'ymax': 289},
#    {'name': 'face', 'xmin': 607, 'ymin': 318, 'xmax': 621, 'ymax': 330},
#    {'name': 'face', 'xmin': 651, 'ymin': 267, 'xmax': 663, 'ymax': 282},
#    {'name': 'face', 'xmin': 641, 'ymin': 301, 'xmax': 661, 'ymax': 328},
#    {'name': 'face', 'xmin': 697, 'ymin': 222, 'xmax': 703, 'ymax': 228},
#    {'name': 'face', 'xmin': 722, 'ymin': 245, 'xmax': 731, 'ymax': 252},
#    {'name': 'face', 'xmin': 748, 'ymin': 265, 'xmax': 759, 'ymax': 279},
#    {'name': 'face', 'xmin': 934, 'ymin': 262, 'xmax': 945, 'ymax': 271},
#    {'name': 'face', 'xmin': 984, 'ymin': 253, 'xmax': 995, 'ymax': 264},
#    {'name': 'face', 'xmin': 925, 'ymin': 305, 'xmax': 938, 'ymax': 319},
#    {'name': 'face', 'xmin': 951, 'ymin': 295, 'xmax': 971, 'ymax': 323},
#    {'name': 'face', 'xmin': 964, 'ymin': 333, 'xmax': 979, 'ymax': 355},
#    {'name': 'face', 'xmin': 781, 'ymin': 289, 'xmax': 789, 'ymax': 297},
#    {'name': 'face', 'xmin': 787, 'ymin': 281, 'xmax': 794, 'ymax': 287},
#    {'name': 'face', 'xmin': 1013, 'ymin': 304, 'xmax': 1024, 'ymax': 332},
#    {'name': 'face', 'xmin': 1000, 'ymin': 290, 'xmax': 1012, 'ymax': 299},
#    {'name': 'face', 'xmin': 1009, 'ymin': 271, 'xmax': 1018, 'ymax': 280},
#    {'name': 'face', 'xmin': 48, 'ymin': 307, 'xmax': 55, 'ymax': 315},
#    {'name': 'face', 'xmin': 293, 'ymin': 312, 'xmax': 306, 'ymax': 325},
#    {'name': 'face', 'xmin': 310, 'ymin': 302, 'xmax': 326, 'ymax': 318},
#    {'name': 'face', 'xmin': 510, 'ymin': 304, 'xmax': 524, 'ymax': 316},
#    {'name': 'face', 'xmin': 492, 'ymin': 275, 'xmax': 498, 'ymax': 283},
#    {'name': 'face', 'xmin': 562, 'ymin': 256, 'xmax': 573, 'ymax': 271},
#    {'name': 'face', 'xmin': 668, 'ymin': 312, 'xmax': 682, 'ymax': 332},
#    {'name': 'face', 'xmin': 711, 'ymin': 293, 'xmax': 725, 'ymax': 304},
#    {'name': 'face', 'xmin': 789, 'ymin': 265, 'xmax': 796, 'ymax': 273},
#    {'name': 'face', 'xmin': 805, 'ymin': 252, 'xmax': 814, 'ymax': 261},
#    {'name': 'face', 'xmin': 969, 'ymin': 278, 'xmax': 976, 'ymax': 286},
#    {'name': 'face', 'xmin': 916, 'ymin': 267, 'xmax': 923, 'ymax': 274},
#    {'name': 'face', 'xmin': 900, 'ymin': 293, 'xmax': 907, 'ymax': 301},
#    {'name': 'face', 'xmin': 350, 'ymin': 29, 'xmax': 358, 'ymax': 41},
#    {'name': 'face', 'xmin': 419, 'ymin': 80, 'xmax': 427, 'ymax': 90},
#    {'name': 'face', 'xmin': 464, 'ymin': 82, 'xmax': 471, 'ymax': 89},
#    {'name': 'face', 'xmin': 502, 'ymin': 107, 'xmax': 511, 'ymax': 115},
#    {'name': 'face', 'xmin': 556, 'ymin': 118, 'xmax': 564, 'ymax': 125},
#    {'name': 'face', 'xmin': 570, 'ymin': 83, 'xmax': 580, 'ymax': 92},
#    {'name': 'face', 'xmin': 668, 'ymin': 162, 'xmax': 675, 'ymax': 176},
#    {'name': 'face', 'xmin': 627, 'ymin': 82, 'xmax': 634, 'ymax': 92},
#    {'name': 'face', 'xmin': 746, 'ymin': 289, 'xmax': 758, 'ymax': 305},
#    {'name': 'face', 'xmin': 756, 'ymin': 295, 'xmax': 766, 'ymax': 313}],
#   'folder': 'wider_face/data/WIDER_train/images/2--Demonstration',
#   'filename': 'wider_face/data/WIDER_train/images/2--Demonstration/2_Demonstration_Demonstration_Or_Protest_2_189.jpg',
#   'width': 1024,
#   'height': 577},
#  {'object': [{'name': 'face',
#     'xmin': 405,
#     'ymin': 201,
#     'xmax': 519,
#     'ymax': 366}],
#   'folder': 'wider_face/data/WIDER_train/images/39--Ice_Skating',
#   'filename': 'wider_face/data/WIDER_train/images/39--Ice_Skating/39_Ice_Skating_Ice_Skating_39_1.jpg',
#   'width': 1024,
#   'height': 1536},
#  {'object': [{'name': 'face',
#     'xmin': 204,
#     'ymin': 277,
#     'xmax': 311,
#     'ymax': 405},
#    {'name': 'face', 'xmin': 80, 'ymin': 159, 'xmax': 122, 'ymax': 224},
#    {'name': 'face', 'xmin': 160, 'ymin': 220, 'xmax': 209, 'ymax': 285},
#    {'name': 'face', 'xmin': 293, 'ymin': 210, 'xmax': 341, 'ymax': 272},
#    {'name': 'face', 'xmin': 398, 'ymin': 228, 'xmax': 450, 'ymax': 292},
#    {'name': 'face', 'xmin': 511, 'ymin': 260, 'xmax': 611, 'ymax': 398},
#    {'name': 'face', 'xmin': 669, 'ymin': 238, 'xmax': 753, 'ymax': 380}],
#   'folder': 'wider_face/data/WIDER_train/images/10--People_Marching',
#   'filename': 'wider_face/data/WIDER_train/images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_101.jpg',
#   'width': 1024,
#   'height': 683},
#  {'object': [{'name': 'face',
#     'xmin': 300,
#     'ymin': 64,
#     'xmax': 426,
#     'ymax': 248}],
#   'folder': 'wider_face/data/WIDER_train/images/34--Baseball',
#   'filename': 'wider_face/data/WIDER_train/images/34--Baseball/34_Baseball_Baseball_34_482.jpg',
#   'width': 1024,
#   'height': 653},
#  {'object': [{'name': 'face',
#     'xmin': 412,
#     'ymin': 111,
#     'xmax': 425,
#     'ymax': 136},
#    {'name': 'face', 'xmin': 814, 'ymin': 162, 'xmax': 835, 'ymax': 184},
#    {'name': 'face', 'xmin': 890, 'ymin': 227, 'xmax': 898, 'ymax': 236},
#    {'name': 'face', 'xmin': 784, 'ymin': 170, 'xmax': 798, 'ymax': 190},
#    {'name': 'face', 'xmin': 724, 'ymin': 186, 'xmax': 738, 'ymax': 202},
#    {'name': 'face', 'xmin': 759, 'ymin': 181, 'xmax': 769, 'ymax': 189},
#    {'name': 'face', 'xmin': 21, 'ymin': 137, 'xmax': 28, 'ymax': 146}],
#   'folder': 'wider_face/data/WIDER_train/images/42--Car_Racing',
#   'filename': 'wider_face/data/WIDER_train/images/42--Car_Racing/42_Car_Racing_Car_Racing_42_37.jpg',
#   'width': 1024,
#   'height': 680},
#  {'object': [{'name': 'face',
#     'xmin': 58,
#     'ymin': 148,
#     'xmax': 148,
#     'ymax': 268},
#    {'name': 'face', 'xmin': 442, 'ymin': 152, 'xmax': 536, 'ymax': 320}],
#   'folder': 'wider_face/data/WIDER_train/images/18--Concerts',
#   'filename': 'wider_face/data/WIDER_train/images/18--Concerts/18_Concerts_Concerts_18_270.jpg',
#   'width': 1024,
#   'height': 688},
#  {'object': [{'name': 'face',
#     'xmin': 738,
#     'ymin': 228,
#     'xmax': 794,
#     'ymax': 306}],
#   'folder': 'wider_face/data/WIDER_train/images/32--Worker_Laborer',
#   'filename': 'wider_face/data/WIDER_train/images/32--Worker_Laborer/32_Worker_Laborer_Worker_Laborer_32_479.jpg',
#   'width': 1024,
#   'height': 685},
#  {'object': [{'name': 'face',
#     'xmin': 310,
#     'ymin': 274,
#     'xmax': 408,
#     'ymax': 396},
#    {'name': 'face', 'xmin': 472, 'ymin': 246, 'xmax': 554, 'ymax': 344},
#    {'name': 'face', 'xmin': 606, 'ymin': 266, 'xmax': 696, 'ymax': 374}],
#   'folder': 'wider_face/data/WIDER_train/images/11--Meeting',
#   'filename': 'wider_face/data/WIDER_train/images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_893.jpg',
#   'width': 1024,
#   'height': 767},
#  {'object': [{'name': 'face',
#     'xmin': 798,
#     'ymin': 112,
#     'xmax': 850,
#     'ymax': 178},
#    {'name': 'face', 'xmin': 653, 'ymin': 108, 'xmax': 705, 'ymax': 171},
#    {'name': 'face', 'xmin': 505, 'ymin': 95, 'xmax': 557, 'ymax': 162},
#    {'name': 'face', 'xmin': 328, 'ymin': 90, 'xmax': 387, 'ymax': 163},
#    {'name': 'face', 'xmin': 196, 'ymin': 99, 'xmax': 261, 'ymax': 167},
#    {'name': 'face', 'xmin': 957, 'ymin': 184, 'xmax': 977, 'ymax': 210},
#    {'name': 'face', 'xmin': 914, 'ymin': 336, 'xmax': 950, 'ymax': 402},
#    {'name': 'face', 'xmin': 1003, 'ymin': 225, 'xmax': 1016, 'ymax': 251},
#    {'name': 'face', 'xmin': 82, 'ymin': 132, 'xmax': 95, 'ymax': 148},
#    {'name': 'face', 'xmin': 37, 'ymin': 162, 'xmax': 50, 'ymax': 178},
#    {'name': 'face', 'xmin': 14, 'ymin': 173, 'xmax': 25, 'ymax': 184},
#    {'name': 'face', 'xmin': 59, 'ymin': 184, 'xmax': 71, 'ymax': 197}],
#   'folder': 'wider_face/data/WIDER_train/images/0--Parade',
#   'filename': 'wider_face/data/WIDER_train/images/0--Parade/0_Parade_Parade_0_253.jpg',
#   'width': 1024,
#   'height': 847},
#  {'object': [{'name': 'face',
#     'xmin': 609,
#     'ymin': 839,
#     'xmax': 872,
#     'ymax': 1155},
#    {'name': 'face', 'xmin': 513, 'ymin': 513, 'xmax': 685, 'ymax': 784},
#    {'name': 'face', 'xmin': 46, 'ymin': 652, 'xmax': 231, 'ymax': 910},
#    {'name': 'face', 'xmin': 169, 'ymin': 417, 'xmax': 323, 'ymax': 624},
#    {'name': 'face', 'xmin': 321, 'ymin': 253, 'xmax': 440, 'ymax': 415},
#    {'name': 'face', 'xmin': 685, 'ymin': 346, 'xmax': 829, 'ymax': 576},
#    {'name': 'face', 'xmin': 731, 'ymin': 233, 'xmax': 865, 'ymax': 367},
#    {'name': 'face', 'xmin': 465, 'ymin': 91, 'xmax': 581, 'ymax': 245},
#    {'name': 'face', 'xmin': 579, 'ymin': 185, 'xmax': 680, 'ymax': 311},
#    {'name': 'face', 'xmin': 162, 'ymin': 139, 'xmax': 271, 'ymax': 291},
#    {'name': 'face', 'xmin': 354, 'ymin': 66, 'xmax': 442, 'ymax': 170}],
#   'folder': 'wider_face/data/WIDER_train/images/29--Students_Schoolkids',
#   'filename': 'wider_face/data/WIDER_train/images/29--Students_Schoolkids/29_Students_Schoolkids_Students_Schoolkids_29_175.jpg',
#   'width': 1024,
#   'height': 1296},
#  {'object': [{'name': 'face',
#     'xmin': 230,
#     'ymin': 230,
#     'xmax': 640,
#     'ymax': 796}],
#   'folder': 'wider_face/data/WIDER_train/images/16--Award_Ceremony',
#   'filename': 'wider_face/data/WIDER_train/images/16--Award_Ceremony/16_Award_Ceremony_Awards_Ceremony_16_520.jpg',
#   'width': 1024,
#   'height': 1294},
#  {'object': [{'name': 'face',
#     'xmin': 433,
#     'ymin': 97,
#     'xmax': 492,
#     'ymax': 138},
#    {'name': 'face', 'xmin': 274, 'ymin': 217, 'xmax': 319, 'ymax': 274},
#    {'name': 'face', 'xmin': 80, 'ymin': 0, 'xmax': 175, 'ymax': 101},
#    {'name': 'face', 'xmin': 784, 'ymin': 128, 'xmax': 819, 'ymax': 173},
#    {'name': 'face', 'xmin': 896, 'ymin': 83, 'xmax': 943, 'ymax': 147},
#    {'name': 'face', 'xmin': 965, 'ymin': 85, 'xmax': 1024, 'ymax': 217},
#    {'name': 'face', 'xmin': 854, 'ymin': 133, 'xmax': 888, 'ymax': 176},
#    {'name': 'face', 'xmin': 541, 'ymin': 238, 'xmax': 577, 'ymax': 291},
#    {'name': 'face', 'xmin': 385, 'ymin': 363, 'xmax': 428, 'ymax': 389},
#    {'name': 'face', 'xmin': 706, 'ymin': 522, 'xmax': 772, 'ymax': 575},
#    {'name': 'face', 'xmin': 600, 'ymin': 345, 'xmax': 653, 'ymax': 388},
#    {'name': 'face', 'xmin': 217, 'ymin': 32, 'xmax': 231, 'ymax': 49}],
#   'folder': 'wider_face/data/WIDER_train/images/6--Funeral',
#   'filename': 'wider_face/data/WIDER_train/images/6--Funeral/6_Funeral_Funeral_6_620.jpg',
#   'width': 1024,
#   'height': 773},
#  {'object': [{'name': 'face',
#     'xmin': 321,
#     'ymin': 199,
#     'xmax': 467,
#     'ymax': 388},
#    {'name': 'face', 'xmin': 672, 'ymin': 282, 'xmax': 784, 'ymax': 447},
#    {'name': 'face', 'xmin': 868, 'ymin': 359, 'xmax': 945, 'ymax': 455},
#    {'name': 'face', 'xmin': 883, 'ymin': 278, 'xmax': 957, 'ymax': 371}],
#   'folder': 'wider_face/data/WIDER_train/images/2--Demonstration',
#   'filename': 'wider_face/data/WIDER_train/images/2--Demonstration/2_Demonstration_Political_Rally_2_512.jpg',
#   'width': 1024,
#   'height': 1225},
#  {'object': [{'name': 'face',
#     'xmin': 387,
#     'ymin': 401,
#     'xmax': 440,
#     'ymax': 498}],
#   'folder': 'wider_face/data/WIDER_train/images/33--Running',
#   'filename': 'wider_face/data/WIDER_train/images/33--Running/33_Running_Running_33_378.jpg',
#   'width': 1024,
#   'height': 1509},
#  {'object': [{'name': 'face',
#     'xmin': 378,
#     'ymin': 302,
#     'xmax': 393,
#     'ymax': 319},
#    {'name': 'face', 'xmin': 403, 'ymin': 305, 'xmax': 421, 'ymax': 326},
#    {'name': 'face', 'xmin': 430, 'ymin': 300, 'xmax': 449, 'ymax': 324},
#    {'name': 'face', 'xmin': 381, 'ymin': 318, 'xmax': 401, 'ymax': 344},
#    {'name': 'face', 'xmin': 361, 'ymin': 331, 'xmax': 381, 'ymax': 356},
#    {'name': 'face', 'xmin': 488, 'ymin': 293, 'xmax': 507, 'ymax': 319},
#    {'name': 'face', 'xmin': 510, 'ymin': 295, 'xmax': 525, 'ymax': 319},
#    {'name': 'face', 'xmin': 548, 'ymin': 297, 'xmax': 577, 'ymax': 335},
#    {'name': 'face', 'xmin': 511, 'ymin': 323, 'xmax': 563, 'ymax': 382},
#    {'name': 'face', 'xmin': 617, 'ymin': 325, 'xmax': 645, 'ymax': 370},
#    {'name': 'face', 'xmin': 626, 'ymin': 298, 'xmax': 649, 'ymax': 325},
#    {'name': 'face', 'xmin': 713, 'ymin': 334, 'xmax': 746, 'ymax': 372},
#    {'name': 'face', 'xmin': 790, 'ymin': 377, 'xmax': 833, 'ymax': 426},
#    {'name': 'face', 'xmin': 851, 'ymin': 335, 'xmax': 879, 'ymax': 370},
#    {'name': 'face', 'xmin': 840, 'ymin': 389, 'xmax': 870, 'ymax': 427},
#    {'name': 'face', 'xmin': 962, 'ymin': 356, 'xmax': 1010, 'ymax': 424},
#    {'name': 'face', 'xmin': 993, 'ymin': 318, 'xmax': 1023, 'ymax': 361},
#    {'name': 'face', 'xmin': 175, 'ymin': 150, 'xmax': 195, 'ymax': 170}],
#   'folder': 'wider_face/data/WIDER_train/images/23--Shoppers',
#   'filename': 'wider_face/data/WIDER_train/images/23--Shoppers/23_Shoppers_Shoppers_23_68.jpg',
#   'width': 1024,
#   'height': 748},
#  {'object': [{'name': 'face',
#     'xmin': 586,
#     'ymin': 73,
#     'xmax': 746,
#     'ymax': 317},
#    {'name': 'face', 'xmin': 389, 'ymin': 232, 'xmax': 578, 'ymax': 397}],
#   'folder': 'wider_face/data/WIDER_train/images/19--Couple',
#   'filename': 'wider_face/data/WIDER_train/images/19--Couple/19_Couple_Couple_19_340.jpg',
#   'width': 1024,
#   'height': 1486},
#  {'object': [{'name': 'face',
#     'xmin': 438,
#     'ymin': 42,
#     'xmax': 550,
#     'ymax': 210}],
#   'folder': 'wider_face/data/WIDER_train/images/56--Voter',
#   'filename': 'wider_face/data/WIDER_train/images/56--Voter/56_Voter_peoplevoting_56_226.jpg',
#   'width': 1024,
#   'height': 579},
#  {'object': [{'name': 'face',
#     'xmin': 429,
#     'ymin': 49,
#     'xmax': 476,
#     'ymax': 108},
#    {'name': 'face', 'xmin': 360, 'ymin': 89, 'xmax': 407, 'ymax': 144},
#    {'name': 'face', 'xmin': 161, 'ymin': 139, 'xmax': 205, 'ymax': 202},
#    {'name': 'face', 'xmin': 119, 'ymin': 260, 'xmax': 170, 'ymax': 330}],
#   'folder': 'wider_face/data/WIDER_train/images/6--Funeral',
#   'filename': 'wider_face/data/WIDER_train/images/6--Funeral/6_Funeral_Funeral_6_146.jpg',
#   'width': 1024,
#   'height': 577},
#  {'object': [{'name': 'face',
#     'xmin': 620,
#     'ymin': 200,
#     'xmax': 647,
#     'ymax': 231},
#    {'name': 'face', 'xmin': 551, 'ymin': 196, 'xmax': 578, 'ymax': 224},
#    {'name': 'face', 'xmin': 492, 'ymin': 202, 'xmax': 522, 'ymax': 236},
#    {'name': 'face', 'xmin': 421, 'ymin': 207, 'xmax': 453, 'ymax': 249},
#    {'name': 'face', 'xmin': 445, 'ymin': 195, 'xmax': 472, 'ymax': 226},
#    {'name': 'face', 'xmin': 509, 'ymin': 175, 'xmax': 517, 'ymax': 186},
#    {'name': 'face', 'xmin': 3, 'ymin': 164, 'xmax': 21, 'ymax': 184}],
#   'folder': 'wider_face/data/WIDER_train/images/29--Students_Schoolkids',
#   'filename': 'wider_face/data/WIDER_train/images/29--Students_Schoolkids/29_Students_Schoolkids_Students_Schoolkids_29_820.jpg',
#   'width': 1024,
#   'height': 576},
#  {'object': [{'name': 'face',
#     'xmin': 530,
#     'ymin': 180,
#     'xmax': 658,
#     'ymax': 402},
#    {'name': 'face', 'xmin': 38, 'ymin': 4, 'xmax': 180, 'ymax': 154},
#    {'name': 'face', 'xmin': 750, 'ymin': 2, 'xmax': 858, 'ymax': 104}],
#   'folder': 'wider_face/data/WIDER_train/images/8--Election_Campain',
#   'filename': 'wider_face/data/WIDER_train/images/8--Election_Campain/8_Election_Campain_Election_Campaign_8_215.jpg',
#   'width': 1024,
#   'height': 682},
#  {'object': [{'name': 'face',
#     'xmin': 540,
#     'ymin': 38,
#     'xmax': 642,
#     'ymax': 158}],
#   'folder': 'wider_face/data/WIDER_train/images/55--Sports_Coach_Trainer',
#   'filename': 'wider_face/data/WIDER_train/images/55--Sports_Coach_Trainer/55_Sports_Coach_Trainer_sportcoaching_55_753.jpg',
#   'width': 1024,
#   'height': 576},
#  {'object': [{'name': 'face',
#     'xmin': 76,
#     'ymin': 46,
#     'xmax': 166,
#     'ymax': 118},
#    {'name': 'face', 'xmin': 738, 'ymin': 488, 'xmax': 832, 'ymax': 576}],
#   'folder': 'wider_face/data/WIDER_train/images/39--Ice_Skating',
#   'filename': 'wider_face/data/WIDER_train/images/39--Ice_Skating/39_Ice_Skating_Ice_Skating_39_212.jpg',
#   'width': 1024,
#   'height': 768},
#  {'object': [{'name': 'face',
#     'xmin': 167,
#     'ymin': 107,
#     'xmax': 217,
#     'ymax': 173},
#    {'name': 'face', 'xmin': 277, 'ymin': 115, 'xmax': 320, 'ymax': 176},
#    {'name': 'face', 'xmin': 439, 'ymin': 150, 'xmax': 479, 'ymax': 199},
#    {'name': 'face', 'xmin': 557, 'ymin': 131, 'xmax': 599, 'ymax': 184},
#    {'name': 'face', 'xmin': 703, 'ymin': 125, 'xmax': 746, 'ymax': 178},
#    {'name': 'face', 'xmin': 874, 'ymin': 94, 'xmax': 922, 'ymax': 155}],
#   'folder': 'wider_face/data/WIDER_train/images/16--Award_Ceremony',
#   'filename': 'wider_face/data/WIDER_train/images/16--Award_Ceremony/16_Award_Ceremony_Awards_Ceremony_16_246.jpg',
#   'width': 1024,
#   'height': 680},
#  {'object': [{'name': 'face',
#     'xmin': 439,
#     'ymin': 319,
#     'xmax': 681,
#     'ymax': 650}],
#   'folder': 'wider_face/data/WIDER_train/images/9--Press_Conference',
#   'filename': 'wider_face/data/WIDER_train/images/9--Press_Conference/9_Press_Conference_Press_Conference_9_301.jpg',
#   'width': 1024,
#   'height': 1530},
#  {'object': [{'name': 'face',
#     'xmin': 562,
#     'ymin': 55,
#     'xmax': 585,
#     'ymax': 84}],
#   'folder': 'wider_face/data/WIDER_train/images/43--Row_Boat',
#   'filename': 'wider_face/data/WIDER_train/images/43--Row_Boat/43_Row_Boat_Rowboat_43_426.jpg',
#   'width': 1024,
#   'height': 451},
#  {'object': [{'name': 'face',
#     'xmin': 272,
#     'ymin': 201,
#     'xmax': 742,
#     'ymax': 819}],
#   'folder': 'wider_face/data/WIDER_train/images/30--Surgeons',
#   'filename': 'wider_face/data/WIDER_train/images/30--Surgeons/30_Surgeons_Surgeons_30_618.jpg',
#   'width': 1024,
#   'height': 1181},
#  {'object': [{'name': 'face',
#     'xmin': 100,
#     'ymin': 323,
#     'xmax': 167,
#     'ymax': 392},
#    {'name': 'face', 'xmin': 195, 'ymin': 307, 'xmax': 215, 'ymax': 330},
#    {'name': 'face', 'xmin': 224, 'ymin': 299, 'xmax': 240, 'ymax': 314},
#    {'name': 'face', 'xmin': 228, 'ymin': 316, 'xmax': 244, 'ymax': 338},
#    {'name': 'face', 'xmin': 262, 'ymin': 311, 'xmax': 280, 'ymax': 340},
#    {'name': 'face', 'xmin': 308, 'ymin': 308, 'xmax': 321, 'ymax': 320},
#    {'name': 'face', 'xmin': 326, 'ymin': 315, 'xmax': 342, 'ymax': 331},
#    {'name': 'face', 'xmin': 341, 'ymin': 307, 'xmax': 355, 'ymax': 323},
#    {'name': 'face', 'xmin': 379, 'ymin': 311, 'xmax': 399, 'ymax': 331},
#    {'name': 'face', 'xmin': 447, 'ymin': 317, 'xmax': 467, 'ymax': 338},
#    {'name': 'face', 'xmin': 482, 'ymin': 327, 'xmax': 503, 'ymax': 351},
#    {'name': 'face', 'xmin': 502, 'ymin': 329, 'xmax': 516, 'ymax': 349},
#    {'name': 'face', 'xmin': 497, 'ymin': 310, 'xmax': 510, 'ymax': 328},
#    {'name': 'face', 'xmin': 532, 'ymin': 314, 'xmax': 546, 'ymax': 329},
#    {'name': 'face', 'xmin': 555, 'ymin': 325, 'xmax': 570, 'ymax': 347},
#    {'name': 'face', 'xmin': 583, 'ymin': 303, 'xmax': 603, 'ymax': 325},
#    {'name': 'face', 'xmin': 664, 'ymin': 303, 'xmax': 680, 'ymax': 330},
#    {'name': 'face', 'xmin': 611, 'ymin': 91, 'xmax': 633, 'ymax': 122},
#    {'name': 'face', 'xmin': 706, 'ymin': 326, 'xmax': 729, 'ymax': 354},
#    {'name': 'face', 'xmin': 691, 'ymin': 303, 'xmax': 710, 'ymax': 326},
#    {'name': 'face', 'xmin': 720, 'ymin': 308, 'xmax': 736, 'ymax': 330},
#    {'name': 'face', 'xmin': 745, 'ymin': 309, 'xmax': 755, 'ymax': 330},
#    {'name': 'face', 'xmin': 768, 'ymin': 284, 'xmax': 796, 'ymax': 316},
#    {'name': 'face', 'xmin': 789, 'ymin': 258, 'xmax': 833, 'ymax': 306},
#    {'name': 'face', 'xmin': 903, 'ymin': 319, 'xmax': 916, 'ymax': 340},
#    {'name': 'face', 'xmin': 968, 'ymin': 296, 'xmax': 992, 'ymax': 325},
#    {'name': 'face', 'xmin': 961, 'ymin': 274, 'xmax': 986, 'ymax': 310},
#    {'name': 'face', 'xmin': 613, 'ymin': 298, 'xmax': 627, 'ymax': 316},
#    {'name': 'face', 'xmin': 643, 'ymin': 300, 'xmax': 661, 'ymax': 323},
#    {'name': 'face', 'xmin': 419, 'ymin': 305, 'xmax': 430, 'ymax': 320}],
#   'folder': 'wider_face/data/WIDER_train/images/2--Demonstration',
#   'filename': 'wider_face/data/WIDER_train/images/2--Demonstration/2_Demonstration_Demonstrators_2_439.jpg',
#   'width': 1024,
#   'height': 668},
#  {'object': [{'name': 'face', 'xmin': 119, 'ymin': 4, 'xmax': 151, 'ymax': 42},
#    {'name': 'face', 'xmin': 30, 'ymin': 15, 'xmax': 39, 'ymax': 25},
#    {'name': 'face', 'xmin': 45, 'ymin': 20, 'xmax': 56, 'ymax': 29},
#    {'name': 'face', 'xmin': 360, 'ymin': 793, 'xmax': 368, 'ymax': 802},
#    {'name': 'face', 'xmin': 442, 'ymin': 860, 'xmax': 456, 'ymax': 876},
#    {'name': 'face', 'xmin': 607, 'ymin': 866, 'xmax': 618, 'ymax': 883}],
#   'folder': 'wider_face/data/WIDER_train/images/39--Ice_Skating',
#   'filename': 'wider_face/data/WIDER_train/images/39--Ice_Skating/39_Ice_Skating_iceskiing_39_113.jpg',
#   'width': 1024,
#   'height': 1024},
#  {'object': [{'name': 'face',
#     'xmin': 312,
#     'ymin': 524,
#     'xmax': 369,
#     'ymax': 595}],
#   'folder': 'wider_face/data/WIDER_train/images/35--Basketball',
#   'filename': 'wider_face/data/WIDER_train/images/35--Basketball/35_Basketball_playingbasketball_35_32.jpg',
#   'width': 1024,
#   'height': 1392},
#  {'object': [{'name': 'face',
#     'xmin': 627,
#     'ymin': 422,
#     'xmax': 655,
#     'ymax': 457}],
#   'folder': 'wider_face/data/WIDER_train/images/10--People_Marching',
#   'filename': 'wider_face/data/WIDER_train/images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_840.jpg',
#   'width': 1024,
#   'height': 772},
#  {'object': [{'name': 'face',
#     'xmin': 470,
#     'ymin': 247,
#     'xmax': 575,
#     'ymax': 389}],
#   'folder': 'wider_face/data/WIDER_train/images/6--Funeral',
#   'filename': 'wider_face/data/WIDER_train/images/6--Funeral/6_Funeral_Funeral_6_634.jpg',
#   'width': 1024,
#   'height': 1543},
#  {'object': [{'name': 'face',
#     'xmin': 937,
#     'ymin': 329,
#     'xmax': 1014,
#     'ymax': 428},
#    {'name': 'face', 'xmin': 918, 'ymin': 382, 'xmax': 959, 'ymax': 457},
#    {'name': 'face', 'xmin': 778, 'ymin': 365, 'xmax': 848, 'ymax': 435},
#    {'name': 'face', 'xmin': 876, 'ymin': 267, 'xmax': 916, 'ymax': 321},
#    {'name': 'face', 'xmin': 752, 'ymin': 269, 'xmax': 805, 'ymax': 333},
#    {'name': 'face', 'xmin': 843, 'ymin': 246, 'xmax': 864, 'ymax': 275},
#    {'name': 'face', 'xmin': 742, 'ymin': 258, 'xmax': 761, 'ymax': 283},
#    {'name': 'face', 'xmin': 739, 'ymin': 238, 'xmax': 752, 'ymax': 251},
#    {'name': 'face', 'xmin': 950, 'ymin': 222, 'xmax': 957, 'ymax': 231},
#    {'name': 'face', 'xmin': 920, 'ymin': 302, 'xmax': 965, 'ymax': 376},
#    {'name': 'face', 'xmin': 647, 'ymin': 300, 'xmax': 695, 'ymax': 378},
#    {'name': 'face', 'xmin': 606, 'ymin': 274, 'xmax': 656, 'ymax': 344},
#    {'name': 'face', 'xmin': 548, 'ymin': 342, 'xmax': 597, 'ymax': 402},
#    {'name': 'face', 'xmin': 549, 'ymin': 297, 'xmax': 593, 'ymax': 343},
#    {'name': 'face', 'xmin': 484, 'ymin': 393, 'xmax': 537, 'ymax': 458},
#    {'name': 'face', 'xmin': 527, 'ymin': 295, 'xmax': 555, 'ymax': 344},
#    {'name': 'face', 'xmin': 497, 'ymin': 291, 'xmax': 529, 'ymax': 338},
#    {'name': 'face', 'xmin': 441, 'ymin': 295, 'xmax': 489, 'ymax': 358},
#    {'name': 'face', 'xmin': 509, 'ymin': 240, 'xmax': 523, 'ymax': 258},
#    {'name': 'face', 'xmin': 399, 'ymin': 347, 'xmax': 436, 'ymax': 399},
#    {'name': 'face', 'xmin': 337, 'ymin': 318, 'xmax': 388, 'ymax': 385},
#    {'name': 'face', 'xmin': 326, 'ymin': 282, 'xmax': 362, 'ymax': 333},
#    {'name': 'face', 'xmin': 363, 'ymin': 255, 'xmax': 392, 'ymax': 291},
#    {'name': 'face', 'xmin': 432, 'ymin': 275, 'xmax': 448, 'ymax': 309},
#    {'name': 'face', 'xmin': 271, 'ymin': 282, 'xmax': 315, 'ymax': 338},
#    {'name': 'face', 'xmin': 195, 'ymin': 313, 'xmax': 249, 'ymax': 373},
#    {'name': 'face', 'xmin': 159, 'ymin': 299, 'xmax': 197, 'ymax': 350},
#    {'name': 'face', 'xmin': 47, 'ymin': 333, 'xmax': 107, 'ymax': 401},
#    {'name': 'face', 'xmin': 109, 'ymin': 320, 'xmax': 146, 'ymax': 363},
#    {'name': 'face', 'xmin': 198, 'ymin': 254, 'xmax': 231, 'ymax': 290},
#    {'name': 'face', 'xmin': 75, 'ymin': 233, 'xmax': 108, 'ymax': 261},
#    {'name': 'face', 'xmin': 26, 'ymin': 278, 'xmax': 73, 'ymax': 337},
#    {'name': 'face', 'xmin': 1, 'ymin': 404, 'xmax': 70, 'ymax': 493},
#    {'name': 'face', 'xmin': 151, 'ymin': 245, 'xmax': 164, 'ymax': 259},
# ...
#   'width': 1024,
#   'height': 768},
#  {'object': [{'name': 'face',
#     'xmin': 53,
#     'ymin': 272,
#     'xmax': 58,
#     'ymax': 278},
#    {'name': 'face', 'xmin': 253, 'ymin': 102, 'xmax': 292, 'ymax': 163},
#    {'name': 'face', 'xmin': 263, 'ymin': 274, 'xmax': 281, 'ymax': 299},
#    {'name': 'face', 'xmin': 714, 'ymin': 82, 'xmax': 772, 'ymax': 154}],
#   'folder': 'wider_face/data/WIDER_train/images/2--Demonstration',
#   'filename': 'wider_face/data/WIDER_train/images/2--Demonstration/2_Demonstration_Demonstration_Or_Protest_2_363.jpg',
#   'width': 1024,
#   'height': 762},
#  {'object': [{'name': 'face',
#     'xmin': 465,
#     'ymin': 338,
#     'xmax': 495,
#     'ymax': 380},
#    {'name': 'face', 'xmin': 520, 'ymin': 368, 'xmax': 554, 'ymax': 409},
#    {'name': 'face', 'xmin': 616, 'ymin': 398, 'xmax': 638, 'ymax': 430},
#    {'name': 'face', 'xmin': 684, 'ymin': 408, 'xmax': 708, 'ymax': 439},
#    {'name': 'face', 'xmin': 744, 'ymin': 436, 'xmax': 760, 'ymax': 460},
#    {'name': 'face', 'xmin': 792, 'ymin': 444, 'xmax': 809, 'ymax': 468},
#    {'name': 'face', 'xmin': 844, 'ymin': 390, 'xmax': 862, 'ymax': 427},
#    {'name': 'face', 'xmin': 978, 'ymin': 462, 'xmax': 1006, 'ymax': 512}],
#   'folder': 'wider_face/data/WIDER_train/images/23--Shoppers',
#   'filename': 'wider_face/data/WIDER_train/images/23--Shoppers/23_Shoppers_Shoppers_23_152.jpg',
#   'width': 1024,
#   'height': 768},
#  {'object': [{'name': 'face',
#     'xmin': 89,
#     'ymin': 108,
#     'xmax': 138,
#     'ymax': 177},
#    {'name': 'face', 'xmin': 280, 'ymin': 134, 'xmax': 314, 'ymax': 165},
#    {'name': 'face', 'xmin': 357, 'ymin': 62, 'xmax': 407, 'ymax': 128},
#    {'name': 'face', 'xmin': 792, 'ymin': 159, 'xmax': 825, 'ymax': 189},
#    {'name': 'face', 'xmin': 971, 'ymin': 114, 'xmax': 1017, 'ymax': 160}],
#   'folder': 'wider_face/data/WIDER_train/images/36--Football',
#   'filename': 'wider_face/data/WIDER_train/images/36--Football/36_Football_americanfootball_ball_36_851.jpg',
#   'width': 1024,
#   'height': 683},
#  {'object': [{'name': 'face',
#     'xmin': 236,
#     'ymin': 304,
#     'xmax': 298,
#     'ymax': 384}],
#   'folder': 'wider_face/data/WIDER_train/images/48--Parachutist_Paratrooper',
#   'filename': 'wider_face/data/WIDER_train/images/48--Parachutist_Paratrooper/48_Parachutist_Paratrooper_Parachutist_Paratrooper_48_146.jpg',
#   'width': 1024,
#   'height': 679},
#  {'object': [{'name': 'face',
#     'xmin': 418,
#     'ymin': 269,
#     'xmax': 654,
#     'ymax': 584}],
#   'folder': 'wider_face/data/WIDER_train/images/28--Sports_Fan',
#   'filename': 'wider_face/data/WIDER_train/images/28--Sports_Fan/28_Sports_Fan_Sports_Fan_28_44.jpg',
#   'width': 1024,
#   'height': 1392},
#  {'object': [{'name': 'face',
#     'xmin': 475,
#     'ymin': 354,
#     'xmax': 623,
#     'ymax': 507},
#    {'name': 'face', 'xmin': 124, 'ymin': 419, 'xmax': 269, 'ymax': 575}],
#   'folder': 'wider_face/data/WIDER_train/images/35--Basketball',
#   'filename': 'wider_face/data/WIDER_train/images/35--Basketball/35_Basketball_basketballgame_ball_35_612.jpg',
#   'width': 1024,
#   'height': 1512},
#  {'object': [{'name': 'face',
#     'xmin': 702,
#     'ymin': 116,
#     'xmax': 936,
#     'ymax': 412}],
#   'folder': 'wider_face/data/WIDER_train/images/34--Baseball',
#   'filename': 'wider_face/data/WIDER_train/images/34--Baseball/34_Baseball_Baseball_34_898.jpg',
#   'width': 1024,
#   'height': 640},
#  {'object': [{'name': 'face',
#     'xmin': 109,
#     'ymin': 213,
#     'xmax': 402,
#     'ymax': 594},
#    {'name': 'face', 'xmin': 591, 'ymin': 449, 'xmax': 950, 'ymax': 927},
#    {'name': 'face', 'xmin': 241, 'ymin': 695, 'xmax': 558, 'ymax': 1073}],
#   'folder': 'wider_face/data/WIDER_train/images/33--Running',
#   'filename': 'wider_face/data/WIDER_train/images/33--Running/33_Running_Running_33_637.jpg',
#   'width': 1024,
#   'height': 1212},
#  {'object': [{'name': 'face',
#     'xmin': 580,
#     'ymin': 340,
#     'xmax': 608,
#     'ymax': 399},
#    {'name': 'face', 'xmin': 617, 'ymin': 119, 'xmax': 666, 'ymax': 176}],
#   'folder': 'wider_face/data/WIDER_train/images/34--Baseball',
#   'filename': 'wider_face/data/WIDER_train/images/34--Baseball/34_Baseball_Baseball_34_126.jpg',
#   'width': 1024,
#   'height': 668},
#  {'object': [{'name': 'face',
#     'xmin': 184,
#     'ymin': 275,
#     'xmax': 242,
#     'ymax': 347},
#    {'name': 'face', 'xmin': 656, 'ymin': 291, 'xmax': 712, 'ymax': 368}],
#   'folder': 'wider_face/data/WIDER_train/images/25--Soldier_Patrol',
#   'filename': 'wider_face/data/WIDER_train/images/25--Soldier_Patrol/25_Soldier_Patrol_Soldier_Patrol_25_619.jpg',
#   'width': 1024,
#   'height': 724},
#  {'object': [{'name': 'face',
#     'xmin': 820,
#     'ymin': 203,
#     'xmax': 846,
#     'ymax': 246},
#    {'name': 'face', 'xmin': 410, 'ymin': 111, 'xmax': 450, 'ymax': 169}],
#   'folder': 'wider_face/data/WIDER_train/images/39--Ice_Skating',
#   'filename': 'wider_face/data/WIDER_train/images/39--Ice_Skating/39_Ice_Skating_Ice_Skating_39_985.jpg',
#   'width': 1024,
#   'height': 685},
#  {'object': [{'name': 'face',
#     'xmin': 452,
#     'ymin': 86,
#     'xmax': 654,
#     'ymax': 409}],
#   'folder': 'wider_face/data/WIDER_train/images/12--Group',
#   'filename': 'wider_face/data/WIDER_train/images/12--Group/12_Group_Team_Organized_Group_12_Group_Team_Organized_Group_12_567.jpg',
#   'width': 1024,
#   'height': 1101},
#  {'object': [{'name': 'face',
#     'xmin': 538,
#     'ymin': 158,
#     'xmax': 682,
#     'ymax': 262},
#    {'name': 'face', 'xmin': 734, 'ymin': 340, 'xmax': 868, 'ymax': 412}],
#   'folder': 'wider_face/data/WIDER_train/images/4--Dancing',
#   'filename': 'wider_face/data/WIDER_train/images/4--Dancing/4_Dancing_Dancing_4_484.jpg',
#   'width': 1024,
#   'height': 662},
#  {'object': [{'name': 'face',
#     'xmin': 235,
#     'ymin': 109,
#     'xmax': 525,
#     'ymax': 507}],
#   'folder': 'wider_face/data/WIDER_train/images/16--Award_Ceremony',
#   'filename': 'wider_face/data/WIDER_train/images/16--Award_Ceremony/16_Award_Ceremony_Awards_Ceremony_16_709.jpg',
#   'width': 1024,
#   'height': 1326},
#  {'object': [{'name': 'face',
#     'xmin': 217,
#     'ymin': 146,
#     'xmax': 243,
#     'ymax': 183},
#    {'name': 'face', 'xmin': 798, 'ymin': 192, 'xmax': 829, 'ymax': 228}],
#   'folder': 'wider_face/data/WIDER_train/images/38--Tennis',
#   'filename': 'wider_face/data/WIDER_train/images/38--Tennis/38_Tennis_Tennis_38_224.jpg',
#   'width': 1024,
#   'height': 662},
#  {'object': [{'name': 'face',
#     'xmin': 481,
#     'ymin': 496,
#     'xmax': 628,
#     'ymax': 681}],
#   'folder': 'wider_face/data/WIDER_train/images/32--Worker_Laborer',
#   'filename': 'wider_face/data/WIDER_train/images/32--Worker_Laborer/32_Worker_Laborer_Worker_Laborer_32_863.jpg',
#   'width': 1024,
#   'height': 1504},
#  {'object': [{'name': 'face',
#     'xmin': 338,
#     'ymin': 261,
#     'xmax': 377,
#     'ymax': 307}],
#   'folder': 'wider_face/data/WIDER_train/images/4--Dancing',
#   'filename': 'wider_face/data/WIDER_train/images/4--Dancing/4_Dancing_Dancing_4_490.jpg',
#   'width': 1024,
#   'height': 683},
#  {'object': [{'name': 'face',
#     'xmin': 144,
#     'ymin': 201,
#     'xmax': 209,
#     'ymax': 286},
#    {'name': 'face', 'xmin': 376, 'ymin': 255, 'xmax': 438, 'ymax': 346},
#    {'name': 'face', 'xmin': 464, 'ymin': 320, 'xmax': 535, 'ymax': 411},
#    {'name': 'face', 'xmin': 687, 'ymin': 266, 'xmax': 763, 'ymax': 359},
#    {'name': 'face', 'xmin': 837, 'ymin': 286, 'xmax': 916, 'ymax': 391}],
#   'folder': 'wider_face/data/WIDER_train/images/18--Concerts',
#   'filename': 'wider_face/data/WIDER_train/images/18--Concerts/18_Concerts_Concerts_18_918.jpg',
#   'width': 1024,
#   'height': 1450},
#  {'object': [{'name': 'face',
#     'xmin': 233,
#     'ymin': 646,
#     'xmax': 264,
#     'ymax': 704}],
#   'folder': 'wider_face/data/WIDER_train/images/27--Spa',
#   'filename': 'wider_face/data/WIDER_train/images/27--Spa/27_Spa_Spa_27_260.jpg',
#   'width': 1024,
#   'height': 1200},
#  {'object': [{'name': 'face',
#     'xmin': 100,
#     'ymin': 364,
#     'xmax': 170,
#     'ymax': 446},
#    {'name': 'face', 'xmin': 480, 'ymin': 334, 'xmax': 538, 'ymax': 420},
#    {'name': 'face', 'xmin': 782, 'ymin': 382, 'xmax': 842, 'ymax': 456}],
#   'folder': 'wider_face/data/WIDER_train/images/2--Demonstration',
#   'filename': 'wider_face/data/WIDER_train/images/2--Demonstration/2_Demonstration_Demonstrators_2_610.jpg',
#   'width': 1024,
#   'height': 808},
#  {'object': [{'name': 'face',
#     'xmin': 121,
#     'ymin': 265,
#     'xmax': 142,
#     'ymax': 293},
#    {'name': 'face', 'xmin': 68, 'ymin': 267, 'xmax': 88, 'ymax': 291},
#    {'name': 'face', 'xmin': 16, 'ymin': 266, 'xmax': 33, 'ymax': 285},
#    {'name': 'face', 'xmin': 41, 'ymin': 277, 'xmax': 56, 'ymax': 293},
#    {'name': 'face', 'xmin': 221, 'ymin': 270, 'xmax': 243, 'ymax': 297},
#    {'name': 'face', 'xmin': 256, 'ymin': 265, 'xmax': 267, 'ymax': 279},
#    {'name': 'face', 'xmin': 306, 'ymin': 275, 'xmax': 323, 'ymax': 293},
#    {'name': 'face', 'xmin': 327, 'ymin': 281, 'xmax': 343, 'ymax': 302},
#    {'name': 'face', 'xmin': 359, 'ymin': 279, 'xmax': 382, 'ymax': 307},
#    {'name': 'face', 'xmin': 502, 'ymin': 297, 'xmax': 521, 'ymax': 323},
#    {'name': 'face', 'xmin': 575, 'ymin': 272, 'xmax': 600, 'ymax': 298},
#    {'name': 'face', 'xmin': 612, 'ymin': 245, 'xmax': 640, 'ymax': 278},
#    {'name': 'face', 'xmin': 648, 'ymin': 278, 'xmax': 665, 'ymax': 297},
#    {'name': 'face', 'xmin': 767, 'ymin': 280, 'xmax': 796, 'ymax': 317},
#    {'name': 'face', 'xmin': 816, 'ymin': 281, 'xmax': 838, 'ymax': 310},
#    {'name': 'face', 'xmin': 1007, 'ymin': 273, 'xmax': 1024, 'ymax': 309}],
#   'folder': 'wider_face/data/WIDER_train/images/12--Group',
#   'filename': 'wider_face/data/WIDER_train/images/12--Group/12_Group_Team_Organized_Group_12_Group_Team_Organized_Group_12_215.jpg',
#   'width': 1024,
#   'height': 680},
#  {'object': [{'name': 'face',
#     'xmin': 486,
#     'ymin': 42,
#     'xmax': 546,
#     'ymax': 126}],
#   'folder': 'wider_face/data/WIDER_train/images/40--Gymnastics',
#   'filename': 'wider_face/data/WIDER_train/images/40--Gymnastics/40_Gymnastics_Gymnastics_40_589.jpg',
#   'width': 1024,
#   'height': 645},
#  {'object': [{'name': 'face',
#     'xmin': 506,
#     'ymin': 220,
#     'xmax': 687,
#     'ymax': 443}],
#   'folder': 'wider_face/data/WIDER_train/images/21--Festival',
#   'filename': 'wider_face/data/WIDER_train/images/21--Festival/21_Festival_Festival_21_972.jpg',
#   'width': 1024,
#   'height': 1543},
#  {'object': [{'name': 'face',
#     'xmin': 380,
#     'ymin': 159,
#     'xmax': 620,
#     'ymax': 449}],
#   'folder': 'wider_face/data/WIDER_train/images/18--Concerts',
#   'filename': 'wider_face/data/WIDER_train/images/18--Concerts/18_Concerts_Concerts_18_887.jpg',
#   'width': 1024,
#   'height': 1535},
#  {'object': [{'name': 'face',
#     'xmin': 260,
#     'ymin': 174,
#     'xmax': 338,
#     'ymax': 288},
#    {'name': 'face', 'xmin': 446, 'ymin': 198, 'xmax': 518, 'ymax': 304},
#    {'name': 'face', 'xmin': 574, 'ymin': 294, 'xmax': 672, 'ymax': 422},
#    {'name': 'face', 'xmin': 764, 'ymin': 284, 'xmax': 854, 'ymax': 396}],
#   'folder': 'wider_face/data/WIDER_train/images/40--Gymnastics',
#   'filename': 'wider_face/data/WIDER_train/images/40--Gymnastics/40_Gymnastics_Gymnastics_40_416.jpg',
#   'width': 1024,
#   'height': 768},
#  {'object': [{'name': 'face',
#     'xmin': 189,
#     'ymin': 267,
#     'xmax': 697,
#     'ymax': 937}],
#   'folder': 'wider_face/data/WIDER_train/images/13--Interview',
#   'filename': 'wider_face/data/WIDER_train/images/13--Interview/13_Interview_Interview_Sequences_13_452.jpg',
#   'width': 1024,
#   'height': 1485},
#  {'object': [{'name': 'face',
#     'xmin': 794,
#     'ymin': 338,
#     'xmax': 815,
#     'ymax': 367},
#    {'name': 'face', 'xmin': 765, 'ymin': 240, 'xmax': 793, 'ymax': 272},
#    {'name': 'face', 'xmin': 610, 'ymin': 244, 'xmax': 628, 'ymax': 266},
#    {'name': 'face', 'xmin': 566, 'ymin': 309, 'xmax': 592, 'ymax': 343},
#    {'name': 'face', 'xmin': 385, 'ymin': 320, 'xmax': 410, 'ymax': 351},
#    {'name': 'face', 'xmin': 211, 'ymin': 319, 'xmax': 236, 'ymax': 353},
#    {'name': 'face', 'xmin': 35, 'ymin': 300, 'xmax': 54, 'ymax': 323},
#    {'name': 'face', 'xmin': 108, 'ymin': 284, 'xmax': 124, 'ymax': 305},
#    {'name': 'face', 'xmin': 441, 'ymin': 255, 'xmax': 464, 'ymax': 281},
#    {'name': 'face', 'xmin': 570, 'ymin': 274, 'xmax': 585, 'ymax': 298},
#    {'name': 'face', 'xmin': 427, 'ymin': 272, 'xmax': 441, 'ymax': 288},
#    {'name': 'face', 'xmin': 968, 'ymin': 264, 'xmax': 1006, 'ymax': 301}],
#   'folder': 'wider_face/data/WIDER_train/images/24--Soldier_Firing',
#   'filename': 'wider_face/data/WIDER_train/images/24--Soldier_Firing/24_Soldier_Firing_Soldier_Firing_24_544.jpg',
#   'width': 1024,
#   'height': 682},
#  {'object': [{'name': 'face',
#     'xmin': 439,
#     'ymin': 182,
#     'xmax': 624,
#     'ymax': 436}],
#   'folder': 'wider_face/data/WIDER_train/images/0--Parade',
#   'filename': 'wider_face/data/WIDER_train/images/0--Parade/0_Parade_marchingband_1_873.jpg',
#   'width': 1024,
#   'height': 1413},
#  {'object': [{'name': 'face',
#     'xmin': 526,
#     'ymin': 106,
#     'xmax': 648,
#     'ymax': 312}],
#   'folder': 'wider_face/data/WIDER_train/images/28--Sports_Fan',
#   'filename': 'wider_face/data/WIDER_train/images/28--Sports_Fan/28_Sports_Fan_Sports_Fan_28_177.jpg',
#   'width': 1024,
#   'height': 683},
#  {'object': [{'name': 'face',
#     'xmin': 404,
#     'ymin': 284,
#     'xmax': 560,
#     'ymax': 488}],
#   'folder': 'wider_face/data/WIDER_train/images/41--Swimming',
#   'filename': 'wider_face/data/WIDER_train/images/41--Swimming/41_Swimming_Swimmer_41_182.jpg',
#   'width': 1024,
#   'height': 615},
#  {'object': [{'name': 'face',
#     'xmin': 332,
#     'ymin': 365,
#     'xmax': 374,
#     'ymax': 417},
#    {'name': 'face', 'xmin': 669, 'ymin': 353, 'xmax': 719, 'ymax': 424}],
#   'folder': 'wider_face/data/WIDER_train/images/27--Spa',
#   'filename': 'wider_face/data/WIDER_train/images/27--Spa/27_Spa_Spa_27_29.jpg',
#   'width': 1024,
#   'height': 683},
#  {'object': [{'name': 'face',
#     'xmin': 730,
#     'ymin': 76,
#     'xmax': 884,
#     'ymax': 292}],
#   'folder': 'wider_face/data/WIDER_train/images/13--Interview',
#   'filename': 'wider_face/data/WIDER_train/images/13--Interview/13_Interview_Interview_Sequences_13_334.jpg',
#   'width': 1024,
#   'height': 576},
#  {'object': [{'name': 'face',
#     'xmin': 368,
#     'ymin': 90,
#     'xmax': 444,
#     'ymax': 200},
#    {'name': 'face', 'xmin': 792, 'ymin': 232, 'xmax': 844, 'ymax': 350}],
#   'folder': 'wider_face/data/WIDER_train/images/24--Soldier_Firing',
#   'filename': 'wider_face/data/WIDER_train/images/24--Soldier_Firing/24_Soldier_Firing_Soldier_Firing_24_222.jpg',
#   'width': 1024,
#   'height': 719},
#  {'object': [{'name': 'face',
#     'xmin': 238,
#     'ymin': 250,
#     'xmax': 294,
#     'ymax': 358},
#    {'name': 'face', 'xmin': 296, 'ymin': 268, 'xmax': 358, 'ymax': 364}],
#   'folder': 'wider_face/data/WIDER_train/images/49--Greeting',
#   'filename': 'wider_face/data/WIDER_train/images/49--Greeting/49_Greeting_peoplegreeting_49_141.jpg',
#   'width': 1024,
#   'height': 768},
#  {'object': [{'name': 'face',
#     'xmin': 268,
#     'ymin': 385,
#     'xmax': 684,
#     'ymax': 889}],
#   'folder': 'wider_face/data/WIDER_train/images/28--Sports_Fan',
#   'filename': 'wider_face/data/WIDER_train/images/28--Sports_Fan/28_Sports_Fan_Sports_Fan_28_1027.jpg',
#   'width': 1024,
#   'height': 1332},
#  {'object': [{'name': 'face',
#     'xmin': 713,
#     'ymin': 211,
#     'xmax': 780,
#     'ymax': 305},
#    {'name': 'face', 'xmin': 452, 'ymin': 157, 'xmax': 493, 'ymax': 213},
#    {'name': 'face', 'xmin': 333, 'ymin': 161, 'xmax': 385, 'ymax': 231},
#    {'name': 'face', 'xmin': 275, 'ymin': 143, 'xmax': 340, 'ymax': 229},
#    {'name': 'face', 'xmin': 570, 'ymin': 298, 'xmax': 596, 'ymax': 328},
#    {'name': 'face', 'xmin': 611, 'ymin': 276, 'xmax': 633, 'ymax': 311},
#    {'name': 'face', 'xmin': 637, 'ymin': 264, 'xmax': 657, 'ymax': 288},
#    {'name': 'face', 'xmin': 369, 'ymin': 503, 'xmax': 411, 'ymax': 537},
#    {'name': 'face', 'xmin': 654, 'ymin': 283, 'xmax': 678, 'ymax': 303}],
#   'folder': 'wider_face/data/WIDER_train/images/12--Group',
#   'filename': 'wider_face/data/WIDER_train/images/12--Group/12_Group_Large_Group_12_Group_Large_Group_12_738.jpg',
#   'width': 1024,
#   'height': 657},
#  ...]

# %%
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf

def load_labels(img_data):
    labels = []
    bboxes = []
    for img in img_data:
        obj = img['object'][0]  # Get the only object in the image
        xmin, ymin, xmax, ymax = obj['xmin'], obj['ymin'], obj['xmax'], obj['ymax']
        
        # Resize bounding box coordinates
        xmin_resized = int(xmin * 224 / img['width'])
        ymin_resized = int(ymin * 224 / img['height'])
        xmax_resized = int(xmax * 224 / img['width'])
        ymax_resized = int(ymax * 224 / img['height'])
        
        labels.append([1])
        bboxes.append([xmin_resized, ymin_resized, xmax_resized, ymax_resized])
    
    labels = np.array(labels, dtype=np.uint8)
    bboxes = np.array(bboxes, dtype=np.float16)
    
    return labels, bboxes

# Split dataset into training and validation sets
train_imgs, val_imgs = train_test_split(train_imgs, test_size=0.2)

# Filter images with exactly one face
train_imgs_filtered = [img for img in train_imgs if len(img['object']) == 1]
val_imgs_filtered = [img for img in val_imgs if len(img['object']) == 1]

# Preprocess image data
X_train_images = np.array([cv2.resize(cv2.imread(img['filename']), (224, 224)) for img in train_imgs_filtered])
X_val_images = np.array([cv2.resize(cv2.imread(img['filename']), (224, 224)) for img in val_imgs_filtered])

# Load labels and bounding boxes
y_train_labels, y_train_bboxes = load_labels(train_imgs_filtered)
y_val_labels, y_val_bboxes = load_labels(val_imgs_filtered)

# %%
# Create TensorFlow datasets
train_labels_ds = tf.data.Dataset.from_tensor_slices((y_train_labels, y_train_bboxes))
val_labels_ds = tf.data.Dataset.from_tensor_slices((y_val_labels, y_val_bboxes))

train_images_ds = tf.data.Dataset.from_tensor_slices(X_train_images)
val_images_ds = tf.data.Dataset.from_tensor_slices(X_val_images)

# Zip the labels and images together
train = tf.data.Dataset.zip((train_images_ds, train_labels_ds))
val = tf.data.Dataset.zip((val_images_ds, val_labels_ds))

val = val.shuffle(5000)
train = train.shuffle(5000)

val = val.batch(8)
train = train.batch(8)

val = val.prefetch(4)
train = train.prefetch(4)
# Out:
# 2024-04-20 11:15:51.971317: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2024-04-20 11:15:51.971333: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2024-04-20 11:15:51.971337: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.00 GB
# 2024-04-20 11:15:51.971619: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-04-20 11:15:51.971630: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
train.as_numpy_iterator().next()[1]
# Out:
# (array([[1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1]], dtype=uint8),
#  array([[ 78.,  46., 102.,  72.],
#         [144., 105., 183., 141.],
#         [114.,  48., 122.,  61.],
#         [ 34.,  33.,  63.,  79.],
#         [ 37.,  21., 116., 192.],
#         [ 49.,  30., 100.,  74.],
#         [ 96.,  84., 109., 105.],
#         [ 61.,  39., 134., 113.]], dtype=float16))

# %%
from matplotlib import pyplot as plt
import cv2

data_samples = train.as_numpy_iterator()
res = data_samples.next()

fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx in range(4): 
    sample_image = res[0][idx].copy()
    sample_coords = res[1][1][idx]

    cv2.rectangle(sample_image, 
                  sample_coords[:2].astype(int),
                  sample_coords[2:].astype(int), 
                        (255,0,0), 2)
    
    sample_image = cv2.cvtColor(sample_image, cv2.COLOR_BGR2RGB)  # Convert color format
    
    ax[idx].imshow(sample_image)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Dense, GlobalMaxPooling2D
from tensorflow.keras.applications import VGG16
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
vgg = VGG16(include_top=False)

# %%
def build_model(): 
    input_layer = Input(shape=(224,224,3))
    
    vgg = VGG16(include_top=False)(input_layer)

    # Classification Model  
    f1 = GlobalMaxPooling2D()(vgg)
    class1 = Dense(2048, activation='relu')(f1)
    class2 = Dense(1, activation='sigmoid')(class1)
    
    # Bounding box model
    f2 = GlobalMaxPooling2D()(vgg)
    regress1 = Dense(2048, activation='relu')(f2)
    regress2 = Dense(4, activation='sigmoid')(regress1)
    
    facetracker = Model(inputs=input_layer, outputs=[class2, regress2])
    return facetracker

# %%
facetracker = build_model()

# %%
facetracker.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 7, 7, 512) │ 14,714,688 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 512)       │          0 │ vgg16[0][0]       │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 512)       │          0 │ vgg16[0][0]       │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 2048)      │  1,050,624 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 2048)      │  1,050,624 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │      2,049 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 4)         │      8,196 │ dense_2[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 16,826,181 (64.19 MB)
#  Trainable params: 16,826,181 (64.19 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
X, y = train.as_numpy_iterator().next()

# %%
X.shape
# Out:
# (8, 224, 224, 3)

# %%
classes, coords = facetracker.predict(X)
# Out:
# 2024-04-20 10:51:38.383982: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step

# %%
classes, coords
# Out:
# (array([[2.1911780e-03],
#         [2.0748470e-14],
#         [3.0371841e-05],
#         [2.2324085e-12],
#         [6.6650867e-01],
#         [4.6184154e-16],
#         [8.4879573e-16],
#         [6.3998877e-09]], dtype=float32),
#  array([[9.9999964e-01, 1.8244683e-06, 1.0000000e+00, 1.0000000e+00],
#         [9.7244531e-01, 2.3055821e-18, 1.0000000e+00, 1.3808438e-04],
#         [9.9999988e-01, 1.2298534e-09, 1.0000000e+00, 8.2806647e-01],
#         [6.6316030e-03, 1.2172983e-06, 1.0000000e+00, 9.9970418e-01],
#         [1.0000000e+00, 2.9219855e-08, 1.0000000e+00, 1.0000000e+00],
#         [2.0617587e-07, 4.6772995e-11, 1.0687176e-08, 3.2746501e-04],
#         [1.0000000e+00, 7.4198237e-03, 5.4522425e-01, 1.0000000e+00],
#         [5.8083278e-03, 1.7559518e-05, 1.0000000e+00, 1.0000000e+00]],
#        dtype=float32))

# %%
batches_per_epoch = len(train)
lr_decay = (1./0.75 -1)/batches_per_epoch

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.0001, decay=lr_decay)
# Out:
# /Users/arthurdesmazures/venv-metal/lib/python3.10/site-packages/keras/src/optimizers/base_optimizer.py:34: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %%
def localization_loss(y_true, yhat):            
    delta_coord = tf.reduce_sum(tf.square(y_true[:,:2] - yhat[:,:2]))
                  
    h_true = y_true[:,3] - y_true[:,1] 
    w_true = y_true[:,2] - y_true[:,0] 

    h_pred = yhat[:,3] - yhat[:,1] 
    w_pred = yhat[:,2] - yhat[:,0] 
    
    delta_size = tf.reduce_sum(tf.square(w_true - w_pred) + tf.square(h_true-h_pred))
    
    return delta_coord + delta_size

# %%
classloss = tf.keras.losses.BinaryCrossentropy()
regressloss = localization_loss

# %%
localization_loss(y[1], coords)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=175985.69>

# %%
classloss(y[0], classes)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=12.190186>

# %%
regressloss(y[1], coords)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=175985.69>

# %%
class FaceTracker(Model): 
    def __init__(self, eyetracker,  **kwargs): 
        super().__init__(**kwargs)
        self.model = eyetracker

    def compile(self, opt, classloss, localizationloss, **kwargs):
        super().compile(**kwargs)
        self.closs = classloss
        self.lloss = localizationloss
        self.opt = opt
    
    def train_step(self, batch, **kwargs): 
        
        X, y = batch
        
        with tf.GradientTape() as tape: 
            classes, coords = self.model(X, training=True)
            
            batch_classloss = self.closs(y[0], classes)
            batch_localizationloss = self.lloss(tf.cast(y[1], tf.float32), coords)
            
            total_loss = batch_localizationloss+0.5*batch_classloss
            
            grad = tape.gradient(total_loss, self.model.trainable_variables)
        
        opt.apply_gradients(zip(grad, self.model.trainable_variables))
        
        return {"total_loss":total_loss, "class_loss":batch_classloss, "regress_loss":batch_localizationloss}
    
    def test_step(self, batch, **kwargs): 
        X, y = batch
        
        classes, coords = self.model(X, training=False)
        
        batch_classloss = self.closs(y[0], classes)
        batch_localizationloss = self.lloss(tf.cast(y[1], tf.float32), coords)
        total_loss = batch_localizationloss+0.5*batch_classloss
        
        return {"total_loss":total_loss, "class_loss":batch_classloss, "regress_loss":batch_localizationloss}
        
    def call(self, X, **kwargs): 
        return self.model(X, **kwargs)

# %%
model = FaceTracker(facetracker)

# %%
model.compile(opt, classloss, regressloss)

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=2, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/2
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 108s 233ms/step - class_loss: 0.0000e+00 - regress_loss: 154103.4688 - total_loss: 154103.4688 - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 2/2
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 108s 234ms/step - class_loss: 0.0000e+00 - regress_loss: 154103.4688 - total_loss: 154103.4688 - loss: 0.0000e+00 - val_loss: 0.0000e+00

# %%
hist.history
# Out:
# {'loss': [0.0, 0.0], 'val_loss': [0.0, 0.0]}

# %%
fig, ax = plt.subplots(ncols=3, figsize=(20,5))

ax[0].plot(hist.history['total_loss'], color='teal', label='loss')
ax[0].plot(hist.history['val_total_loss'], color='orange', label='val loss')
ax[0].title.set_text('Loss')
ax[0].legend()

ax[1].plot(hist.history['class_loss'], color='teal', label='class loss')
ax[1].plot(hist.history['val_class_loss'], color='orange', label='val class loss')
ax[1].title.set_text('Classification Loss')
ax[1].legend()

ax[2].plot(hist.history['regress_loss'], color='teal', label='regress loss')
ax[2].plot(hist.history['val_regress_loss'], color='orange', label='val regress loss')
ax[2].title.set_text('Regression Loss')
ax[2].legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 3
#       1 fig, ax = plt.subplots(ncols=3, figsize=(20,5))
# ----> 3 ax[0].plot(hist.history['total_loss'], color='teal', label='loss')
#       4 ax[0].plot(hist.history['val_total_loss'], color='orange', label='val loss')
#       5 ax[0].title.set_text('Loss')
#
# KeyError: 'total_loss'

# %%
from tensorflow.keras.models import load_model

# %%
facetracker.save('facetracker.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 facetracker.save('facetracker.h5')
#
# File ~/venv-metal/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:123, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#     121     # To get the full stack trace, call:
#     122     # `keras.config.disable_traceback_filtering()`
# --> 123     raise e.with_traceback(filtered_tb) from None
#     124 finally:
#     125     del filtered_tb
#
# File ~/venv-metal/lib/python3.10/site-packages/h5py/_hl/group.py:183, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     180         parent_path, name = name.rsplit(b'/', 1)
#     181         group = self.require_group(parent_path)
# --> 183 dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     184 dset = dataset.Dataset(dsid)
#     185 return dset
#
# File ~/venv-metal/lib/python3.10/site-packages/h5py/_hl/dataset.py:163, in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, dapl, efile_prefix, virtual_prefix, allow_unknown_filter, rdcc_nslots, rdcc_nbytes, rdcc_w0)
#     160 else:
#     161     sid = h5s.create_simple(shape, maxshape)
# --> 163 dset_id = h5d.create(parent.id, name, tid, sid, dcpl=dcpl, dapl=dapl)
#     165 if (data is not None) and (not isinstance(data, Empty)):
#     166     dset_id.write(h5s.ALL, h5s.ALL, data)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5d.pyx:137, in h5py.h5d.create()
#
# ValueError: Unable to create dataset (name already exists)

# %%
facetracker = load_model('facetracker.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 facetracker = load_model('facetracker.h5')
#
# File ~/venv-metal/lib/python3.10/site-packages/keras/src/saving/saving_api.py:183, in load_model(filepath, custom_objects, compile, safe_mode)
#     176     return saving_lib.load_model(
#     177         filepath,
#     178         custom_objects=custom_objects,
#     179         compile=compile,
#     180         safe_mode=safe_mode,
#     181     )
#     182 if str(filepath).endswith((".h5", ".hdf5")):
# --> 183     return legacy_h5_format.load_model_from_hdf5(filepath)
#     184 elif str(filepath).endswith(".keras"):
#     185     raise ValueError(
#     186         f"File not found: filepath={filepath}. "
#     187         "Please ensure the file is an accessible `.keras` "
#     188         "zip file."
#     189     )
#
# File ~/venv-metal/lib/python3.10/site-packages/keras/src/legacy/saving/legacy_h5_format.py:138, in load_model_from_hdf5(filepath, custom_objects, compile)
#     133     model = saving_utils.model_from_config(
#     134         model_config, custom_objects=custom_objects
#     135     )
#     137     # set weights
# --> 138     load_weights_from_hdf5_group(f["model_weights"], model)
#     140 if compile:
#     141     # instantiate optimizer
#     142     training_config = f.attrs.get("training_config")
#
# File ~/venv-metal/lib/python3.10/site-packages/keras/src/legacy/saving/legacy_h5_format.py:376, in load_weights_from_hdf5_group(f, model)
#     369         raise ValueError(
#     370             f"Weight count mismatch for layer #{k} (named {layer.name} in "
#     371             f"the current model, {name} in the save file). "
#     372             f"Layer expects {len(symbolic_weights)} weight(s). Received "
#     373             f"{len(weight_values)} saved weight(s)"
#     374         )
#     375     for ref_v, val in zip(symbolic_weights, weight_values):
# --> 376         ref_v.assign(val)
#     378 if "top_level_model_weights" in f:
#     379     symbolic_weights = list(
#     380         # model.weights
#     381         v
#     382         for v in model._trainable_variables + model._non_trainable_variables
#     383         if v in model.weights
#     384     )
#
# File ~/venv-metal/lib/python3.10/site-packages/keras/src/backend/common/variables.py:135, in KerasVariable.assign(self, value)
#     133 value = self._convert_to_tensor(value, dtype=self.dtype)
#     134 if not shape_equal(value.shape, self.shape):
# --> 135     raise ValueError(
#     136         "The shape of the target variable and "
#     137         "the shape of the target value in "
#     138         "`variable.assign(value)` must match. "
#     139         f"variable.shape={self.value.shape}, "
#     140         f"Received: value.shape={value.shape}. "
#     141         f"Target variable: {self}"
#     142     )
#     143 if in_stateless_scope():
#     144     scope = get_stateless_scope()
#
# ValueError: The shape of the target variable and the shape of the target value in `variable.assign(value)` must match. variable.shape=(3, 3, 64, 64), Received: value.shape=(3, 3, 3, 64). Target variable: <KerasVariable shape=(3, 3, 64, 64), dtype=float32, path=block1_conv2/kernel>

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    _ , frame = cap.read()
    frame = frame[50:500, 50:500,:]
    
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    resized = tf.image.resize(rgb, (120,120))
    
    yhat = facetracker.predict(np.expand_dims(resized/255,0))
    sample_coords = yhat[1][0]
    
    if yhat[0] > 0.5: 
        # Controls the main rectangle
        cv2.rectangle(frame, 
                      tuple(np.multiply(sample_coords[:2], [450,450]).astype(int)),
                      tuple(np.multiply(sample_coords[2:], [450,450]).astype(int)), 
                            (255,0,0), 2)
        # Controls the label rectangle
        cv2.rectangle(frame, 
                      tuple(np.add(np.multiply(sample_coords[:2], [450,450]).astype(int), 
                                    [0,-30])),
                      tuple(np.add(np.multiply(sample_coords[:2], [450,450]).astype(int),
                                    [80,0])), 
                            (255,0,0), -1)
        
        # Controls the text rendered
        cv2.putText(frame, 'face', tuple(np.add(np.multiply(sample_coords[:2], [450,450]).astype(int),
                                               [0,-5])),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
    
    cv2.imshow('EyeTrack', frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 9
#       6 rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#       7 resized = tf.image.resize(rgb, (120,120))
# ----> 9 yhat = facetracker.predict(np.expand_dims(resized/255,0))
#      10 sample_coords = yhat[1][0]
#      12 if yhat[0] > 0.5:
#      13     # Controls the main rectangle
#
# File ~/venv-metal/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:123, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#     121     # To get the full stack trace, call:
#     122     # `keras.config.disable_traceback_filtering()`
# --> 123     raise e.with_traceback(filtered_tb) from None
#     124 finally:
#     125     del filtered_tb
#
# File ~/venv-metal/lib/python3.10/site-packages/keras/src/layers/input_spec.py:245, in assert_input_compatibility(input_spec, inputs, layer_name)
#     243 if spec_dim is not None and dim is not None:
#     244     if spec_dim != dim:
# --> 245         raise ValueError(
#     246             f'Input {input_index} of layer "{layer_name}" is '
#     247             "incompatible with the layer: "
#     248             f"expected shape={spec.shape}, "
#     249             f"found shape={shape}"
#     250         )
#
# ValueError: Input 0 of layer "functional_1" is incompatible with the layer: expected shape=(None, 224, 224, 3), found shape=(1, 120, 120, 3)
